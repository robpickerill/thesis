# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # Suppress TensorFlow INFO and WARNING messages

# %%
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1732466481.861594  386165 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1732466481.868195  386165 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
from tensorflow.keras import mixed_precision

mixed_precision.set_global_policy('mixed_float16')

# %%
import tensorflow as tf
import keras
import pandas as pd
import os
import keras_cv
import matplotlib.pyplot as plt

# %%
csv_file = 'ham10000_data/HAM10000_metadata.csv'
img_dir = 'ham10000_data/images'
file_ext = '.jpg'

df = pd.read_csv(csv_file)

image_paths = [
    os.path.join(img_dir, image_id + file_ext)
    for image_id in df['image_id']
]

print(f"Number of images: {len(image_paths)}")
print(f"First 5 image paths: {image_paths[:5]}")

classes = sorted(df['dx'].unique())
num_classes = len(classes)

print(f"Number of classes: {num_classes}")
print(f"Classes: {classes}")

labels = df['dx'].map(lambda x: classes.index(x)).values
class_to_idx = {cls: idx for idx, cls in enumerate(classes)}

print(f"Class to Index Mapping: {class_to_idx}")
print(f"Labels: {labels}")
# Out:
# Number of images: 10015
# First 5 image paths: ['ham10000_data/images/ISIC_0027419.jpg', 'ham10000_data/images/ISIC_0025030.jpg', 'ham10000_data/images/ISIC_0026769.jpg', 'ham10000_data/images/ISIC_0025661.jpg', 'ham10000_data/images/ISIC_0031633.jpg']
# Number of classes: 7
# Classes: ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']
# Class to Index Mapping: {'akiec': 0, 'bcc': 1, 'bkl': 2, 'df': 3, 'mel': 4, 'nv': 5, 'vasc': 6}
# Labels: [2 2 2 ... 0 0 4]

# %%
def load_and_preprocess_image(image_id, label):
    # Load and preprocess the image
    image = tf.io.read_file(image_id)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, (224, 224))  # ResNet expects 224x224 images
    image = tf.keras.applications.resnet50.preprocess_input(image)  # Preprocessing for ResNet

    # One-hot encode the label
    label = tf.one_hot(label, depth=num_classes)

    return image, label

# %%
from sklearn.model_selection import StratifiedShuffleSplit

train_paths = []
train_labels = []
val_paths = []
val_labels = []

sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, val_index in sss.split(image_paths, labels):
    train_paths = [image_paths[i] for i in train_index]
    train_labels = labels[train_index]
    val_paths = [image_paths[i] for i in val_index]
    val_labels = labels[val_index]

print(f"Training set size: {len(train_paths)}")
print(f"Validation set size: {len(val_paths)}")

train_dataset = tf.data.Dataset.from_tensor_slices((train_paths, train_labels))
val_dataset = tf.data.Dataset.from_tensor_slices((val_paths, val_labels))
# Out:
# Training set size: 8012
# Validation set size: 2003
# I0000 00:00:1732466485.611702  386165 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 11139 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:0b:00.0, compute capability: 6.0
# I0000 00:00:1732466485.612260  386165 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 15253 MB memory:  -> device: 1, name: Tesla P100-PCIE-16GB, pci bus id: 0000:13:00.0, compute capability: 6.0

# %%
batch_size = 32

train_dataset = train_dataset.map(load_and_preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
train_dataset = train_dataset.shuffle(buffer_size=1000).batch(batch_size).prefetch(tf.data.AUTOTUNE)
train_dataset = train_dataset.cache()

val_dataset = val_dataset.map(load_and_preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
val_dataset = val_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
val_dataset = val_dataset.cache()

# %%
data_augmentation = keras.Sequential([
    keras.layers.RandomFlip('horizontal'),
    keras.layers.RandomRotation(0.1),
    keras.layers.RandomZoom(0.1),
    keras.layers.RandomContrast(0.1),
    keras.layers.RandomTranslation(0.1, 0.1),
])

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# Compute class counts and class priors
class_counts = np.bincount(train_labels)
total_counts = np.sum(class_counts)
class_prior = class_counts / total_counts

# Clip class_prior to avoid log(0)
class_prior = np.clip(class_prior, 1e-7, 1.0)
output_bias = np.log(class_prior)

print(f"Class Counts: {class_counts}")
print(f"Class Prior: {class_prior}")
print(f"Output Bias: {output_bias}")
# Out:
# Class Counts: [ 262  411  879   92  890 5364  114]
# Class Prior: [0.03270095 0.05129805 0.10971043 0.01148278 0.11108337 0.66949576
#  0.01422866]
# Output Bias: [-3.42035119 -2.97010248 -2.2099108  -4.46690712 -2.19747423 -0.40123045
#  -4.25249725]

# %%
import tensorflow as tf
from tensorflow.keras import backend as K

def focal_loss(gamma=2., alpha=0.25):
    """
    Focal Loss for multi-class classification.

    Parameters:
    - gamma: Focusing parameter that adjusts the rate at which easy examples are down-weighted.
    - alpha: Balancing factor to balance the importance of different classes.

    Returns:
    - A loss function that can be used with multi-class classification models.
    """
    def focal_loss_fixed(y_true, y_pred):
        # Clip predictions to prevent log(0)
        epsilon = K.epsilon()
        y_pred = K.clip(y_pred, epsilon, 1. - epsilon)

        # Compute cross entropy
        cross_entropy = -y_true * K.log(y_pred)

        # Compute the focal loss weights
        loss_weight = alpha * K.pow(1 - y_pred, gamma)

        # Apply focal loss weights
        loss = loss_weight * cross_entropy

        # Sum over the last axis (the class axis)
        return K.sum(loss, axis=-1)

    return focal_loss_fixed

# %%
from tensorflow.keras.layers import GlobalAveragePooling2D, Reshape, Dense, Multiply

def se_block(input_tensor, reduction_ratio=16, l2_regularization=0.01):
    filters = input_tensor.shape[-1]  # Get the number of channels
    se_shape = (1, 1, filters)

    # Squeeze: Global Average Pooling
    se = GlobalAveragePooling2D()(input_tensor)
    se = Reshape(se_shape)(se)

    # Excitation: Fully connected layers
    se = Dense(
        filters // reduction_ratio,
        activation='relu',
        kernel_initializer='he_normal',
        use_bias=False,
        kernel_regularizer=keras.regularizers.l2(l2_regularization)
    )(se)

    se = Dense(
        filters,
        activation='sigmoid',
        kernel_initializer='he_normal',
        use_bias=False,
        kernel_regularizer=keras.regularizers.l2(l2_regularization)
    )(se)

    # Scale: Multiply the input by the SE block output
    x = Multiply()([input_tensor, se])

    return x

# %%
import tensorflow as tf
from tensorflow import keras


def build_resnet50_with_se(hp):
    inputs = tf.keras.Input(shape=(224, 224, 3))

    base_model = tf.keras.applications.ResNet50(
        include_top=False,
        weights='imagenet',
        input_tensor=inputs,
        pooling=None
    )

    # Freeze all layers initially
    base_model.trainable = False

    # Unfreeze later layers based on a hyperparameter
    unfreeze_from = hp.Choice('unfreeze_from', values=[0, -10, -20, -50])
    if unfreeze_from is not None:
        for layer in base_model.layers[unfreeze_from:]:
            layer.trainable = True

    reduction_ratio = hp.Choice('reduction_ratio', values=[4, 8, 16, 32])
    l2_regularization = hp.Choice('l2_regularization', values=[0.01, 0.001, 0.0001])

    # Get specific layers and apply SE blocks
    x = base_model.get_layer("conv2_block3_out").output
    x = se_block(x, reduction_ratio=reduction_ratio, l2_regularization=l2_regularization)

    x = base_model.get_layer("conv3_block4_out").output
    x = se_block(x, reduction_ratio=reduction_ratio, l2_regularization=l2_regularization)

    x = base_model.get_layer("conv4_block6_out").output
    x = se_block(x, reduction_ratio=reduction_ratio, l2_regularization=l2_regularization)

    x = base_model.get_layer("conv5_block3_out").output
    x = se_block(x, reduction_ratio=reduction_ratio, l2_regularization=l2_regularization)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    dropout_rate = hp.Choice('dropout_rate', values=[0.2, 0.3, 0.5])
    x = tf.keras.layers.Dropout(dropout_rate)(x)

    output_bias = np.log(np.ones((num_classes,)) / num_classes)
    outputs = tf.keras.layers.Dense(
        num_classes,
        activation='softmax',
        bias_initializer=tf.keras.initializers.Constant(output_bias),
        kernel_regularizer=tf.keras.regularizers.l2(hp.Choice('l2_regularization_output', values=[0.01, 0.001, 0.0001]))
    )(x)

    model = tf.keras.Model(inputs=inputs, outputs=outputs)

    learning_rate = hp.Choice('learning_rate', values=[1e-3, 1e-4, 1e-5])
    weight_decay = hp.Choice('weight_decay', values=[1e-2, 1e-3, 1e-4])
    optimizer_choice = hp.Choice('optimizer', values=['adamw', 'sgd'])

    if optimizer_choice == 'adamw':
        optimizer = tf.keras.optimizers.AdamW(learning_rate=learning_rate, weight_decay=weight_decay)
    else:
        momentum = hp.Choice('momentum', values=[0.8, 0.9, 0.99])
        optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=momentum, weight_decay=weight_decay)

    model.compile(
        optimizer=optimizer,
        loss=focal_loss(gamma=hp.Choice('gamma', values=[0.5, 1.0, 2.0]), alpha=hp.Choice('alpha', values=[0.25, 0.5, 0.75])),
        metrics=[
            tf.keras.metrics.AUC(name='auc', multi_label=False),
            'accuracy'
        ]
    )

    return model

# %%
from sklearn.utils import class_weight
import numpy as np


class_weights = class_weight.compute_class_weight(
    'balanced',
    classes=np.unique(train_labels),
    y=train_labels
)

class_weights_dict = dict(enumerate(class_weights))

# %%
import keras_tuner as kt

from tensorflow.keras.callbacks import EarlyStopping


early_stopping = EarlyStopping(monitor='val_auc', patience=10, restore_best_weights=True)


# Create a tuner
tuner = kt.Hyperband(
    build_resnet50_with_se,
    objective='val_auc',
    max_epochs=50,
    factor=3,
    directory='se_block_residual_3',
    project_name='hyperparameter_tuning'
)

# Perform the search
tuner.search(
  train_dataset,
  validation_data=val_dataset,
  epochs=50,
  class_weight=class_weights_dict,
  callbacks=[early_stopping]
)

# Get the best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"Best Hyperparameters: {best_hps.values}")

# Build the model with the best hyperparameters
model = tuner.hypermodel.build(best_hps)
# Out:
# Trial 88 Complete [00h 12m 17s]
# val_auc: 0.9189573526382446
#
# Best val_auc So Far: 0.975376307964325
# Total elapsed time: 04h 07m 16s
# Best Hyperparameters: {'reduction_ratio': 8, 'l2_regularization': 0.0001, 'dropout_rate': 0.5, 'l2_regularization_output': 0.001, 'learning_rate': 0.0001, 'weight_decay': 0.001, 'optimizer': 'adamw', 'gamma': 2.0, 'alpha': 0.75, 'tuner/epochs': 50, 'tuner/initial_epoch': 17, 'tuner/bracket': 2, 'tuner/round': 2, 'tuner/trial_id': '0068'}

# %%
import numpy as np


callbacks = [
    keras.callbacks.EarlyStopping(
        monitor='val_auc',
        patience=12,
        min_delta=1e-4,
        restore_best_weights=True,
        mode='max'
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_auc',
        factor=0.1,
        patience=4,
        min_lr=1e-7,
        mode='max'
    ),
    keras.callbacks.ModelCheckpoint(
        filepath='best_models/resnet50-seblock-residual.keras',
        monitor='val_auc',
        save_best_only=True,
        save_weights_only=False,
        mode='max',
        verbose=1
    )
]

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=500,
    callbacks=callbacks,
    class_weight=class_weights_dict,
)
# Out:
# Epoch 1/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 32s 86ms/step - accuracy: 0.2683 - auc_2: 0.6413 - loss: 1.6756 - val_accuracy: 0.5312 - val_auc_2: 0.8535 - val_loss: 1.0784 - learning_rate: 1.0000e-04
# Epoch 2/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.4950 - auc_2: 0.8244 - loss: 1.1399 - val_accuracy: 0.6046 - val_auc_2: 0.8936 - val_loss: 0.9369 - learning_rate: 1.0000e-04
# Epoch 3/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.5432 - auc_2: 0.8617 - loss: 0.9955 - val_accuracy: 0.6525 - val_auc_2: 0.9164 - val_loss: 0.8423 - learning_rate: 1.0000e-04
# Epoch 4/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.6004 - auc_2: 0.8913 - loss: 0.8951 - val_accuracy: 0.6715 - val_auc_2: 0.9244 - val_loss: 0.7946 - learning_rate: 1.0000e-04
# Epoch 5/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.6039 - auc_2: 0.8979 - loss: 0.8416 - val_accuracy: 0.6800 - val_auc_2: 0.9278 - val_loss: 0.7670 - learning_rate: 1.0000e-04
# Epoch 6/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.6390 - auc_2: 0.9162 - loss: 0.7632 - val_accuracy: 0.7079 - val_auc_2: 0.9389 - val_loss: 0.7153 - learning_rate: 1.0000e-04
# Epoch 7/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.6481 - auc_2: 0.9235 - loss: 0.7312 - val_accuracy: 0.7034 - val_auc_2: 0.9424 - val_loss: 0.6897 - learning_rate: 1.0000e-04
# Epoch 8/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.6602 - auc_2: 0.9282 - loss: 0.6873 - val_accuracy: 0.7134 - val_auc_2: 0.9437 - val_loss: 0.6724 - learning_rate: 1.0000e-04
# Epoch 9/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.6689 - auc_2: 0.9336 - loss: 0.6566 - val_accuracy: 0.7274 - val_auc_2: 0.9490 - val_loss: 0.6419 - learning_rate: 1.0000e-04
# Epoch 10/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.7010 - auc_2: 0.9418 - loss: 0.6080 - val_accuracy: 0.7154 - val_auc_2: 0.9468 - val_loss: 0.6399 - learning_rate: 1.0000e-04
# Epoch 11/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.6899 - auc_2: 0.9423 - loss: 0.5938 - val_accuracy: 0.7209 - val_auc_2: 0.9493 - val_loss: 0.6219 - learning_rate: 1.0000e-04
# Epoch 12/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.7150 - auc_2: 0.9498 - loss: 0.5574 - val_accuracy: 0.7324 - val_auc_2: 0.9564 - val_loss: 0.5844 - learning_rate: 1.0000e-04
# Epoch 13/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.7219 - auc_2: 0.9519 - loss: 0.5442 - val_accuracy: 0.7404 - val_auc_2: 0.9571 - val_loss: 0.5770 - learning_rate: 1.0000e-04
# Epoch 14/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.7354 - auc_2: 0.9568 - loss: 0.5145 - val_accuracy: 0.7449 - val_auc_2: 0.9575 - val_loss: 0.5657 - learning_rate: 1.0000e-04
# Epoch 15/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.7385 - auc_2: 0.9577 - loss: 0.4986 - val_accuracy: 0.7459 - val_auc_2: 0.9586 - val_loss: 0.5511 - learning_rate: 1.0000e-04
# Epoch 16/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.7435 - auc_2: 0.9602 - loss: 0.4866 - val_accuracy: 0.7484 - val_auc_2: 0.9592 - val_loss: 0.5459 - learning_rate: 1.0000e-04
# Epoch 17/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.7624 - auc_2: 0.9629 - loss: 0.4619 - val_accuracy: 0.7399 - val_auc_2: 0.9572 - val_loss: 0.5470 - learning_rate: 1.0000e-04
# Epoch 18/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.7597 - auc_2: 0.9641 - loss: 0.4477 - val_accuracy: 0.7688 - val_auc_2: 0.9637 - val_loss: 0.5143 - learning_rate: 1.0000e-04
# Epoch 19/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.7720 - auc_2: 0.9664 - loss: 0.4260 - val_accuracy: 0.7634 - val_auc_2: 0.9636 - val_loss: 0.5090 - learning_rate: 1.0000e-04
# Epoch 20/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.7782 - auc_2: 0.9692 - loss: 0.4102 - val_accuracy: 0.7654 - val_auc_2: 0.9632 - val_loss: 0.5040 - learning_rate: 1.0000e-04
# Epoch 21/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.7826 - auc_2: 0.9703 - loss: 0.3972 - val_accuracy: 0.7629 - val_auc_2: 0.9627 - val_loss: 0.5005 - learning_rate: 1.0000e-04
# Epoch 22/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.7925 - auc_2: 0.9715 - loss: 0.3859 - val_accuracy: 0.7728 - val_auc_2: 0.9670 - val_loss: 0.4774 - learning_rate: 1.0000e-04
# Epoch 23/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8019 - auc_2: 0.9739 - loss: 0.3773 - val_accuracy: 0.7838 - val_auc_2: 0.9691 - val_loss: 0.4636 - learning_rate: 1.0000e-04
# Epoch 24/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8012 - auc_2: 0.9744 - loss: 0.3726 - val_accuracy: 0.7783 - val_auc_2: 0.9664 - val_loss: 0.4684 - learning_rate: 1.0000e-04
# Epoch 25/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8061 - auc_2: 0.9762 - loss: 0.3585 - val_accuracy: 0.7743 - val_auc_2: 0.9659 - val_loss: 0.4701 - learning_rate: 1.0000e-04
# Epoch 26/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8109 - auc_2: 0.9767 - loss: 0.3449 - val_accuracy: 0.7908 - val_auc_2: 0.9698 - val_loss: 0.4448 - learning_rate: 1.0000e-04
# Epoch 27/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8180 - auc_2: 0.9784 - loss: 0.3374 - val_accuracy: 0.7903 - val_auc_2: 0.9703 - val_loss: 0.4400 - learning_rate: 1.0000e-04
# Epoch 28/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8210 - auc_2: 0.9805 - loss: 0.3226 - val_accuracy: 0.7818 - val_auc_2: 0.9693 - val_loss: 0.4397 - learning_rate: 1.0000e-04
# Epoch 29/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8289 - auc_2: 0.9813 - loss: 0.3105 - val_accuracy: 0.8078 - val_auc_2: 0.9735 - val_loss: 0.4174 - learning_rate: 1.0000e-04
# Epoch 30/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8297 - auc_2: 0.9823 - loss: 0.3054 - val_accuracy: 0.7853 - val_auc_2: 0.9688 - val_loss: 0.4317 - learning_rate: 1.0000e-04
# Epoch 31/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8465 - auc_2: 0.9825 - loss: 0.2926 - val_accuracy: 0.7868 - val_auc_2: 0.9697 - val_loss: 0.4275 - learning_rate: 1.0000e-04
# Epoch 32/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8352 - auc_2: 0.9824 - loss: 0.2950 - val_accuracy: 0.7953 - val_auc_2: 0.9719 - val_loss: 0.4119 - learning_rate: 1.0000e-04
# Epoch 33/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8488 - auc_2: 0.9843 - loss: 0.2823 - val_accuracy: 0.7848 - val_auc_2: 0.9706 - val_loss: 0.4176 - learning_rate: 1.0000e-04
# Epoch 34/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8423 - auc_2: 0.9844 - loss: 0.2774 - val_accuracy: 0.7948 - val_auc_2: 0.9722 - val_loss: 0.4057 - learning_rate: 1.0000e-04
# Epoch 35/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8524 - auc_2: 0.9850 - loss: 0.2664 - val_accuracy: 0.7958 - val_auc_2: 0.9731 - val_loss: 0.3974 - learning_rate: 1.0000e-04
# Epoch 36/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8573 - auc_2: 0.9874 - loss: 0.2559 - val_accuracy: 0.7943 - val_auc_2: 0.9712 - val_loss: 0.4028 - learning_rate: 1.0000e-04
# Epoch 37/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8492 - auc_2: 0.9861 - loss: 0.2612 - val_accuracy: 0.7963 - val_auc_2: 0.9727 - val_loss: 0.3929 - learning_rate: 1.0000e-04
# Epoch 38/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8639 - auc_2: 0.9871 - loss: 0.2491 - val_accuracy: 0.8123 - val_auc_2: 0.9760 - val_loss: 0.3739 - learning_rate: 1.0000e-04
# Epoch 39/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8711 - auc_2: 0.9887 - loss: 0.2422 - val_accuracy: 0.8073 - val_auc_2: 0.9742 - val_loss: 0.3806 - learning_rate: 1.0000e-04
# Epoch 40/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8731 - auc_2: 0.9893 - loss: 0.2325 - val_accuracy: 0.8093 - val_auc_2: 0.9741 - val_loss: 0.3772 - learning_rate: 1.0000e-04
# Epoch 41/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8653 - auc_2: 0.9882 - loss: 0.2335 - val_accuracy: 0.8073 - val_auc_2: 0.9739 - val_loss: 0.3760 - learning_rate: 1.0000e-04
# Epoch 42/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8704 - auc_2: 0.9893 - loss: 0.2292 - val_accuracy: 0.8028 - val_auc_2: 0.9725 - val_loss: 0.3814 - learning_rate: 1.0000e-04
# Epoch 43/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8918 - auc_2: 0.9912 - loss: 0.2141 - val_accuracy: 0.8118 - val_auc_2: 0.9754 - val_loss: 0.3636 - learning_rate: 1.0000e-05
# Epoch 44/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8869 - auc_2: 0.9914 - loss: 0.2129 - val_accuracy: 0.8123 - val_auc_2: 0.9758 - val_loss: 0.3615 - learning_rate: 1.0000e-05
# Epoch 45/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8905 - auc_2: 0.9914 - loss: 0.2110 - val_accuracy: 0.8113 - val_auc_2: 0.9758 - val_loss: 0.3611 - learning_rate: 1.0000e-05
# Epoch 46/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8926 - auc_2: 0.9923 - loss: 0.2100 - val_accuracy: 0.8098 - val_auc_2: 0.9755 - val_loss: 0.3630 - learning_rate: 1.0000e-05
# Epoch 47/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8837 - auc_2: 0.9914 - loss: 0.2096 - val_accuracy: 0.8118 - val_auc_2: 0.9763 - val_loss: 0.3592 - learning_rate: 1.0000e-05
# Epoch 48/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8908 - auc_2: 0.9921 - loss: 0.2098 - val_accuracy: 0.8143 - val_auc_2: 0.9766 - val_loss: 0.3568 - learning_rate: 1.0000e-05
# Epoch 49/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8912 - auc_2: 0.9921 - loss: 0.2098 - val_accuracy: 0.8123 - val_auc_2: 0.9760 - val_loss: 0.3589 - learning_rate: 1.0000e-05
# Epoch 50/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8973 - auc_2: 0.9920 - loss: 0.2062 - val_accuracy: 0.8113 - val_auc_2: 0.9765 - val_loss: 0.3562 - learning_rate: 1.0000e-05
# Epoch 51/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8951 - auc_2: 0.9927 - loss: 0.2049 - val_accuracy: 0.8148 - val_auc_2: 0.9763 - val_loss: 0.3576 - learning_rate: 1.0000e-05
# Epoch 52/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8945 - auc_2: 0.9922 - loss: 0.2064 - val_accuracy: 0.8168 - val_auc_2: 0.9765 - val_loss: 0.3556 - learning_rate: 1.0000e-05
# Epoch 53/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9031 - auc_2: 0.9925 - loss: 0.2044 - val_accuracy: 0.8138 - val_auc_2: 0.9766 - val_loss: 0.3549 - learning_rate: 1.0000e-05
# Epoch 54/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8967 - auc_2: 0.9924 - loss: 0.2039 - val_accuracy: 0.8128 - val_auc_2: 0.9761 - val_loss: 0.3565 - learning_rate: 1.0000e-05
# Epoch 55/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8981 - auc_2: 0.9925 - loss: 0.2024 - val_accuracy: 0.8178 - val_auc_2: 0.9768 - val_loss: 0.3528 - learning_rate: 1.0000e-05
# Epoch 56/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8968 - auc_2: 0.9927 - loss: 0.2025 - val_accuracy: 0.8123 - val_auc_2: 0.9759 - val_loss: 0.3563 - learning_rate: 1.0000e-05
# Epoch 57/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8955 - auc_2: 0.9928 - loss: 0.2010 - val_accuracy: 0.8148 - val_auc_2: 0.9767 - val_loss: 0.3525 - learning_rate: 1.0000e-05
# Epoch 58/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9052 - auc_2: 0.9932 - loss: 0.1982 - val_accuracy: 0.8153 - val_auc_2: 0.9763 - val_loss: 0.3544 - learning_rate: 1.0000e-05
# Epoch 59/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8988 - auc_2: 0.9929 - loss: 0.1998 - val_accuracy: 0.8123 - val_auc_2: 0.9764 - val_loss: 0.3526 - learning_rate: 1.0000e-05
# Epoch 60/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8975 - auc_2: 0.9927 - loss: 0.1980 - val_accuracy: 0.8143 - val_auc_2: 0.9766 - val_loss: 0.3511 - learning_rate: 1.0000e-05
# Epoch 61/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9015 - auc_2: 0.9930 - loss: 0.1992 - val_accuracy: 0.8143 - val_auc_2: 0.9759 - val_loss: 0.3545 - learning_rate: 1.0000e-05
# Epoch 62/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8986 - auc_2: 0.9931 - loss: 0.1964 - val_accuracy: 0.8128 - val_auc_2: 0.9766 - val_loss: 0.3499 - learning_rate: 1.0000e-05
# Epoch 63/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8987 - auc_2: 0.9930 - loss: 0.1961 - val_accuracy: 0.8118 - val_auc_2: 0.9768 - val_loss: 0.3492 - learning_rate: 1.0000e-05
# Epoch 64/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8961 - auc_2: 0.9929 - loss: 0.1968 - val_accuracy: 0.8193 - val_auc_2: 0.9772 - val_loss: 0.3462 - learning_rate: 1.0000e-05
# Epoch 65/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9050 - auc_2: 0.9937 - loss: 0.1935 - val_accuracy: 0.8103 - val_auc_2: 0.9758 - val_loss: 0.3528 - learning_rate: 1.0000e-05
# Epoch 66/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9019 - auc_2: 0.9930 - loss: 0.1933 - val_accuracy: 0.8118 - val_auc_2: 0.9764 - val_loss: 0.3496 - learning_rate: 1.0000e-05
# Epoch 67/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8940 - auc_2: 0.9935 - loss: 0.1926 - val_accuracy: 0.8108 - val_auc_2: 0.9765 - val_loss: 0.3484 - learning_rate: 1.0000e-05
# Epoch 68/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8964 - auc_2: 0.9929 - loss: 0.1933 - val_accuracy: 0.8128 - val_auc_2: 0.9764 - val_loss: 0.3478 - learning_rate: 1.0000e-05
# Epoch 69/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9016 - auc_2: 0.9931 - loss: 0.1910 - val_accuracy: 0.8148 - val_auc_2: 0.9767 - val_loss: 0.3469 - learning_rate: 1.0000e-06
# Epoch 70/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8982 - auc_2: 0.9927 - loss: 0.1961 - val_accuracy: 0.8128 - val_auc_2: 0.9767 - val_loss: 0.3463 - learning_rate: 1.0000e-06
# Epoch 71/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9055 - auc_2: 0.9935 - loss: 0.1924 - val_accuracy: 0.8138 - val_auc_2: 0.9768 - val_loss: 0.3461 - learning_rate: 1.0000e-06
# Epoch 72/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9000 - auc_2: 0.9931 - loss: 0.1915 - val_accuracy: 0.8133 - val_auc_2: 0.9770 - val_loss: 0.3454 - learning_rate: 1.0000e-06
# Epoch 73/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9083 - auc_2: 0.9937 - loss: 0.1913 - val_accuracy: 0.8138 - val_auc_2: 0.9771 - val_loss: 0.3448 - learning_rate: 1.0000e-06
# Epoch 74/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8996 - auc_2: 0.9937 - loss: 0.1908 - val_accuracy: 0.8123 - val_auc_2: 0.9769 - val_loss: 0.3452 - learning_rate: 1.0000e-06
# Epoch 75/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8981 - auc_2: 0.9932 - loss: 0.1925 - val_accuracy: 0.8148 - val_auc_2: 0.9769 - val_loss: 0.3452 - learning_rate: 1.0000e-06
# Epoch 76/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8993 - auc_2: 0.9933 - loss: 0.1924 - val_accuracy: 0.8148 - val_auc_2: 0.9772 - val_loss: 0.3446 - learning_rate: 1.0000e-06
# Epoch 77/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9043 - auc_2: 0.9936 - loss: 0.1896 - val_accuracy: 0.8143 - val_auc_2: 0.9773 - val_loss: 0.3442 - learning_rate: 1.0000e-06
# Epoch 78/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9050 - auc_2: 0.9935 - loss: 0.1912 - val_accuracy: 0.8143 - val_auc_2: 0.9769 - val_loss: 0.3449 - learning_rate: 1.0000e-06
# Epoch 79/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9025 - auc_2: 0.9936 - loss: 0.1895 - val_accuracy: 0.8153 - val_auc_2: 0.9771 - val_loss: 0.3441 - learning_rate: 1.0000e-06
# Epoch 80/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9016 - auc_2: 0.9938 - loss: 0.1910 - val_accuracy: 0.8138 - val_auc_2: 0.9771 - val_loss: 0.3441 - learning_rate: 1.0000e-06
# Epoch 81/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9044 - auc_2: 0.9938 - loss: 0.1898 - val_accuracy: 0.8138 - val_auc_2: 0.9772 - val_loss: 0.3436 - learning_rate: 1.0000e-06
# Epoch 82/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9033 - auc_2: 0.9937 - loss: 0.1920 - val_accuracy: 0.8153 - val_auc_2: 0.9771 - val_loss: 0.3439 - learning_rate: 1.0000e-06
# Epoch 83/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9094 - auc_2: 0.9939 - loss: 0.1887 - val_accuracy: 0.8143 - val_auc_2: 0.9771 - val_loss: 0.3438 - learning_rate: 1.0000e-06
# Epoch 84/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9087 - auc_2: 0.9939 - loss: 0.1896 - val_accuracy: 0.8138 - val_auc_2: 0.9771 - val_loss: 0.3440 - learning_rate: 1.0000e-06
# Epoch 85/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9060 - auc_2: 0.9939 - loss: 0.1897 - val_accuracy: 0.8153 - val_auc_2: 0.9773 - val_loss: 0.3432 - learning_rate: 1.0000e-06
# Epoch 86/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9058 - auc_2: 0.9935 - loss: 0.1904 - val_accuracy: 0.8158 - val_auc_2: 0.9772 - val_loss: 0.3435 - learning_rate: 1.0000e-06
# Epoch 87/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9054 - auc_2: 0.9942 - loss: 0.1901 - val_accuracy: 0.8133 - val_auc_2: 0.9772 - val_loss: 0.3438 - learning_rate: 1.0000e-06
# Epoch 88/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9046 - auc_2: 0.9937 - loss: 0.1907 - val_accuracy: 0.8123 - val_auc_2: 0.9770 - val_loss: 0.3443 - learning_rate: 1.0000e-06
# Epoch 89/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9022 - auc_2: 0.9935 - loss: 0.1892 - val_accuracy: 0.8158 - val_auc_2: 0.9773 - val_loss: 0.3437 - learning_rate: 1.0000e-06
# Epoch 90/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9073 - auc_2: 0.9938 - loss: 0.1928 - val_accuracy: 0.8163 - val_auc_2: 0.9773 - val_loss: 0.3437 - learning_rate: 1.0000e-07
# Epoch 91/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9055 - auc_2: 0.9936 - loss: 0.1911 - val_accuracy: 0.8148 - val_auc_2: 0.9772 - val_loss: 0.3437 - learning_rate: 1.0000e-07
# Epoch 92/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9045 - auc_2: 0.9940 - loss: 0.1891 - val_accuracy: 0.8158 - val_auc_2: 0.9772 - val_loss: 0.3436 - learning_rate: 1.0000e-07
# Epoch 93/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9022 - auc_2: 0.9934 - loss: 0.1887 - val_accuracy: 0.8153 - val_auc_2: 0.9772 - val_loss: 0.3436 - learning_rate: 1.0000e-07
# Epoch 94/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9116 - auc_2: 0.9941 - loss: 0.1900 - val_accuracy: 0.8148 - val_auc_2: 0.9771 - val_loss: 0.3437 - learning_rate: 1.0000e-07
# Epoch 95/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9070 - auc_2: 0.9936 - loss: 0.1912 - val_accuracy: 0.8148 - val_auc_2: 0.9772 - val_loss: 0.3436 - learning_rate: 1.0000e-07
# Epoch 96/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9029 - auc_2: 0.9939 - loss: 0.1885 - val_accuracy: 0.8143 - val_auc_2: 0.9772 - val_loss: 0.3436 - learning_rate: 1.0000e-07
# Epoch 97/500
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9030 - auc_2: 0.9937 - loss: 0.1902 - val_accuracy: 0.8143 - val_auc_2: 0.9772 - val_loss: 0.3436 - learning_rate: 1.0000e-07

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf

y_true = []
y_pred = []

def get_predictions(dataset):
    for images, labels in dataset:
        predictions = model.predict(images)
        y_true.extend(labels.numpy())
        y_pred.extend(np.argmax(predictions, axis=1))
    return np.array(y_true), np.array(y_pred)

# Get predictions for validation dataset
y_true, y_pred = get_predictions(val_dataset)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step

# %%
# Classification Report

y_true = np.argmax(y_true, axis=1) if y_true.ndim > 1 else y_true
y_pred = np.argmax(y_pred, axis=1) if y_pred.ndim > 1 else y_pred

print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=classes))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        akiec       0.59      0.68      0.63        65
#          bcc       0.66      0.69      0.68       103
#          bkl       0.64      0.70      0.67       220
#           df       0.57      0.52      0.55        23
#          mel       0.54      0.68      0.60       223
#           nv       0.94      0.88      0.91      1341
#         vasc       0.77      0.71      0.74        28
#
#     accuracy                           0.82      2003
#    macro avg       0.67      0.69      0.68      2003
# weighted avg       0.83      0.82      0.82      2003

# %%
# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=classes, yticklabels=classes)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# Per-class Accuracy Plot
class_accuracies = cm.diagonal() / cm.sum(axis=1)
plt.figure(figsize=(10, 6))
sns.barplot(x=classes, y=class_accuracies)
plt.title('Per-class Accuracy')
plt.xlabel('Class')
plt.ylabel('Accuracy')
plt.xticks(rotation=45)
plt.show()
