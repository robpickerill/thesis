# %%
import os
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Layer, Reshape, Multiply, Conv2D, BatchNormalization, Activation, Add, Input, ZeroPadding2D, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import glorot_uniform
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.utils import register_keras_serializable


os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

tf.keras.mixed_precision.set_global_policy('mixed_float16')

# %%
base = '/Users/robp/scm/personal/github.com/robpickerill/thesis'
csv_file = os.path.join(base, 'ham10000_data/HAM10000_metadata.csv')
img_dir = os.path.join(base, 'ham10000_data/images')
file_ext = '.jpg'

df = pd.read_csv(csv_file)
df['image_path'] = df['image_id'].apply(lambda x: os.path.join(img_dir, x + file_ext))

print(df.head())
print(f"Total samples in dataset: {len(df)}")
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#                                           image_path
# 0  /Users/robp/scm/personal/github.com/robpickeri...
# 1  /Users/robp/scm/personal/github.com/robpickeri...
# 2  /Users/robp/scm/personal/github.com/robpickeri...
# 3  /Users/robp/scm/personal/github.com/robpickeri...
# 4  /Users/robp/scm/personal/github.com/robpickeri...
# Total samples in dataset: 10015

# %%
import tensorflow as tf
from tensorflow.keras import layers

class SEBlock(layers.Layer):
    """
    Squeeze-and-Excitation (SE) Block

    The SE block recalibrates channel-wise feature responses by explicitly modeling
    interdependencies between channels. Given an input feature map of shape
    (batch, height, width, channels), it:

    1. Squeezes global spatial information into a channel descriptor by using
       global average pooling.
    2. Excites each channel by passing this descriptor through a fully-connected
       bottleneck and expanding transformation, utilizing a sigmoid activation
       to generate channel-wise weights.
    3. Scales the original feature map by these learned weights,
       reinforcing channels that are relevant and suppressing those that are not.

    Parameters
    ----------
    reduction_ratio : int, optional (default=16)
        The reduction ratio used to compute the size of the bottleneck layer.
        For an input with `C` channels, the bottleneck layer will have
        `C // reduction_ratio` channels.

    name : str, optional
        String name for the layer.

    Attributes
    ----------
    fc1 : Dense layer
        The first fully connected layer that reduces the channel dimension.
    fc2 : Dense layer
        The second fully connected layer that expands back to the original channel dimension.
    """
    def __init__(self, reduction_ratio=16, name=None, **kwargs):
        super(SEBlock, self).__init__(name=name, **kwargs)
        self.reduction_ratio = reduction_ratio

    def build(self, input_shape):
        """
        Build the internal layers of the SE block. This method is called
        automatically once the shape of the inputs is known.

        Parameters
        ----------
        input_shape : TensorShape
            The shape of the input tensor. Typically (batch, height, width, channels).
        """
        if len(input_shape) != 4:
            raise ValueError("SEBlock only supports inputs with shape (batch, height, width, channels).")

        channels = input_shape[-1]
        reduced_channels = max(channels // self.reduction_ratio, 1)

        # First FC layer for reduction (C -> C//r)
        self.fc1 = layers.Dense(units=reduced_channels,
                                activation='relu',  # Non-linear activation
                                use_bias=True,
                                name='se_fc1')

        # Second FC layer to restore original dimension (C//r -> C)
        self.fc2 = layers.Dense(units=channels,
                                activation='sigmoid',  # Outputs channel-wise gating weights
                                use_bias=True,
                                name='se_fc2')

        super(SEBlock, self).build(input_shape)

    def call(self, inputs, training=False):
        """
        Forward pass of the SE block.

        Steps:
        1. Global average pooling to get channel-wise statistics of shape (batch, channels).
        2. Pass through the first FC layer (reduction).
        3. Pass through the second FC layer (expansion) with sigmoid activation to get weights.
        4. Reshape weights to (batch, 1, 1, channels) to match the input shape.
        5. Multiply the original inputs by these weights (channel-wise scaling).

        Parameters
        ----------
        inputs : tf.Tensor
            The input tensor with shape (batch, height, width, channels).

        training : bool, optional
            Specifies if the layer should behave in training mode or inference mode.
            This parameter can be used by certain layers that behave differently
            during training and inference.

        Returns
        -------
        tf.Tensor
            The output tensor with the same shape as `inputs`, after channel-wise rescaling.
        """
        # Step 1: Squeeze
        # Global average pooling: (batch, H, W, C) -> (batch, C)
        squeeze_tensor = tf.reduce_mean(inputs, axis=[1, 2], keepdims=False)

        # Step 2 & 3: Excitation
        # FC reduce: (batch, C) -> (batch, C//r)
        reduced = self.fc1(squeeze_tensor, training=training)
        # FC expand: (batch, C//r) -> (batch, C)
        excitation = self.fc2(reduced, training=training)

        # Reshape excitation to (batch, 1, 1, C) for broadcasting
        excitation = tf.reshape(excitation, [-1, 1, 1, tf.shape(inputs)[-1]])

        # Step 4: Scale
        # Scale input by the learned weights: (batch, H, W, C)
        scaled_inputs = inputs * excitation
        return scaled_inputs

    def compute_output_shape(self, input_shape):
        """
        Compute the output shape of the SE block. It remains the same as the input shape.

        Parameters
        ----------
        input_shape : Tuple[int]
            Shape of the input tensor.

        Returns
        -------
        Tuple[int]
            The output shape, identical to the input shape.
        """
        return input_shape

    def get_config(self):
        """
        Returns the configuration of the layer. This enables the layer
        to be serialized and deserialized, for example, when saving and loading models.

        Returns
        -------
        dict
            A dictionary containing the layer configuration.
        """
        config = super(SEBlock, self).get_config()
        config.update({
            'reduction_ratio': self.reduction_ratio
        })
        return config

# %%
def identity_block(input_tensor, kernel_size, filters, stage, block):
    bn_axis = 3
    filters1, filters2, filters3 = filters
    conv_name_base = f'conv{stage}_block{block}_'

    x = Conv2D(filters1, (1, 1),
               use_bias=True,
               kernel_initializer='he_normal',
               name=conv_name_base + '1_conv')(input_tensor)
    x = BatchNormalization(axis=bn_axis, epsilon=1.001e-5, name=conv_name_base + '1_bn')(x)
    x = Activation('relu', name=conv_name_base + '1_relu')(x)

    x = Conv2D(filters2, kernel_size,
               padding='same',
               use_bias=True,
               kernel_initializer='he_normal',
               name=conv_name_base + '2_conv')(x)
    x = BatchNormalization(axis=bn_axis, epsilon=1.001e-5, name=conv_name_base + '2_bn')(x)
    x = Activation('relu', name=conv_name_base + '2_relu')(x)

    x = Conv2D(filters3, (1, 1),
               use_bias=True,
               kernel_initializer='he_normal',
               name=conv_name_base + '3_conv')(x)
    x = BatchNormalization(axis=bn_axis, epsilon=1.001e-5, name=conv_name_base + '3_bn')(x)

    x = Add(name=conv_name_base + 'add')([x, input_tensor])
    x = Activation('relu', name=conv_name_base + 'out')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, stage, block, strides=(2, 2)):
    bn_axis = 3
    filters1, filters2, filters3 = filters
    conv_name_base = f'conv{stage}_block{block}_'

    x = Conv2D(filters1, (1, 1), strides=strides,
               use_bias=True,
               kernel_initializer='he_normal',
               name=conv_name_base + '1_conv')(input_tensor)
    x = BatchNormalization(axis=bn_axis, epsilon=1.001e-5, name=conv_name_base + '1_bn')(x)
    x = Activation('relu', name=conv_name_base + '1_relu')(x)

    x = Conv2D(filters2, kernel_size, padding='same',
               use_bias=True,
               kernel_initializer='he_normal',
               name=conv_name_base + '2_conv')(x)
    x = BatchNormalization(axis=bn_axis, epsilon=1.001e-5, name=conv_name_base + '2_bn')(x)
    x = Activation('relu', name=conv_name_base + '2_relu')(x)

    x = Conv2D(filters3, (1, 1),
               use_bias=True,
               kernel_initializer='he_normal',
               name=conv_name_base + '3_conv')(x)
    x = BatchNormalization(axis=bn_axis, epsilon=1.001e-5, name=conv_name_base + '3_bn')(x)

    shortcut = Conv2D(filters3, (1, 1), strides=strides,
                      use_bias=True,
                      kernel_initializer='he_normal',
                      name=conv_name_base + '0_conv')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, epsilon=1.001e-5, name=conv_name_base + '0_bn')(shortcut)

    x = Add(name=conv_name_base + 'add')([x, shortcut])
    x = Activation('relu', name=conv_name_base + 'out')(x)
    return x

def build_resnet50(input_shape, num_classes):
    inputs = Input(shape=input_shape, name='input_1')
    bn_axis = 3  # channels_last

    # Stage 1
    x = ZeroPadding2D(padding=(3, 3), name='conv1_pad')(inputs)
    x = Conv2D(64, (7, 7), strides=(2, 2),
               padding='valid', use_bias=True,
               kernel_initializer='he_normal',
               name='conv1_conv')(x)
    x = BatchNormalization(axis=bn_axis, epsilon=1.001e-5, name='conv1_bn')(x)
    x = Activation('relu', name='conv1_relu')(x)
    x = ZeroPadding2D(padding=(1, 1), name='pool1_pad')(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), name='pool1_pool')(x)

    # Stage 2
    x = conv_block(x, 3, [64, 64, 256], stage=2, block=1, strides=(1, 1))
    x = identity_block(x, 3, [64, 64, 256], stage=2, block=2)
    x = identity_block(x, 3, [64, 64, 256], stage=2, block=3)

    # Stage 3
    x = conv_block(x, 3, [128, 128, 512], stage=3, block=1)
    x = identity_block(x, 3, [128, 128, 512], stage=3, block=2)
    x = identity_block(x, 3, [128, 128, 512], stage=3, block=3)
    x = identity_block(x, 3, [128, 128, 512], stage=3, block=4)

    # Stage 4
    x = conv_block(x, 3, [256, 256, 1024], stage=4, block=1)
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block=2)
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block=3)
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block=4)
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block=5)
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block=6)

    # Stage 5
    x = conv_block(x, 3, [512, 512, 2048], stage=5, block=1)
    x = identity_block(x, 3, [512, 512, 2048], stage=5, block=2)
    x = identity_block(x, 3, [512, 512, 2048], stage=5, block=3)

    # CBAM
    x = SEBlock()(x)

    # Global Pooling & Classifier
    x = GlobalAveragePooling2D(name='avg_pool')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax', name='predictions')(x)

    model = Model(inputs, outputs, name='resnet50')
    return model

def transfer_weights(base_model, target_model):
    """
    Transfer weights from a Keras ResNet50 base_model into the custom ResNet50
    architecture whenever layer names match.
    """
    for layer in target_model.layers:
        try:
            pretrained_layer = base_model.get_layer(layer.name)
            layer.set_weights(pretrained_layer.get_weights())
        except Exception:
            # If layer doesn't exist in pretrained base, skip
            pass

# %%
def focal_loss(alpha=0.25, gamma=2.0):
    def focal_loss_fixed(y_true, y_pred):
        y_pred = tf.clip_by_value(y_pred, tf.keras.backend.epsilon(), 1. - tf.keras.backend.epsilon())
        cross_entropy = -y_true * tf.math.log(y_pred)
        weights = alpha * y_true * tf.math.pow((1 - y_pred), gamma)
        return tf.reduce_mean(tf.reduce_sum(weights * cross_entropy, axis=-1))
    return focal_loss_fixed

# %%
k_folds = 5
skf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=42)

# For tracking the best fold, to later evaluate performance
best_fold = None
best_auc_across_folds = 0.0

# For collecting metrics across folds
fold_accuracies = []
fold_aucs = []
fold_losses = []

# Epochs for each phase
EPOCHS_PHASE1 = 20   # Freeze the backbone
EPOCHS_PHASE2 = 200  # Fine-tuning

IMG_SIZE = 224
BATCH_SIZE = 32
NUM_CLASSES = 7

base_resnet50 = ResNet50(weights='imagenet', include_top=False, pooling=None)

# Data augmentation
datagen_train = ImageDataGenerator(
    rescale=1.0/255.0,
    rotation_range=5,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    brightness_range=[0.9, 1.1],
    horizontal_flip=True,
    fill_mode='nearest'
)
datagen_val = ImageDataGenerator(rescale=1.0/255.0)

# Get unique class labels (strings)
all_class_labels = sorted(df['dx'].unique())

# Compute global class weights for the entire dataset
class_weights_array = compute_class_weight(
    class_weight='balanced',
    classes=np.array(all_class_labels),
    y=df['dx'].values
)
# Map to dictionary: {class_index: weight}
class_weights_dict = {}
for label, w in zip(all_class_labels, class_weights_array):
    # Index of this label in the alphabetical-sorted list
    idx = all_class_labels.index(label)
    class_weights_dict[idx] = w
print("Class weights dict:", class_weights_dict)

fold_index = 1
for train_idx, val_idx in skf.split(df, df['dx']):
    print(f"\n\n===== FOLD {fold_index}/{k_folds} =====")

    # ------------------------------------------------------
    # 4.1) CREATE DATAFRAMES FOR THIS FOLD
    # ------------------------------------------------------
    train_df = df.iloc[train_idx].reset_index(drop=True)
    val_df = df.iloc[val_idx].reset_index(drop=True)

    print("Train size:", len(train_df), "Val size:", len(val_df))
    print("Train distribution:\n", train_df['dx'].value_counts())
    print("Val distribution:\n", val_df['dx'].value_counts())

    # ------------------------------------------------------
    # 4.2) FLOW FROM DATAFRAME: TRAIN & VAL
    # ------------------------------------------------------
    train_generator = datagen_train.flow_from_dataframe(
        dataframe=train_df,
        x_col='image_path',
        y_col='dx',
        target_size=(IMG_SIZE, IMG_SIZE),
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=True
    )
    val_generator = datagen_val.flow_from_dataframe(
        dataframe=val_df,
        x_col='image_path',
        y_col='dx',
        target_size=(IMG_SIZE, IMG_SIZE),
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=False
    )

    # Extract class names from the train_generator
    # The generator creates an internal mapping of classes -> indices
    class_names = list(train_generator.class_indices.keys())

    # ------------------------------------------------------
    # 4.3) BUILD & COMPILE MODEL FROM SCRATCH FOR EACH FOLD
    # ------------------------------------------------------
    custom_resnet = build_resnet50(input_shape=(IMG_SIZE, IMG_SIZE, 3), num_classes=NUM_CLASSES)
    # Transfer weights from base Keras ResNet50 (ImageNet) to custom ResNet
    transfer_weights(base_resnet50, custom_resnet)

    # Freeze layers in the main body
    for layer in custom_resnet.layers:
        if layer.name.startswith('conv'):
            layer.trainable = False
        else:
            layer.trainable = True

    custom_resnet.compile(
        optimizer=Adam(learning_rate=1e-3),
        loss=focal_loss(),
        metrics=['accuracy', tf.keras.metrics.AUC(name='auc')]
    )

    # ------------------------------------------------------
    # 4.4) CALLBACKS & TRAIN (PHASE 1)
    # ------------------------------------------------------
    model_path_phase1 = f"resnet50_cbam_classificationhead_fold{fold_index}_phase1.keras"
    callbacks_phase1 = [
        EarlyStopping(monitor='val_auc', patience=3, restore_best_weights=True, mode='max', verbose=1),
        ModelCheckpoint(model_path_phase1, monitor='val_auc', save_best_only=True, mode='max', verbose=1)
    ]

    history_phase1 = custom_resnet.fit(
        train_generator,
        validation_data=val_generator,
        epochs=EPOCHS_PHASE1,
        class_weight=class_weights_dict,
        callbacks=callbacks_phase1
    )

    # Load best weights from Phase 1
    custom_resnet.load_weights(model_path_phase1)

    # ------------------------------------------------------
    # 4.5) UNFREEZE & FINE-TUNING (PHASE 2)
    # ------------------------------------------------------
    for layer in custom_resnet.layers:
        layer.trainable = True

    custom_resnet.compile(
        optimizer=Adam(learning_rate=1e-5),
        loss=focal_loss(),
        metrics=['accuracy', tf.keras.metrics.AUC(name='auc')]
    )

    model_path_phase2 = f"resnet50_cbam_classificationhead_fold{fold_index}_phase2.keras"
    callbacks_phase2 = [
        ReduceLROnPlateau(monitor='val_auc', factor=0.1, patience=3, mode='max', verbose=1),
        EarlyStopping(monitor='val_auc', patience=7, restore_best_weights=True, mode='max', verbose=1),
        ModelCheckpoint(model_path_phase2, monitor='val_auc', save_best_only=True, mode='max', verbose=1)
    ]

    history_phase2 = custom_resnet.fit(
        train_generator,
        validation_data=val_generator,
        epochs=EPOCHS_PHASE2,
        class_weight=class_weights_dict,
        callbacks=callbacks_phase2
    )

    # Load best weights from Phase 2
    custom_resnet.load_weights(model_path_phase2)

    # ------------------------------------------------------
    # 4.6) EVALUATE ON THIS FOLD
    # ------------------------------------------------------
    loss, accuracy, auc_val = custom_resnet.evaluate(val_generator, verbose=0)
    print(f"FOLD {fold_index} - Loss: {loss:.4f}, Accuracy: {accuracy:.4f}, AUC: {auc_val:.4f}")

    fold_losses.append(loss)
    fold_accuracies.append(accuracy)
    fold_aucs.append(auc_val)

    # Check if this fold is the best so far
    if auc_val > best_auc_across_folds:
        best_auc_across_folds = auc_val
        best_fold = fold_index

    # Move to next fold
    fold_index += 1

# -------------------------------------------------------------------------
# 5) CROSS-VALIDATION RESULTS
# -------------------------------------------------------------------------
print("\n=== CROSS-VALIDATION RESULTS ===")
print(f"Average Loss over {k_folds} folds  : {np.mean(fold_losses):.4f} (± {np.std(fold_losses):.4f})")
print(f"Average Accuracy over {k_folds} folds: {np.mean(fold_accuracies):.4f} (± {np.std(fold_accuracies):.4f})")
print(f"Average AUC over {k_folds} folds     : {np.mean(fold_aucs):.4f} (± {np.std(fold_aucs):.4f})")
# Out:
# Class weights dict: {0: np.float64(4.375273044997815), 1: np.float64(2.78349082823791), 2: np.float64(1.301832835044846), 3: np.float64(12.440993788819876), 4: np.float64(1.2854575792581184), 5: np.float64(0.21338020666879728), 6: np.float64(10.075452716297788)}
#
#
# ===== FOLD 1/5 =====
# Train size: 8012 Val size: 2003
# Train distribution:
#  dx
# nv       5364
# mel       890
# bkl       879
# bcc       411
# akiec     262
# vasc      114
# df         92
# Name: count, dtype: int64
# Val distribution:
#  dx
# nv       1341
# mel       223
# bkl       220
# bcc       103
# akiec      65
# vasc       28
# df         23
# Name: count, dtype: int64
# Found 8012 validated image filenames belonging to 7 classes.
# Found 2003 validated image filenames belonging to 7 classes.
# /Users/robp/.local/share/virtualenvs/account-management-Kww3qb6U/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 781ms/step - accuracy: 0.6260 - auc: 0.8542 - loss: 0.2159
# Epoch 1: val_auc improved from -inf to 0.88311, saving model to resnet50_cbam_classificationhead_fold1_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 248s 977ms/step - accuracy: 0.6261 - auc: 0.8542 - loss: 0.2158 - val_accuracy: 0.6695 - val_auc: 0.8831 - val_loss: 0.1728
# Epoch 2/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 788ms/step - accuracy: 0.6745 - auc: 0.8768 - loss: 0.1828
# Epoch 2: val_auc improved from 0.88311 to 0.89101, saving model to resnet50_cbam_classificationhead_fold1_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 245s 976ms/step - accuracy: 0.6745 - auc: 0.8768 - loss: 0.1828 - val_accuracy: 0.6695 - val_auc: 0.8910 - val_loss: 0.1703
# Epoch 3/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 764ms/step - accuracy: 0.6799 - auc: 0.8821 - loss: 0.1724
# Epoch 3: val_auc improved from 0.89101 to 0.89714, saving model to resnet50_cbam_classificationhead_fold1_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 239s 952ms/step - accuracy: 0.6799 - auc: 0.8821 - loss: 0.1724 - val_accuracy: 0.6695 - val_auc: 0.8971 - val_loss: 0.1695
# Epoch 4/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.6614 - auc: 0.8755 - loss: 0.1964
# Epoch 4: val_auc improved from 0.89714 to 0.89790, saving model to resnet50_cbam_classificationhead_fold1_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 235s 937ms/step - accuracy: 0.6614 - auc: 0.8755 - loss: 0.1963 - val_accuracy: 0.6695 - val_auc: 0.8979 - val_loss: 0.1680
# Epoch 5/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 759ms/step - accuracy: 0.6731 - auc: 0.8834 - loss: 0.1738
# Epoch 5: val_auc did not improve from 0.89790
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 237s 943ms/step - accuracy: 0.6731 - auc: 0.8834 - loss: 0.1738 - val_accuracy: 0.6695 - val_auc: 0.8933 - val_loss: 0.1683
# Epoch 6/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 736ms/step - accuracy: 0.6522 - auc: 0.8777 - loss: 0.1920
# Epoch 6: val_auc improved from 0.89790 to 0.90062, saving model to resnet50_cbam_classificationhead_fold1_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 230s 917ms/step - accuracy: 0.6523 - auc: 0.8777 - loss: 0.1920 - val_accuracy: 0.6705 - val_auc: 0.9006 - val_loss: 0.1666
# Epoch 7/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.6687 - auc: 0.8853 - loss: 0.1803
# Epoch 7: val_auc improved from 0.90062 to 0.90231, saving model to resnet50_cbam_classificationhead_fold1_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 228s 909ms/step - accuracy: 0.6687 - auc: 0.8853 - loss: 0.1803 - val_accuracy: 0.6700 - val_auc: 0.9023 - val_loss: 0.1665
# Epoch 8/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 736ms/step - accuracy: 0.6706 - auc: 0.8871 - loss: 0.1786
# Epoch 8: val_auc did not improve from 0.90231
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 230s 916ms/step - accuracy: 0.6706 - auc: 0.8871 - loss: 0.1786 - val_accuracy: 0.6700 - val_auc: 0.8971 - val_loss: 0.1655
# Epoch 9/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 736ms/step - accuracy: 0.6629 - auc: 0.8840 - loss: 0.1854
# Epoch 9: val_auc did not improve from 0.90231
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 230s 916ms/step - accuracy: 0.6629 - auc: 0.8840 - loss: 0.1853 - val_accuracy: 0.6700 - val_auc: 0.9020 - val_loss: 0.1654
# Epoch 10/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.6780 - auc: 0.8918 - loss: 0.1693
# Epoch 10: val_auc did not improve from 0.90231
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 229s 912ms/step - accuracy: 0.6779 - auc: 0.8918 - loss: 0.1693 - val_accuracy: 0.6700 - val_auc: 0.9011 - val_loss: 0.1642
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Epoch 1/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6386 - auc: 0.8567 - loss: 0.6361
# Epoch 1: val_auc improved from -inf to 0.82801, saving model to resnet50_cbam_classificationhead_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 681s 3s/step - accuracy: 0.6385 - auc: 0.8568 - loss: 0.6356 - val_accuracy: 0.6455 - val_auc: 0.8280 - val_loss: 0.8564 - learning_rate: 1.0000e-05
# Epoch 2/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6493 - auc: 0.9048 - loss: 0.3136
# Epoch 2: val_auc did not improve from 0.82801
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 645s 3s/step - accuracy: 0.6494 - auc: 0.9049 - loss: 0.3135 - val_accuracy: 0.1598 - val_auc: 0.6925 - val_loss: 1.3474 - learning_rate: 1.0000e-05
# Epoch 3/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6722 - auc: 0.9242 - loss: 0.2000
# Epoch 3: val_auc did not improve from 0.82801
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 665s 3s/step - accuracy: 0.6722 - auc: 0.9242 - loss: 0.2000 - val_accuracy: 0.6695 - val_auc: 0.8172 - val_loss: 1.1152 - learning_rate: 1.0000e-05
# Epoch 4/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6924 - auc: 0.9374 - loss: 0.1543
# Epoch 4: val_auc improved from 0.82801 to 0.92499, saving model to resnet50_cbam_classificationhead_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 684s 3s/step - accuracy: 0.6924 - auc: 0.9374 - loss: 0.1543 - val_accuracy: 0.6905 - val_auc: 0.9250 - val_loss: 0.2337 - learning_rate: 1.0000e-05
# Epoch 5/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7168 - auc: 0.9481 - loss: 0.1280
# Epoch 5: val_auc improved from 0.92499 to 0.96012, saving model to resnet50_cbam_classificationhead_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 675s 3s/step - accuracy: 0.7168 - auc: 0.9481 - loss: 0.1280 - val_accuracy: 0.7459 - val_auc: 0.9601 - val_loss: 0.1054 - learning_rate: 1.0000e-05
# Epoch 6/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7279 - auc: 0.9560 - loss: 0.1182
# Epoch 6: val_auc improved from 0.96012 to 0.96722, saving model to resnet50_cbam_classificationhead_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 651s 3s/step - accuracy: 0.7279 - auc: 0.9560 - loss: 0.1182 - val_accuracy: 0.7768 - val_auc: 0.9672 - val_loss: 0.0917 - learning_rate: 1.0000e-05
# Epoch 7/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7581 - auc: 0.9618 - loss: 0.1036
# Epoch 7: val_auc improved from 0.96722 to 0.97059, saving model to resnet50_cbam_classificationhead_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 657s 3s/step - accuracy: 0.7581 - auc: 0.9618 - loss: 0.1036 - val_accuracy: 0.7898 - val_auc: 0.9706 - val_loss: 0.0845 - learning_rate: 1.0000e-05
# Epoch 8/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7656 - auc: 0.9646 - loss: 0.1012
# Epoch 8: val_auc improved from 0.97059 to 0.97238, saving model to resnet50_cbam_classificationhead_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 661s 3s/step - accuracy: 0.7656 - auc: 0.9646 - loss: 0.1011 - val_accuracy: 0.7968 - val_auc: 0.9724 - val_loss: 0.0795 - learning_rate: 1.0000e-05
# Epoch 9/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7804 - auc: 0.9710 - loss: 0.0876
# Epoch 9: val_auc improved from 0.97238 to 0.97447, saving model to resnet50_cbam_classificationhead_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 656s 3s/step - accuracy: 0.7804 - auc: 0.9710 - loss: 0.0876 - val_accuracy: 0.8003 - val_auc: 0.9745 - val_loss: 0.0742 - learning_rate: 1.0000e-05
# Epoch 10/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7769 - auc: 0.9702 - loss: 0.0908
# Epoch 10: val_auc improved from 0.97447 to 0.97638, saving model to resnet50_cbam_classificationhead_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 652s 3s/step - accuracy: 0.7769 - auc: 0.9702 - loss: 0.0908 - val_accuracy: 0.8103 - val_auc: 0.9764 - val_loss: 0.0700 - learning_rate: 1.0000e-05
# Epoch 11/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8007 - auc: 0.9763 - loss: 0.0747
# Epoch 11: val_auc improved from 0.97638 to 0.97770, saving model to resnet50_cbam_classificationhead_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 660s 3s/step - accuracy: 0.8007 - auc: 0.9763 - loss: 0.0747 - val_accuracy: 0.8113 - val_auc: 0.9777 - val_loss: 0.0673 - learning_rate: 1.0000e-05
# Epoch 12/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8094 - auc: 0.9782 - loss: 0.0705
# Epoch 12: val_auc did not improve from 0.97770
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 656s 3s/step - accuracy: 0.8094 - auc: 0.9782 - loss: 0.0705 - val_accuracy: 0.8103 - val_auc: 0.9777 - val_loss: 0.0667 - learning_rate: 1.0000e-05
# Epoch 13/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8182 - auc: 0.9795 - loss: 0.0665
# Epoch 13: val_auc improved from 0.97770 to 0.97946, saving model to resnet50_cbam_classificationhead_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 658s 3s/step - accuracy: 0.8183 - auc: 0.9795 - loss: 0.0665 - val_accuracy: 0.8168 - val_auc: 0.9795 - val_loss: 0.0661 - learning_rate: 1.0000e-05
# Epoch 14/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8294 - auc: 0.9829 - loss: 0.0594
# Epoch 14: val_auc improved from 0.97946 to 0.97948, saving model to resnet50_cbam_classificationhead_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 658s 3s/step - accuracy: 0.8294 - auc: 0.9829 - loss: 0.0594 - val_accuracy: 0.8183 - val_auc: 0.9795 - val_loss: 0.0642 - learning_rate: 1.0000e-05
# Epoch 15/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8301 - auc: 0.9838 - loss: 0.0553
# Epoch 15: val_auc improved from 0.97948 to 0.98160, saving model to resnet50_cbam_classificationhead_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 654s 3s/step - accuracy: 0.8301 - auc: 0.9838 - loss: 0.0553 - val_accuracy: 0.8278 - val_auc: 0.9816 - val_loss: 0.0598 - learning_rate: 1.0000e-05
# Epoch 16/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8461 - auc: 0.9853 - loss: 0.0529
# Epoch 16: val_auc did not improve from 0.98160
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 653s 3s/step - accuracy: 0.8461 - auc: 0.9853 - loss: 0.0529 - val_accuracy: 0.8218 - val_auc: 0.9808 - val_loss: 0.0625 - learning_rate: 1.0000e-05
# Epoch 17/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8541 - auc: 0.9874 - loss: 0.0466
# Epoch 17: val_auc did not improve from 0.98160
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 652s 3s/step - accuracy: 0.8541 - auc: 0.9874 - loss: 0.0466 - val_accuracy: 0.8183 - val_auc: 0.9807 - val_loss: 0.0632 - learning_rate: 1.0000e-05
# Epoch 18/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8626 - auc: 0.9892 - loss: 0.0434
# Epoch 18: val_auc improved from 0.98160 to 0.98287, saving model to resnet50_cbam_classificationhead_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 653s 3s/step - accuracy: 0.8626 - auc: 0.9892 - loss: 0.0434 - val_accuracy: 0.8268 - val_auc: 0.9829 - val_loss: 0.0574 - learning_rate: 1.0000e-05
# Epoch 19/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8728 - auc: 0.9909 - loss: 0.0387
# Epoch 19: val_auc improved from 0.98287 to 0.98290, saving model to resnet50_cbam_classificationhead_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 659s 3s/step - accuracy: 0.8728 - auc: 0.9909 - loss: 0.0387 - val_accuracy: 0.8342 - val_auc: 0.9829 - val_loss: 0.0599 - learning_rate: 1.0000e-05
# Epoch 20/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8866 - auc: 0.9920 - loss: 0.0367
# Epoch 20: val_auc improved from 0.98290 to 0.98364, saving model to resnet50_cbam_classificationhead_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 653s 3s/step - accuracy: 0.8866 - auc: 0.9920 - loss: 0.0367 - val_accuracy: 0.8347 - val_auc: 0.9836 - val_loss: 0.0586 - learning_rate: 1.0000e-05
# Epoch 21/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8923 - auc: 0.9925 - loss: 0.0340
# Epoch 21: val_auc did not improve from 0.98364
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 651s 3s/step - accuracy: 0.8923 - auc: 0.9925 - loss: 0.0340 - val_accuracy: 0.8218 - val_auc: 0.9818 - val_loss: 0.0644 - learning_rate: 1.0000e-05
# Epoch 22/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9090 - auc: 0.9948 - loss: 0.0269
# Epoch 22: val_auc did not improve from 0.98364
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 660s 3s/step - accuracy: 0.9090 - auc: 0.9948 - loss: 0.0269 - val_accuracy: 0.8223 - val_auc: 0.9815 - val_loss: 0.0657 - learning_rate: 1.0000e-05
# Epoch 23/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9092 - auc: 0.9947 - loss: 0.0266
# Epoch 23: val_auc improved from 0.98364 to 0.98411, saving model to resnet50_cbam_classificationhead_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 658s 3s/step - accuracy: 0.9093 - auc: 0.9947 - loss: 0.0266 - val_accuracy: 0.8457 - val_auc: 0.9841 - val_loss: 0.0592 - learning_rate: 1.0000e-05
# Epoch 24/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9162 - auc: 0.9956 - loss: 0.0226
# Epoch 24: val_auc did not improve from 0.98411
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 658s 3s/step - accuracy: 0.9162 - auc: 0.9956 - loss: 0.0226 - val_accuracy: 0.8293 - val_auc: 0.9820 - val_loss: 0.0677 - learning_rate: 1.0000e-05
# Epoch 25/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9278 - auc: 0.9961 - loss: 0.0211
# Epoch 25: val_auc did not improve from 0.98411
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 657s 3s/step - accuracy: 0.9278 - auc: 0.9961 - loss: 0.0211 - val_accuracy: 0.8328 - val_auc: 0.9827 - val_loss: 0.0685 - learning_rate: 1.0000e-05
# Epoch 26/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9305 - auc: 0.9967 - loss: 0.0204
# Epoch 26: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 26: val_auc did not improve from 0.98411
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 653s 3s/step - accuracy: 0.9304 - auc: 0.9967 - loss: 0.0204 - val_accuracy: 0.8333 - val_auc: 0.9817 - val_loss: 0.0682 - learning_rate: 1.0000e-05
# Epoch 27/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9413 - auc: 0.9976 - loss: 0.0157
# Epoch 27: val_auc did not improve from 0.98411
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 656s 3s/step - accuracy: 0.9413 - auc: 0.9976 - loss: 0.0157 - val_accuracy: 0.8387 - val_auc: 0.9826 - val_loss: 0.0663 - learning_rate: 1.0000e-06
# Epoch 28/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9421 - auc: 0.9976 - loss: 0.0172
# Epoch 28: val_auc did not improve from 0.98411
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 655s 3s/step - accuracy: 0.9421 - auc: 0.9976 - loss: 0.0172 - val_accuracy: 0.8352 - val_auc: 0.9821 - val_loss: 0.0687 - learning_rate: 1.0000e-06
# Epoch 29/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9437 - auc: 0.9977 - loss: 0.0167
# Epoch 29: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
#
# Epoch 29: val_auc did not improve from 0.98411
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 655s 3s/step - accuracy: 0.9437 - auc: 0.9977 - loss: 0.0167 - val_accuracy: 0.8387 - val_auc: 0.9823 - val_loss: 0.0685 - learning_rate: 1.0000e-06
# Epoch 30/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9409 - auc: 0.9978 - loss: 0.0148
# Epoch 30: val_auc did not improve from 0.98411
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 662s 3s/step - accuracy: 0.9409 - auc: 0.9978 - loss: 0.0148 - val_accuracy: 0.8337 - val_auc: 0.9821 - val_loss: 0.0698 - learning_rate: 1.0000e-07
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 23.
# FOLD 1 - Loss: 0.0592, Accuracy: 0.8457, AUC: 0.9841
#
#
# ===== FOLD 2/5 =====
# Train size: 8012 Val size: 2003
# Train distribution:
#  dx
# nv       5364
# mel       890
# bkl       879
# bcc       411
# akiec     262
# vasc      114
# df         92
# Name: count, dtype: int64
# Val distribution:
#  dx
# nv       1341
# mel       223
# bkl       220
# bcc       103
# akiec      65
# vasc       28
# df         23
# Name: count, dtype: int64
# Found 8012 validated image filenames belonging to 7 classes.
# Found 2003 validated image filenames belonging to 7 classes.
# /Users/robp/.local/share/virtualenvs/account-management-Kww3qb6U/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 711ms/step - accuracy: 0.6408 - auc: 0.8567 - loss: 0.1997
# Epoch 1: val_auc improved from -inf to 0.87930, saving model to resnet50_cbam_classificationhead_fold2_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 226s 889ms/step - accuracy: 0.6409 - auc: 0.8567 - loss: 0.1997 - val_accuracy: 0.6695 - val_auc: 0.8793 - val_loss: 0.1725
# Epoch 2/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 718ms/step - accuracy: 0.6684 - auc: 0.8720 - loss: 0.1902
# Epoch 2: val_auc improved from 0.87930 to 0.88706, saving model to resnet50_cbam_classificationhead_fold2_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 225s 895ms/step - accuracy: 0.6684 - auc: 0.8720 - loss: 0.1902 - val_accuracy: 0.6695 - val_auc: 0.8871 - val_loss: 0.1711
# Epoch 3/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.6812 - auc: 0.8835 - loss: 0.1674
# Epoch 3: val_auc improved from 0.88706 to 0.89059, saving model to resnet50_cbam_classificationhead_fold2_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 221s 882ms/step - accuracy: 0.6812 - auc: 0.8834 - loss: 0.1674 - val_accuracy: 0.6690 - val_auc: 0.8906 - val_loss: 0.1717
# Epoch 4/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 722ms/step - accuracy: 0.6679 - auc: 0.8787 - loss: 0.1887
# Epoch 4: val_auc improved from 0.89059 to 0.89581, saving model to resnet50_cbam_classificationhead_fold2_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 226s 899ms/step - accuracy: 0.6680 - auc: 0.8788 - loss: 0.1886 - val_accuracy: 0.6705 - val_auc: 0.8958 - val_loss: 0.1685
# Epoch 5/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 716ms/step - accuracy: 0.6725 - auc: 0.8842 - loss: 0.1748
# Epoch 5: val_auc did not improve from 0.89581
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 224s 893ms/step - accuracy: 0.6724 - auc: 0.8842 - loss: 0.1748 - val_accuracy: 0.6705 - val_auc: 0.8926 - val_loss: 0.1674
# Epoch 6/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 726ms/step - accuracy: 0.6730 - auc: 0.8876 - loss: 0.1707
# Epoch 6: val_auc improved from 0.89581 to 0.89726, saving model to resnet50_cbam_classificationhead_fold2_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 227s 904ms/step - accuracy: 0.6730 - auc: 0.8876 - loss: 0.1707 - val_accuracy: 0.6700 - val_auc: 0.8973 - val_loss: 0.1675
# Epoch 7/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.6721 - auc: 0.8879 - loss: 0.1759
# Epoch 7: val_auc improved from 0.89726 to 0.90052, saving model to resnet50_cbam_classificationhead_fold2_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 229s 911ms/step - accuracy: 0.6721 - auc: 0.8879 - loss: 0.1759 - val_accuracy: 0.6705 - val_auc: 0.9005 - val_loss: 0.1666
# Epoch 8/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 717ms/step - accuracy: 0.6686 - auc: 0.8858 - loss: 0.1846
# Epoch 8: val_auc improved from 0.90052 to 0.90133, saving model to resnet50_cbam_classificationhead_fold2_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 225s 896ms/step - accuracy: 0.6686 - auc: 0.8858 - loss: 0.1846 - val_accuracy: 0.6700 - val_auc: 0.9013 - val_loss: 0.1664
# Epoch 9/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 711ms/step - accuracy: 0.6703 - auc: 0.8900 - loss: 0.1740
# Epoch 9: val_auc did not improve from 0.90133
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 222s 885ms/step - accuracy: 0.6703 - auc: 0.8900 - loss: 0.1741 - val_accuracy: 0.6700 - val_auc: 0.8987 - val_loss: 0.1650
# Epoch 10/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 717ms/step - accuracy: 0.6697 - auc: 0.8894 - loss: 0.1785
# Epoch 10: val_auc did not improve from 0.90133
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 224s 893ms/step - accuracy: 0.6697 - auc: 0.8894 - loss: 0.1785 - val_accuracy: 0.6700 - val_auc: 0.8989 - val_loss: 0.1646
# Epoch 11/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 718ms/step - accuracy: 0.6808 - auc: 0.8927 - loss: 0.1704
# Epoch 11: val_auc improved from 0.90133 to 0.90246, saving model to resnet50_cbam_classificationhead_fold2_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 224s 894ms/step - accuracy: 0.6808 - auc: 0.8927 - loss: 0.1704 - val_accuracy: 0.6740 - val_auc: 0.9025 - val_loss: 0.1651
# Epoch 12/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 719ms/step - accuracy: 0.6752 - auc: 0.8928 - loss: 0.1797
# Epoch 12: val_auc improved from 0.90246 to 0.90248, saving model to resnet50_cbam_classificationhead_fold2_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 225s 897ms/step - accuracy: 0.6752 - auc: 0.8928 - loss: 0.1797 - val_accuracy: 0.6760 - val_auc: 0.9025 - val_loss: 0.1644
# Epoch 13/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 719ms/step - accuracy: 0.6718 - auc: 0.8933 - loss: 0.1712
# Epoch 13: val_auc did not improve from 0.90248
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 225s 897ms/step - accuracy: 0.6718 - auc: 0.8933 - loss: 0.1712 - val_accuracy: 0.6785 - val_auc: 0.9011 - val_loss: 0.1617
# Epoch 14/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 724ms/step - accuracy: 0.6652 - auc: 0.8934 - loss: 0.1769
# Epoch 14: val_auc improved from 0.90248 to 0.90367, saving model to resnet50_cbam_classificationhead_fold2_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 226s 902ms/step - accuracy: 0.6652 - auc: 0.8934 - loss: 0.1769 - val_accuracy: 0.6785 - val_auc: 0.9037 - val_loss: 0.1598
# Epoch 15/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 726ms/step - accuracy: 0.6640 - auc: 0.8944 - loss: 0.1777
# Epoch 15: val_auc improved from 0.90367 to 0.90378, saving model to resnet50_cbam_classificationhead_fold2_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 227s 902ms/step - accuracy: 0.6641 - auc: 0.8944 - loss: 0.1777 - val_accuracy: 0.6780 - val_auc: 0.9038 - val_loss: 0.1585
# Epoch 16/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 718ms/step - accuracy: 0.6697 - auc: 0.8972 - loss: 0.1784
# Epoch 16: val_auc improved from 0.90378 to 0.90451, saving model to resnet50_cbam_classificationhead_fold2_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 225s 897ms/step - accuracy: 0.6697 - auc: 0.8972 - loss: 0.1784 - val_accuracy: 0.6780 - val_auc: 0.9045 - val_loss: 0.1657
# Epoch 17/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 712ms/step - accuracy: 0.6686 - auc: 0.8996 - loss: 0.1649
# Epoch 17: val_auc improved from 0.90451 to 0.90871, saving model to resnet50_cbam_classificationhead_fold2_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 223s 888ms/step - accuracy: 0.6686 - auc: 0.8996 - loss: 0.1649 - val_accuracy: 0.6785 - val_auc: 0.9087 - val_loss: 0.1604
# Epoch 18/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 717ms/step - accuracy: 0.6648 - auc: 0.8964 - loss: 0.1819
# Epoch 18: val_auc did not improve from 0.90871
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 224s 891ms/step - accuracy: 0.6648 - auc: 0.8964 - loss: 0.1819 - val_accuracy: 0.6740 - val_auc: 0.9051 - val_loss: 0.1626
# Epoch 19/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 720ms/step - accuracy: 0.6757 - auc: 0.9005 - loss: 0.1697
# Epoch 19: val_auc did not improve from 0.90871
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 225s 896ms/step - accuracy: 0.6757 - auc: 0.9005 - loss: 0.1697 - val_accuracy: 0.6790 - val_auc: 0.9067 - val_loss: 0.1558
# Epoch 20/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 717ms/step - accuracy: 0.6659 - auc: 0.8994 - loss: 0.1761
# Epoch 20: val_auc improved from 0.90871 to 0.90949, saving model to resnet50_cbam_classificationhead_fold2_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 224s 892ms/step - accuracy: 0.6659 - auc: 0.8994 - loss: 0.1760 - val_accuracy: 0.6810 - val_auc: 0.9095 - val_loss: 0.1539
# Restoring model weights from the end of the best epoch: 20.
# Epoch 1/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6587 - auc: 0.8300 - loss: 1.0911
# Epoch 1: val_auc improved from -inf to 0.80767, saving model to resnet50_cbam_classificationhead_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 667s 3s/step - accuracy: 0.6587 - auc: 0.8301 - loss: 1.0903 - val_accuracy: 0.6695 - val_auc: 0.8077 - val_loss: 1.3266 - learning_rate: 1.0000e-05
# Epoch 2/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6496 - auc: 0.8842 - loss: 0.5311
# Epoch 2: val_auc did not improve from 0.80767
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 655s 3s/step - accuracy: 0.6496 - auc: 0.8842 - loss: 0.5308 - val_accuracy: 0.6695 - val_auc: 0.8072 - val_loss: 1.3301 - learning_rate: 1.0000e-05
# Epoch 3/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6744 - auc: 0.9159 - loss: 0.3047
# Epoch 3: val_auc improved from 0.80767 to 0.81264, saving model to resnet50_cbam_classificationhead_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 656s 3s/step - accuracy: 0.6744 - auc: 0.9159 - loss: 0.3046 - val_accuracy: 0.6695 - val_auc: 0.8126 - val_loss: 1.1143 - learning_rate: 1.0000e-05
# Epoch 4/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6836 - auc: 0.9282 - loss: 0.2022
# Epoch 4: val_auc improved from 0.81264 to 0.91174, saving model to resnet50_cbam_classificationhead_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 660s 3s/step - accuracy: 0.6836 - auc: 0.9282 - loss: 0.2022 - val_accuracy: 0.6855 - val_auc: 0.9117 - val_loss: 0.2545 - learning_rate: 1.0000e-05
# Epoch 5/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7021 - auc: 0.9396 - loss: 0.1641
# Epoch 5: val_auc improved from 0.91174 to 0.94898, saving model to resnet50_cbam_classificationhead_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 655s 3s/step - accuracy: 0.7021 - auc: 0.9396 - loss: 0.1641 - val_accuracy: 0.7349 - val_auc: 0.9490 - val_loss: 0.1349 - learning_rate: 1.0000e-05
# Epoch 6/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7202 - auc: 0.9490 - loss: 0.1339
# Epoch 6: val_auc improved from 0.94898 to 0.95662, saving model to resnet50_cbam_classificationhead_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 660s 3s/step - accuracy: 0.7202 - auc: 0.9490 - loss: 0.1339 - val_accuracy: 0.7489 - val_auc: 0.9566 - val_loss: 0.1126 - learning_rate: 1.0000e-05
# Epoch 7/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7311 - auc: 0.9520 - loss: 0.1279
# Epoch 7: val_auc improved from 0.95662 to 0.96011, saving model to resnet50_cbam_classificationhead_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 657s 3s/step - accuracy: 0.7311 - auc: 0.9520 - loss: 0.1279 - val_accuracy: 0.7544 - val_auc: 0.9601 - val_loss: 0.1022 - learning_rate: 1.0000e-05
# Epoch 8/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7495 - auc: 0.9595 - loss: 0.1059
# Epoch 8: val_auc improved from 0.96011 to 0.96380, saving model to resnet50_cbam_classificationhead_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 654s 3s/step - accuracy: 0.7495 - auc: 0.9595 - loss: 0.1059 - val_accuracy: 0.7609 - val_auc: 0.9638 - val_loss: 0.0947 - learning_rate: 1.0000e-05
# Epoch 9/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7600 - auc: 0.9611 - loss: 0.1066
# Epoch 9: val_auc improved from 0.96380 to 0.96601, saving model to resnet50_cbam_classificationhead_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 654s 3s/step - accuracy: 0.7600 - auc: 0.9611 - loss: 0.1066 - val_accuracy: 0.7753 - val_auc: 0.9660 - val_loss: 0.0901 - learning_rate: 1.0000e-05
# Epoch 10/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7610 - auc: 0.9652 - loss: 0.0967
# Epoch 10: val_auc improved from 0.96601 to 0.96947, saving model to resnet50_cbam_classificationhead_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 656s 3s/step - accuracy: 0.7610 - auc: 0.9652 - loss: 0.0967 - val_accuracy: 0.7828 - val_auc: 0.9695 - val_loss: 0.0843 - learning_rate: 1.0000e-05
# Epoch 11/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7663 - auc: 0.9666 - loss: 0.0971
# Epoch 11: val_auc improved from 0.96947 to 0.97114, saving model to resnet50_cbam_classificationhead_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 652s 3s/step - accuracy: 0.7663 - auc: 0.9666 - loss: 0.0971 - val_accuracy: 0.7888 - val_auc: 0.9711 - val_loss: 0.0796 - learning_rate: 1.0000e-05
# Epoch 12/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7783 - auc: 0.9691 - loss: 0.0954
# Epoch 12: val_auc improved from 0.97114 to 0.97287, saving model to resnet50_cbam_classificationhead_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 656s 3s/step - accuracy: 0.7783 - auc: 0.9691 - loss: 0.0953 - val_accuracy: 0.7978 - val_auc: 0.9729 - val_loss: 0.0755 - learning_rate: 1.0000e-05
# Epoch 13/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7914 - auc: 0.9739 - loss: 0.0832
# Epoch 13: val_auc improved from 0.97287 to 0.97327, saving model to resnet50_cbam_classificationhead_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 655s 3s/step - accuracy: 0.7914 - auc: 0.9739 - loss: 0.0832 - val_accuracy: 0.8023 - val_auc: 0.9733 - val_loss: 0.0752 - learning_rate: 1.0000e-05
# Epoch 14/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8130 - auc: 0.9769 - loss: 0.0761
# Epoch 14: val_auc improved from 0.97327 to 0.97557, saving model to resnet50_cbam_classificationhead_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 655s 3s/step - accuracy: 0.8130 - auc: 0.9769 - loss: 0.0761 - val_accuracy: 0.8063 - val_auc: 0.9756 - val_loss: 0.0694 - learning_rate: 1.0000e-05
# Epoch 15/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8113 - auc: 0.9777 - loss: 0.0701
# Epoch 15: val_auc improved from 0.97557 to 0.97576, saving model to resnet50_cbam_classificationhead_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 656s 3s/step - accuracy: 0.8113 - auc: 0.9778 - loss: 0.0701 - val_accuracy: 0.8048 - val_auc: 0.9758 - val_loss: 0.0684 - learning_rate: 1.0000e-05
# Epoch 16/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8160 - auc: 0.9801 - loss: 0.0641
# Epoch 16: val_auc improved from 0.97576 to 0.97701, saving model to resnet50_cbam_classificationhead_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 655s 3s/step - accuracy: 0.8160 - auc: 0.9801 - loss: 0.0641 - val_accuracy: 0.8108 - val_auc: 0.9770 - val_loss: 0.0665 - learning_rate: 1.0000e-05
# Epoch 17/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8316 - auc: 0.9818 - loss: 0.0597
# Epoch 17: val_auc improved from 0.97701 to 0.97876, saving model to resnet50_cbam_classificationhead_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 652s 3s/step - accuracy: 0.8316 - auc: 0.9818 - loss: 0.0597 - val_accuracy: 0.8228 - val_auc: 0.9788 - val_loss: 0.0636 - learning_rate: 1.0000e-05
# Epoch 18/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8425 - auc: 0.9845 - loss: 0.0542
# Epoch 18: val_auc improved from 0.97876 to 0.97987, saving model to resnet50_cbam_classificationhead_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 663s 3s/step - accuracy: 0.8425 - auc: 0.9845 - loss: 0.0542 - val_accuracy: 0.8278 - val_auc: 0.9799 - val_loss: 0.0623 - learning_rate: 1.0000e-05
# Epoch 19/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8532 - auc: 0.9856 - loss: 0.0497
# Epoch 19: val_auc did not improve from 0.97987
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 651s 3s/step - accuracy: 0.8532 - auc: 0.9856 - loss: 0.0497 - val_accuracy: 0.8318 - val_auc: 0.9793 - val_loss: 0.0630 - learning_rate: 1.0000e-05
# Epoch 20/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8576 - auc: 0.9869 - loss: 0.0512
# Epoch 20: val_auc improved from 0.97987 to 0.98115, saving model to resnet50_cbam_classificationhead_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 656s 3s/step - accuracy: 0.8576 - auc: 0.9869 - loss: 0.0512 - val_accuracy: 0.8392 - val_auc: 0.9811 - val_loss: 0.0606 - learning_rate: 1.0000e-05
# Epoch 21/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8662 - auc: 0.9894 - loss: 0.0424
# Epoch 21: val_auc improved from 0.98115 to 0.98131, saving model to resnet50_cbam_classificationhead_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 658s 3s/step - accuracy: 0.8662 - auc: 0.9894 - loss: 0.0424 - val_accuracy: 0.8377 - val_auc: 0.9813 - val_loss: 0.0599 - learning_rate: 1.0000e-05
# Epoch 22/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8723 - auc: 0.9890 - loss: 0.0434
# Epoch 22: val_auc did not improve from 0.98131
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 653s 3s/step - accuracy: 0.8723 - auc: 0.9890 - loss: 0.0434 - val_accuracy: 0.8328 - val_auc: 0.9801 - val_loss: 0.0634 - learning_rate: 1.0000e-05
# Epoch 23/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8726 - auc: 0.9891 - loss: 0.0457
# Epoch 23: val_auc did not improve from 0.98131
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 656s 3s/step - accuracy: 0.8726 - auc: 0.9891 - loss: 0.0456 - val_accuracy: 0.8198 - val_auc: 0.9789 - val_loss: 0.0684 - learning_rate: 1.0000e-05
# Epoch 24/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8809 - auc: 0.9907 - loss: 0.0383
# Epoch 24: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 24: val_auc did not improve from 0.98131
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 657s 3s/step - accuracy: 0.8809 - auc: 0.9907 - loss: 0.0383 - val_accuracy: 0.8347 - val_auc: 0.9809 - val_loss: 0.0624 - learning_rate: 1.0000e-05
# Epoch 25/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8950 - auc: 0.9929 - loss: 0.0327
# Epoch 25: val_auc did not improve from 0.98131
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 656s 3s/step - accuracy: 0.8950 - auc: 0.9929 - loss: 0.0327 - val_accuracy: 0.8308 - val_auc: 0.9804 - val_loss: 0.0643 - learning_rate: 1.0000e-06
# Epoch 26/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8964 - auc: 0.9931 - loss: 0.0307
# Epoch 26: val_auc did not improve from 0.98131
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 660s 3s/step - accuracy: 0.8965 - auc: 0.9931 - loss: 0.0307 - val_accuracy: 0.8323 - val_auc: 0.9810 - val_loss: 0.0639 - learning_rate: 1.0000e-06
# Epoch 27/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9115 - auc: 0.9940 - loss: 0.0292
# Epoch 27: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
#
# Epoch 27: val_auc did not improve from 0.98131
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 653s 3s/step - accuracy: 0.9115 - auc: 0.9940 - loss: 0.0292 - val_accuracy: 0.8377 - val_auc: 0.9812 - val_loss: 0.0633 - learning_rate: 1.0000e-06
# Epoch 28/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9046 - auc: 0.9939 - loss: 0.0295
# Epoch 28: val_auc did not improve from 0.98131
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 656s 3s/step - accuracy: 0.9046 - auc: 0.9939 - loss: 0.0295 - val_accuracy: 0.8323 - val_auc: 0.9803 - val_loss: 0.0652 - learning_rate: 1.0000e-07
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 21.
# FOLD 2 - Loss: 0.0599, Accuracy: 0.8377, AUC: 0.9813
#
#
# ===== FOLD 3/5 =====
# Train size: 8012 Val size: 2003
# Train distribution:
#  dx
# nv       5364
# mel       891
# bkl       879
# bcc       411
# akiec     262
# vasc      113
# df         92
# Name: count, dtype: int64
# Val distribution:
#  dx
# nv       1341
# mel       222
# bkl       220
# bcc       103
# akiec      65
# vasc       29
# df         23
# Name: count, dtype: int64
# Found 8012 validated image filenames belonging to 7 classes.
# Found 2003 validated image filenames belonging to 7 classes.
# /Users/robp/.local/share/virtualenvs/account-management-Kww3qb6U/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 717ms/step - accuracy: 0.6303 - auc: 0.8458 - loss: 0.2146
# Epoch 1: val_auc improved from -inf to 0.88420, saving model to resnet50_cbam_classificationhead_fold3_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 228s 900ms/step - accuracy: 0.6304 - auc: 0.8459 - loss: 0.2145 - val_accuracy: 0.6695 - val_auc: 0.8842 - val_loss: 0.1724
# Epoch 2/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 716ms/step - accuracy: 0.6703 - auc: 0.8762 - loss: 0.1834
# Epoch 2: val_auc improved from 0.88420 to 0.89173, saving model to resnet50_cbam_classificationhead_fold3_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 224s 893ms/step - accuracy: 0.6703 - auc: 0.8762 - loss: 0.1834 - val_accuracy: 0.6695 - val_auc: 0.8917 - val_loss: 0.1739
# Epoch 3/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 716ms/step - accuracy: 0.6665 - auc: 0.8766 - loss: 0.1886
# Epoch 3: val_auc improved from 0.89173 to 0.89220, saving model to resnet50_cbam_classificationhead_fold3_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 224s 893ms/step - accuracy: 0.6665 - auc: 0.8766 - loss: 0.1886 - val_accuracy: 0.6700 - val_auc: 0.8922 - val_loss: 0.1705
# Epoch 4/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.6692 - auc: 0.8796 - loss: 0.1809
# Epoch 4: val_auc improved from 0.89220 to 0.89434, saving model to resnet50_cbam_classificationhead_fold3_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 220s 875ms/step - accuracy: 0.6692 - auc: 0.8796 - loss: 0.1809 - val_accuracy: 0.6695 - val_auc: 0.8943 - val_loss: 0.1697
# Epoch 5/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 713ms/step - accuracy: 0.6789 - auc: 0.8869 - loss: 0.1718
# Epoch 5: val_auc did not improve from 0.89434
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 223s 888ms/step - accuracy: 0.6788 - auc: 0.8869 - loss: 0.1718 - val_accuracy: 0.6695 - val_auc: 0.8904 - val_loss: 0.1707
# Epoch 6/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 713ms/step - accuracy: 0.6720 - auc: 0.8862 - loss: 0.1755
# Epoch 6: val_auc did not improve from 0.89434
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 223s 890ms/step - accuracy: 0.6720 - auc: 0.8862 - loss: 0.1755 - val_accuracy: 0.6690 - val_auc: 0.8909 - val_loss: 0.1698
# Epoch 7/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 719ms/step - accuracy: 0.6643 - auc: 0.8828 - loss: 0.1835
# Epoch 7: val_auc did not improve from 0.89434
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 225s 897ms/step - accuracy: 0.6643 - auc: 0.8828 - loss: 0.1835 - val_accuracy: 0.6690 - val_auc: 0.8938 - val_loss: 0.1684
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Epoch 1/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5636 - auc: 0.8555 - loss: 0.4640
# Epoch 1: val_auc improved from -inf to 0.80575, saving model to resnet50_cbam_classificationhead_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 670s 3s/step - accuracy: 0.5637 - auc: 0.8556 - loss: 0.4637 - val_accuracy: 0.6650 - val_auc: 0.8057 - val_loss: 1.1664 - learning_rate: 1.0000e-05
# Epoch 2/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6437 - auc: 0.9111 - loss: 0.2646
# Epoch 2: val_auc improved from 0.80575 to 0.81270, saving model to resnet50_cbam_classificationhead_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 657s 3s/step - accuracy: 0.6437 - auc: 0.9111 - loss: 0.2645 - val_accuracy: 0.6321 - val_auc: 0.8127 - val_loss: 1.1846 - learning_rate: 1.0000e-05
# Epoch 3/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6757 - auc: 0.9303 - loss: 0.1777
# Epoch 3: val_auc improved from 0.81270 to 0.82588, saving model to resnet50_cbam_classificationhead_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 656s 3s/step - accuracy: 0.6757 - auc: 0.9303 - loss: 0.1777 - val_accuracy: 0.6670 - val_auc: 0.8259 - val_loss: 1.0826 - learning_rate: 1.0000e-05
# Epoch 4/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7009 - auc: 0.9450 - loss: 0.1450
# Epoch 4: val_auc improved from 0.82588 to 0.91085, saving model to resnet50_cbam_classificationhead_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 654s 3s/step - accuracy: 0.7009 - auc: 0.9450 - loss: 0.1449 - val_accuracy: 0.6880 - val_auc: 0.9108 - val_loss: 0.3210 - learning_rate: 1.0000e-05
# Epoch 5/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7230 - auc: 0.9524 - loss: 0.1300
# Epoch 5: val_auc improved from 0.91085 to 0.95696, saving model to resnet50_cbam_classificationhead_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 652s 3s/step - accuracy: 0.7230 - auc: 0.9524 - loss: 0.1300 - val_accuracy: 0.7574 - val_auc: 0.9570 - val_loss: 0.1134 - learning_rate: 1.0000e-05
# Epoch 6/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7429 - auc: 0.9605 - loss: 0.1119
# Epoch 6: val_auc improved from 0.95696 to 0.96494, saving model to resnet50_cbam_classificationhead_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 658s 3s/step - accuracy: 0.7429 - auc: 0.9605 - loss: 0.1118 - val_accuracy: 0.7703 - val_auc: 0.9649 - val_loss: 0.0960 - learning_rate: 1.0000e-05
# Epoch 7/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7699 - auc: 0.9678 - loss: 0.0948
# Epoch 7: val_auc improved from 0.96494 to 0.96863, saving model to resnet50_cbam_classificationhead_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 655s 3s/step - accuracy: 0.7699 - auc: 0.9678 - loss: 0.0948 - val_accuracy: 0.7843 - val_auc: 0.9686 - val_loss: 0.0894 - learning_rate: 1.0000e-05
# Epoch 8/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7861 - auc: 0.9732 - loss: 0.0810
# Epoch 8: val_auc improved from 0.96863 to 0.97055, saving model to resnet50_cbam_classificationhead_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 653s 3s/step - accuracy: 0.7862 - auc: 0.9732 - loss: 0.0810 - val_accuracy: 0.7813 - val_auc: 0.9706 - val_loss: 0.0854 - learning_rate: 1.0000e-05
# Epoch 9/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8010 - auc: 0.9763 - loss: 0.0741
# Epoch 9: val_auc improved from 0.97055 to 0.97227, saving model to resnet50_cbam_classificationhead_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 656s 3s/step - accuracy: 0.8010 - auc: 0.9763 - loss: 0.0741 - val_accuracy: 0.7998 - val_auc: 0.9723 - val_loss: 0.0796 - learning_rate: 1.0000e-05
# Epoch 10/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8106 - auc: 0.9789 - loss: 0.0693
# Epoch 10: val_auc improved from 0.97227 to 0.97418, saving model to resnet50_cbam_classificationhead_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 654s 3s/step - accuracy: 0.8106 - auc: 0.9789 - loss: 0.0693 - val_accuracy: 0.8003 - val_auc: 0.9742 - val_loss: 0.0760 - learning_rate: 1.0000e-05
# Epoch 11/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8229 - auc: 0.9820 - loss: 0.0626
# Epoch 11: val_auc improved from 0.97418 to 0.97681, saving model to resnet50_cbam_classificationhead_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 655s 3s/step - accuracy: 0.8229 - auc: 0.9820 - loss: 0.0626 - val_accuracy: 0.8128 - val_auc: 0.9768 - val_loss: 0.0721 - learning_rate: 1.0000e-05
# Epoch 12/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8311 - auc: 0.9834 - loss: 0.0591
# Epoch 12: val_auc improved from 0.97681 to 0.97682, saving model to resnet50_cbam_classificationhead_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 658s 3s/step - accuracy: 0.8311 - auc: 0.9834 - loss: 0.0591 - val_accuracy: 0.8063 - val_auc: 0.9768 - val_loss: 0.0709 - learning_rate: 1.0000e-05
# Epoch 13/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8431 - auc: 0.9846 - loss: 0.0578
# Epoch 13: val_auc improved from 0.97682 to 0.97758, saving model to resnet50_cbam_classificationhead_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 658s 3s/step - accuracy: 0.8432 - auc: 0.9846 - loss: 0.0578 - val_accuracy: 0.8108 - val_auc: 0.9776 - val_loss: 0.0696 - learning_rate: 1.0000e-05
# Epoch 14/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8491 - auc: 0.9868 - loss: 0.0478
# Epoch 14: val_auc did not improve from 0.97758
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 653s 3s/step - accuracy: 0.8491 - auc: 0.9868 - loss: 0.0478 - val_accuracy: 0.8028 - val_auc: 0.9772 - val_loss: 0.0708 - learning_rate: 1.0000e-05
# Epoch 15/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8585 - auc: 0.9886 - loss: 0.0458
# Epoch 15: val_auc did not improve from 0.97758
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 697s 3s/step - accuracy: 0.8585 - auc: 0.9886 - loss: 0.0458 - val_accuracy: 0.8128 - val_auc: 0.9772 - val_loss: 0.0739 - learning_rate: 1.0000e-05
# Epoch 16/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8721 - auc: 0.9909 - loss: 0.0399
# Epoch 16: val_auc improved from 0.97758 to 0.97943, saving model to resnet50_cbam_classificationhead_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 664s 3s/step - accuracy: 0.8721 - auc: 0.9909 - loss: 0.0399 - val_accuracy: 0.8243 - val_auc: 0.9794 - val_loss: 0.0749 - learning_rate: 1.0000e-05
# Epoch 17/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8870 - auc: 0.9925 - loss: 0.0368
# Epoch 17: val_auc improved from 0.97943 to 0.98102, saving model to resnet50_cbam_classificationhead_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 670s 3s/step - accuracy: 0.8870 - auc: 0.9925 - loss: 0.0368 - val_accuracy: 0.8362 - val_auc: 0.9810 - val_loss: 0.0702 - learning_rate: 1.0000e-05
# Epoch 18/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8884 - auc: 0.9925 - loss: 0.0351
# Epoch 18: val_auc did not improve from 0.98102
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 652s 3s/step - accuracy: 0.8884 - auc: 0.9925 - loss: 0.0351 - val_accuracy: 0.8333 - val_auc: 0.9803 - val_loss: 0.0713 - learning_rate: 1.0000e-05
# Epoch 19/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9034 - auc: 0.9934 - loss: 0.0312
# Epoch 19: val_auc did not improve from 0.98102
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 653s 3s/step - accuracy: 0.9034 - auc: 0.9934 - loss: 0.0312 - val_accuracy: 0.8093 - val_auc: 0.9757 - val_loss: 0.0810 - learning_rate: 1.0000e-05
# Epoch 20/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9099 - auc: 0.9952 - loss: 0.0261
# Epoch 20: val_auc improved from 0.98102 to 0.98180, saving model to resnet50_cbam_classificationhead_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 667s 3s/step - accuracy: 0.9098 - auc: 0.9952 - loss: 0.0261 - val_accuracy: 0.8392 - val_auc: 0.9818 - val_loss: 0.0676 - learning_rate: 1.0000e-05
# Epoch 21/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9186 - auc: 0.9956 - loss: 0.0245
# Epoch 21: val_auc did not improve from 0.98180
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 663s 3s/step - accuracy: 0.9185 - auc: 0.9956 - loss: 0.0245 - val_accuracy: 0.8362 - val_auc: 0.9797 - val_loss: 0.0746 - learning_rate: 1.0000e-05
# Epoch 22/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9243 - auc: 0.9962 - loss: 0.0228
# Epoch 22: val_auc did not improve from 0.98180
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 645s 3s/step - accuracy: 0.9243 - auc: 0.9962 - loss: 0.0228 - val_accuracy: 0.8412 - val_auc: 0.9798 - val_loss: 0.0742 - learning_rate: 1.0000e-05
# Epoch 23/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9296 - auc: 0.9968 - loss: 0.0204
# Epoch 23: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 23: val_auc did not improve from 0.98180
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 662s 3s/step - accuracy: 0.9296 - auc: 0.9968 - loss: 0.0204 - val_accuracy: 0.8303 - val_auc: 0.9779 - val_loss: 0.0828 - learning_rate: 1.0000e-05
# Epoch 24/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9373 - auc: 0.9973 - loss: 0.0175
# Epoch 24: val_auc did not improve from 0.98180
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 662s 3s/step - accuracy: 0.9373 - auc: 0.9973 - loss: 0.0175 - val_accuracy: 0.8318 - val_auc: 0.9778 - val_loss: 0.0811 - learning_rate: 1.0000e-06
# Epoch 25/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9413 - auc: 0.9977 - loss: 0.0161
# Epoch 25: val_auc did not improve from 0.98180
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 640s 3s/step - accuracy: 0.9413 - auc: 0.9977 - loss: 0.0161 - val_accuracy: 0.8397 - val_auc: 0.9787 - val_loss: 0.0790 - learning_rate: 1.0000e-06
# Epoch 26/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9443 - auc: 0.9978 - loss: 0.0160
# Epoch 26: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
#
# Epoch 26: val_auc did not improve from 0.98180
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 640s 3s/step - accuracy: 0.9443 - auc: 0.9978 - loss: 0.0160 - val_accuracy: 0.8357 - val_auc: 0.9791 - val_loss: 0.0799 - learning_rate: 1.0000e-06
# Epoch 27/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9435 - auc: 0.9978 - loss: 0.0162
# ...
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 220s 878ms/step - accuracy: 0.6692 - auc: 0.8884 - loss: 0.1771 - val_accuracy: 0.6680 - val_auc: 0.9012 - val_loss: 0.1657
# Epoch 10/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.6737 - auc: 0.8893 - loss: 0.1783
# Epoch 10: val_auc did not improve from 0.90122
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 220s 877ms/step - accuracy: 0.6737 - auc: 0.8893 - loss: 0.1783 - val_accuracy: 0.6680 - val_auc: 0.9007 - val_loss: 0.1653
# Epoch 11/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 711ms/step - accuracy: 0.6605 - auc: 0.8824 - loss: 0.1932
# Epoch 11: val_auc improved from 0.90122 to 0.90174, saving model to resnet50_cbam_classificationhead_fold5_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 222s 885ms/step - accuracy: 0.6606 - auc: 0.8824 - loss: 0.1931 - val_accuracy: 0.6695 - val_auc: 0.9017 - val_loss: 0.1639
# Epoch 12/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 712ms/step - accuracy: 0.6726 - auc: 0.8920 - loss: 0.1724
# Epoch 12: val_auc improved from 0.90174 to 0.90285, saving model to resnet50_cbam_classificationhead_fold5_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 223s 886ms/step - accuracy: 0.6726 - auc: 0.8920 - loss: 0.1725 - val_accuracy: 0.6705 - val_auc: 0.9029 - val_loss: 0.1682
# Epoch 13/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 710ms/step - accuracy: 0.6751 - auc: 0.8904 - loss: 0.1751
# Epoch 13: val_auc did not improve from 0.90285
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 222s 886ms/step - accuracy: 0.6751 - auc: 0.8904 - loss: 0.1751 - val_accuracy: 0.6705 - val_auc: 0.9024 - val_loss: 0.1644
# Epoch 14/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 712ms/step - accuracy: 0.6718 - auc: 0.8940 - loss: 0.1730
# Epoch 14: val_auc did not improve from 0.90285
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 222s 886ms/step - accuracy: 0.6718 - auc: 0.8940 - loss: 0.1730 - val_accuracy: 0.6725 - val_auc: 0.8986 - val_loss: 0.1605
# Epoch 15/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 705ms/step - accuracy: 0.6793 - auc: 0.8951 - loss: 0.1712
# Epoch 15: val_auc improved from 0.90285 to 0.90299, saving model to resnet50_cbam_classificationhead_fold5_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 220s 878ms/step - accuracy: 0.6793 - auc: 0.8951 - loss: 0.1712 - val_accuracy: 0.6750 - val_auc: 0.9030 - val_loss: 0.1597
# Epoch 16/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.6718 - auc: 0.8957 - loss: 0.1811
# Epoch 16: val_auc improved from 0.90299 to 0.90407, saving model to resnet50_cbam_classificationhead_fold5_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 221s 881ms/step - accuracy: 0.6718 - auc: 0.8957 - loss: 0.1811 - val_accuracy: 0.6765 - val_auc: 0.9041 - val_loss: 0.1576
# Epoch 17/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 710ms/step - accuracy: 0.6682 - auc: 0.8967 - loss: 0.1751
# Epoch 17: val_auc improved from 0.90407 to 0.90686, saving model to resnet50_cbam_classificationhead_fold5_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 222s 884ms/step - accuracy: 0.6682 - auc: 0.8967 - loss: 0.1751 - val_accuracy: 0.6775 - val_auc: 0.9069 - val_loss: 0.1579
# Epoch 18/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 714ms/step - accuracy: 0.6700 - auc: 0.8955 - loss: 0.1807
# Epoch 18: val_auc did not improve from 0.90686
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 223s 889ms/step - accuracy: 0.6700 - auc: 0.8955 - loss: 0.1807 - val_accuracy: 0.6765 - val_auc: 0.9057 - val_loss: 0.1561
# Epoch 19/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 706ms/step - accuracy: 0.6758 - auc: 0.9018 - loss: 0.1709
# Epoch 19: val_auc did not improve from 0.90686
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 221s 882ms/step - accuracy: 0.6758 - auc: 0.9018 - loss: 0.1709 - val_accuracy: 0.6765 - val_auc: 0.9059 - val_loss: 0.1579
# Epoch 20/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 709ms/step - accuracy: 0.6713 - auc: 0.8992 - loss: 0.1748
# Epoch 20: val_auc did not improve from 0.90686
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 222s 883ms/step - accuracy: 0.6713 - auc: 0.8992 - loss: 0.1748 - val_accuracy: 0.6770 - val_auc: 0.9063 - val_loss: 0.1577
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 17.
# Epoch 1/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6491 - auc: 0.8247 - loss: 1.0722
# Epoch 1: val_auc improved from -inf to 0.80721, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 645s 3s/step - accuracy: 0.6491 - auc: 0.8248 - loss: 1.0714 - val_accuracy: 0.6695 - val_auc: 0.8072 - val_loss: 1.3318 - learning_rate: 1.0000e-05
# Epoch 2/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6563 - auc: 0.8902 - loss: 0.5012
# Epoch 2: val_auc did not improve from 0.80721
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 634s 3s/step - accuracy: 0.6562 - auc: 0.8902 - loss: 0.5011 - val_accuracy: 0.6695 - val_auc: 0.8072 - val_loss: 1.3310 - learning_rate: 1.0000e-05
# Epoch 3/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6677 - auc: 0.9116 - loss: 0.3170
# Epoch 3: val_auc improved from 0.80721 to 0.81204, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 636s 3s/step - accuracy: 0.6676 - auc: 0.9117 - loss: 0.3169 - val_accuracy: 0.6695 - val_auc: 0.8120 - val_loss: 1.1543 - learning_rate: 1.0000e-05
# Epoch 4/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6844 - auc: 0.9277 - loss: 0.1998
# Epoch 4: val_auc improved from 0.81204 to 0.91658, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 636s 3s/step - accuracy: 0.6844 - auc: 0.9278 - loss: 0.1998 - val_accuracy: 0.6760 - val_auc: 0.9166 - val_loss: 0.2647 - learning_rate: 1.0000e-05
# Epoch 5/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7020 - auc: 0.9380 - loss: 0.1569
# Epoch 5: val_auc improved from 0.91658 to 0.95204, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 635s 3s/step - accuracy: 0.7020 - auc: 0.9380 - loss: 0.1569 - val_accuracy: 0.7459 - val_auc: 0.9520 - val_loss: 0.1221 - learning_rate: 1.0000e-05
# Epoch 6/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7185 - auc: 0.9471 - loss: 0.1376
# Epoch 6: val_auc improved from 0.95204 to 0.96083, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 645s 3s/step - accuracy: 0.7185 - auc: 0.9470 - loss: 0.1376 - val_accuracy: 0.7604 - val_auc: 0.9608 - val_loss: 0.1025 - learning_rate: 1.0000e-05
# Epoch 7/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7296 - auc: 0.9512 - loss: 0.1257
# Epoch 7: val_auc improved from 0.96083 to 0.96445, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 660s 3s/step - accuracy: 0.7296 - auc: 0.9512 - loss: 0.1257 - val_accuracy: 0.7703 - val_auc: 0.9645 - val_loss: 0.0953 - learning_rate: 1.0000e-05
# Epoch 8/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7370 - auc: 0.9542 - loss: 0.1218
# Epoch 8: val_auc improved from 0.96445 to 0.96660, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 646s 3s/step - accuracy: 0.7371 - auc: 0.9542 - loss: 0.1218 - val_accuracy: 0.7708 - val_auc: 0.9666 - val_loss: 0.0902 - learning_rate: 1.0000e-05
# Epoch 9/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7497 - auc: 0.9593 - loss: 0.1119
# Epoch 9: val_auc improved from 0.96660 to 0.96832, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 637s 3s/step - accuracy: 0.7497 - auc: 0.9593 - loss: 0.1119 - val_accuracy: 0.7813 - val_auc: 0.9683 - val_loss: 0.0863 - learning_rate: 1.0000e-05
# Epoch 10/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7611 - auc: 0.9613 - loss: 0.1078
# Epoch 10: val_auc improved from 0.96832 to 0.97078, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 635s 3s/step - accuracy: 0.7611 - auc: 0.9613 - loss: 0.1078 - val_accuracy: 0.7868 - val_auc: 0.9708 - val_loss: 0.0809 - learning_rate: 1.0000e-05
# Epoch 11/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7650 - auc: 0.9649 - loss: 0.0979
# Epoch 11: val_auc improved from 0.97078 to 0.97340, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 637s 3s/step - accuracy: 0.7650 - auc: 0.9649 - loss: 0.0979 - val_accuracy: 0.7993 - val_auc: 0.9734 - val_loss: 0.0760 - learning_rate: 1.0000e-05
# Epoch 12/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7737 - auc: 0.9666 - loss: 0.0983
# Epoch 12: val_auc improved from 0.97340 to 0.97509, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 640s 3s/step - accuracy: 0.7738 - auc: 0.9666 - loss: 0.0982 - val_accuracy: 0.8078 - val_auc: 0.9751 - val_loss: 0.0725 - learning_rate: 1.0000e-05
# Epoch 13/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7866 - auc: 0.9700 - loss: 0.0891
# Epoch 13: val_auc improved from 0.97509 to 0.97576, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 637s 3s/step - accuracy: 0.7866 - auc: 0.9700 - loss: 0.0891 - val_accuracy: 0.8088 - val_auc: 0.9758 - val_loss: 0.0709 - learning_rate: 1.0000e-05
# Epoch 14/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7996 - auc: 0.9734 - loss: 0.0812
# Epoch 14: val_auc improved from 0.97576 to 0.97674, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 636s 3s/step - accuracy: 0.7996 - auc: 0.9734 - loss: 0.0812 - val_accuracy: 0.8223 - val_auc: 0.9767 - val_loss: 0.0685 - learning_rate: 1.0000e-05
# Epoch 15/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8104 - auc: 0.9754 - loss: 0.0748
# Epoch 15: val_auc improved from 0.97674 to 0.97821, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 635s 3s/step - accuracy: 0.8104 - auc: 0.9754 - loss: 0.0748 - val_accuracy: 0.8168 - val_auc: 0.9782 - val_loss: 0.0660 - learning_rate: 1.0000e-05
# Epoch 16/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8077 - auc: 0.9771 - loss: 0.0717
# Epoch 16: val_auc improved from 0.97821 to 0.97875, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 637s 3s/step - accuracy: 0.8077 - auc: 0.9771 - loss: 0.0717 - val_accuracy: 0.8293 - val_auc: 0.9788 - val_loss: 0.0650 - learning_rate: 1.0000e-05
# Epoch 17/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8141 - auc: 0.9795 - loss: 0.0643
# Epoch 17: val_auc improved from 0.97875 to 0.97943, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 636s 3s/step - accuracy: 0.8141 - auc: 0.9795 - loss: 0.0643 - val_accuracy: 0.8233 - val_auc: 0.9794 - val_loss: 0.0646 - learning_rate: 1.0000e-05
# Epoch 18/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8263 - auc: 0.9816 - loss: 0.0605
# Epoch 18: val_auc did not improve from 0.97943
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 636s 3s/step - accuracy: 0.8263 - auc: 0.9816 - loss: 0.0605 - val_accuracy: 0.8218 - val_auc: 0.9777 - val_loss: 0.0675 - learning_rate: 1.0000e-05
# Epoch 19/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8377 - auc: 0.9834 - loss: 0.0575
# Epoch 19: val_auc did not improve from 0.97943
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 636s 3s/step - accuracy: 0.8377 - auc: 0.9834 - loss: 0.0574 - val_accuracy: 0.8198 - val_auc: 0.9762 - val_loss: 0.0700 - learning_rate: 1.0000e-05
# Epoch 20/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8384 - auc: 0.9846 - loss: 0.0536
# Epoch 20: val_auc improved from 0.97943 to 0.98046, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 638s 3s/step - accuracy: 0.8385 - auc: 0.9846 - loss: 0.0536 - val_accuracy: 0.8278 - val_auc: 0.9805 - val_loss: 0.0625 - learning_rate: 1.0000e-05
# Epoch 21/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8415 - auc: 0.9856 - loss: 0.0522
# Epoch 21: val_auc improved from 0.98046 to 0.98095, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 635s 3s/step - accuracy: 0.8415 - auc: 0.9856 - loss: 0.0522 - val_accuracy: 0.8303 - val_auc: 0.9809 - val_loss: 0.0607 - learning_rate: 1.0000e-05
# Epoch 22/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8671 - auc: 0.9878 - loss: 0.0473
# Epoch 22: val_auc did not improve from 0.98095
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 636s 3s/step - accuracy: 0.8671 - auc: 0.9878 - loss: 0.0473 - val_accuracy: 0.8298 - val_auc: 0.9809 - val_loss: 0.0630 - learning_rate: 1.0000e-05
# Epoch 23/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8668 - auc: 0.9881 - loss: 0.0451
# Epoch 23: val_auc improved from 0.98095 to 0.98247, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 636s 3s/step - accuracy: 0.8668 - auc: 0.9881 - loss: 0.0451 - val_accuracy: 0.8412 - val_auc: 0.9825 - val_loss: 0.0593 - learning_rate: 1.0000e-05
# Epoch 24/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8767 - auc: 0.9907 - loss: 0.0399
# Epoch 24: val_auc improved from 0.98247 to 0.98270, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 637s 3s/step - accuracy: 0.8767 - auc: 0.9907 - loss: 0.0399 - val_accuracy: 0.8457 - val_auc: 0.9827 - val_loss: 0.0606 - learning_rate: 1.0000e-05
# Epoch 25/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8799 - auc: 0.9911 - loss: 0.0371
# Epoch 25: val_auc did not improve from 0.98270
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 636s 3s/step - accuracy: 0.8799 - auc: 0.9911 - loss: 0.0371 - val_accuracy: 0.8417 - val_auc: 0.9812 - val_loss: 0.0640 - learning_rate: 1.0000e-05
# Epoch 26/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8958 - auc: 0.9923 - loss: 0.0345
# Epoch 26: val_auc did not improve from 0.98270
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 637s 3s/step - accuracy: 0.8958 - auc: 0.9923 - loss: 0.0345 - val_accuracy: 0.8432 - val_auc: 0.9801 - val_loss: 0.0687 - learning_rate: 1.0000e-05
# Epoch 27/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8977 - auc: 0.9930 - loss: 0.0320
# Epoch 27: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 27: val_auc did not improve from 0.98270
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 636s 3s/step - accuracy: 0.8977 - auc: 0.9930 - loss: 0.0320 - val_accuracy: 0.8412 - val_auc: 0.9817 - val_loss: 0.0631 - learning_rate: 1.0000e-05
# Epoch 28/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9070 - auc: 0.9941 - loss: 0.0291
# Epoch 28: val_auc did not improve from 0.98270
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 636s 3s/step - accuracy: 0.9070 - auc: 0.9941 - loss: 0.0291 - val_accuracy: 0.8342 - val_auc: 0.9808 - val_loss: 0.0656 - learning_rate: 1.0000e-06
# Epoch 29/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9077 - auc: 0.9949 - loss: 0.0251
# Epoch 29: val_auc did not improve from 0.98270
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 636s 3s/step - accuracy: 0.9077 - auc: 0.9949 - loss: 0.0251 - val_accuracy: 0.8407 - val_auc: 0.9816 - val_loss: 0.0638 - learning_rate: 1.0000e-06
# Epoch 30/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9091 - auc: 0.9944 - loss: 0.0276
# Epoch 30: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
#
# Epoch 30: val_auc did not improve from 0.98270
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 636s 3s/step - accuracy: 0.9091 - auc: 0.9944 - loss: 0.0276 - val_accuracy: 0.8422 - val_auc: 0.9811 - val_loss: 0.0658 - learning_rate: 1.0000e-06
# Epoch 31/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9111 - auc: 0.9950 - loss: 0.0246
# Epoch 31: val_auc did not improve from 0.98270
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 636s 3s/step - accuracy: 0.9111 - auc: 0.9950 - loss: 0.0246 - val_accuracy: 0.8402 - val_auc: 0.9807 - val_loss: 0.0674 - learning_rate: 1.0000e-07
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 24.
# FOLD 5 - Loss: 0.0606, Accuracy: 0.8457, AUC: 0.9827
#
# === CROSS-VALIDATION RESULTS ===
# Average Loss over 5 folds  : 0.0617 (± 0.0030)
# Average Accuracy over 5 folds: 0.8404 (± 0.0047)
# Average AUC over 5 folds     : 0.9822 (± 0.0011)
