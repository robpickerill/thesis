# %%
import os
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Layer, Reshape, Multiply, Conv2D, BatchNormalization, Activation, Add, Input, ZeroPadding2D, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import glorot_uniform
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.utils import register_keras_serializable


os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

tf.keras.mixed_precision.set_global_policy('mixed_float16')

# %%
base = '/Users/robp/scm/personal/github.com/robpickerill/thesis'
csv_file = os.path.join(base, 'ham10000_data/HAM10000_metadata.csv')
img_dir = os.path.join(base, 'ham10000_data/images')
file_ext = '.jpg'

df = pd.read_csv(csv_file)
df['image_path'] = df['image_id'].apply(lambda x: os.path.join(img_dir, x + file_ext))

print(df.head())
print(f"Total samples in dataset: {len(df)}")
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#                                           image_path
# 0  /Users/robp/scm/personal/github.com/robpickeri...
# 1  /Users/robp/scm/personal/github.com/robpickeri...
# 2  /Users/robp/scm/personal/github.com/robpickeri...
# 3  /Users/robp/scm/personal/github.com/robpickeri...
# 4  /Users/robp/scm/personal/github.com/robpickeri...
# Total samples in dataset: 10015

# %%
@register_keras_serializable(package="Custom")
class CBAM(Layer):
    """
    Convolutional Block Attention Module (CBAM)

    Reference: "CBAM: Convolutional Block Attention Module"
    (Woo et al., ECCV 2018) - https://arxiv.org/abs/1807.06521

    The CBAM block applies both Channel Attention and Spatial Attention
    to refine feature maps adaptively. It consists of two sequential sub-blocks:

    1. Channel Attention Module (CAM):
       - Uses both global average and max pooling operations to generate channel descriptors.
       - Passes them through a shared MLP to produce channel-wise weights.
       - The output is a channel attention map that emphasizes meaningful channels.

    2. Spatial Attention Module (SAM):
       - Uses average and max pooling along the channel dimension to produce spatial descriptors.
       - Applies a convolution (often 7x7) to produce a spatial attention map.
       - This map emphasizes "where" to focus within each channel.

    Parameters
    ----------
    reduction_ratio : int, optional (default=16)
        Reduction ratio for the internal MLP in the channel attention module.

    spatial_kernel_size : int, optional (default=7)
        The kernel size for the spatial attention convolution.
    """
    def __init__(self, reduction_ratio=16, spatial_kernel_size=7, name=None, **kwargs):
        super(CBAM, self).__init__(name=name, **kwargs)
        self.reduction_ratio = reduction_ratio
        self.spatial_kernel_size = spatial_kernel_size

    def build(self, input_shape):
        if len(input_shape) != 4:
            raise ValueError("CBAM input must be in the shape: (batch, height, width, channels)")

        channels = input_shape[-1]
        reduced_channels = max(channels // self.reduction_ratio, 1)

        # Shared MLP for channel attention
        # Two Dense layers: C -> C//r -> C
        self.mlp_dense_1 = Dense(units=reduced_channels,
                                        activation='relu',
                                        use_bias=True,
                                        name='channel_mlp_1')
        self.mlp_dense_2 = Dense(units=channels,
                                        use_bias=True,
                                        name='channel_mlp_2')

        # No weights needed to pre-build for the spatial attention layer
        # since we'll use a Conv2D layer directly on the fly.
        self.spatial_conv = Conv2D(filters=1,
                                          kernel_size=self.spatial_kernel_size,
                                          strides=1,
                                          padding='same',
                                          activation='sigmoid',
                                          use_bias=False,
                                          name='spatial_conv')

        super(CBAM, self).build(input_shape)

    def call(self, inputs, training=False):
        # ----- Channel Attention -----
        # Global average pooling
        avg_pool = tf.reduce_mean(inputs, axis=[1, 2], keepdims=False)  # (batch, C)
        # Global max pooling
        max_pool = tf.reduce_max(inputs, axis=[1, 2], keepdims=False)   # (batch, C)

        # Shared MLP transforms
        avg_out = self.mlp_dense_2(self.mlp_dense_1(avg_pool, training=training), training=training)
        max_out = self.mlp_dense_2(self.mlp_dense_1(max_pool, training=training), training=training)

        # Combine and apply sigmoid
        channel_attention = tf.nn.sigmoid(avg_out + max_out)  # (batch, C)

        # Reshape to broadcast
        channel_attention = tf.reshape(channel_attention, [-1, 1, 1, tf.shape(inputs)[-1]])
        channel_refined = inputs * channel_attention

        # ----- Spatial Attention -----
        # Avg and max along channel axis
        avg_spatial = tf.reduce_mean(channel_refined, axis=-1, keepdims=True)  # (batch, H, W, 1)
        max_spatial = tf.reduce_max(channel_refined, axis=-1, keepdims=True)   # (batch, H, W, 1)

        # Concatenate along channel axis
        spatial_concat = tf.concat([avg_spatial, max_spatial], axis=-1)  # (batch, H, W, 2)

        # Apply spatial conv
        spatial_attention = self.spatial_conv(spatial_concat, training=training)  # (batch, H, W, 1)

        # Refine features spatially
        refined_outputs = channel_refined * spatial_attention
        return refined_outputs

    def compute_output_shape(self, input_shape):
        return input_shape

    def get_config(self):
        config = super(CBAM, self).get_config()
        config.update({
            'reduction_ratio': self.reduction_ratio,
            'spatial_kernel_size': self.spatial_kernel_size
        })
        return config

# %%
def identity_block(input_tensor, kernel_size, filters, stage, block):
    bn_axis = 3
    filters1, filters2, filters3 = filters
    conv_name_base = f'conv{stage}_block{block}_'

    x = Conv2D(filters1, (1, 1),
               use_bias=True,
               kernel_initializer='he_normal',
               name=conv_name_base + '1_conv')(input_tensor)
    x = BatchNormalization(axis=bn_axis, epsilon=1.001e-5, name=conv_name_base + '1_bn')(x)
    x = Activation('relu', name=conv_name_base + '1_relu')(x)

    x = Conv2D(filters2, kernel_size,
               padding='same',
               use_bias=True,
               kernel_initializer='he_normal',
               name=conv_name_base + '2_conv')(x)
    x = BatchNormalization(axis=bn_axis, epsilon=1.001e-5, name=conv_name_base + '2_bn')(x)
    x = Activation('relu', name=conv_name_base + '2_relu')(x)

    x = Conv2D(filters3, (1, 1),
               use_bias=True,
               kernel_initializer='he_normal',
               name=conv_name_base + '3_conv')(x)
    x = BatchNormalization(axis=bn_axis, epsilon=1.001e-5, name=conv_name_base + '3_bn')(x)

    if stage == 5:
        x = CBAM()(x)

    x = Add(name=conv_name_base + 'add')([x, input_tensor])
    x = Activation('relu', name=conv_name_base + 'out')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, stage, block, strides=(2, 2)):
    bn_axis = 3
    filters1, filters2, filters3 = filters
    conv_name_base = f'conv{stage}_block{block}_'

    x = Conv2D(filters1, (1, 1), strides=strides,
               use_bias=True,
               kernel_initializer='he_normal',
               name=conv_name_base + '1_conv')(input_tensor)
    x = BatchNormalization(axis=bn_axis, epsilon=1.001e-5, name=conv_name_base + '1_bn')(x)
    x = Activation('relu', name=conv_name_base + '1_relu')(x)

    x = Conv2D(filters2, kernel_size, padding='same',
               use_bias=True,
               kernel_initializer='he_normal',
               name=conv_name_base + '2_conv')(x)
    x = BatchNormalization(axis=bn_axis, epsilon=1.001e-5, name=conv_name_base + '2_bn')(x)
    x = Activation('relu', name=conv_name_base + '2_relu')(x)

    x = Conv2D(filters3, (1, 1),
               use_bias=True,
               kernel_initializer='he_normal',
               name=conv_name_base + '3_conv')(x)
    x = BatchNormalization(axis=bn_axis, epsilon=1.001e-5, name=conv_name_base + '3_bn')(x)

    shortcut = Conv2D(filters3, (1, 1), strides=strides,
                      use_bias=True,
                      kernel_initializer='he_normal',
                      name=conv_name_base + '0_conv')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, epsilon=1.001e-5, name=conv_name_base + '0_bn')(shortcut)

    if stage == 5:
        x = CBAM()(x)

    x = Add(name=conv_name_base + 'add')([x, shortcut])
    x = Activation('relu', name=conv_name_base + 'out')(x)
    return x

def build_resnet50(input_shape, num_classes):
    inputs = Input(shape=input_shape, name='input_1')
    bn_axis = 3  # channels_last

    # Stage 1
    x = ZeroPadding2D(padding=(3, 3), name='conv1_pad')(inputs)
    x = Conv2D(64, (7, 7), strides=(2, 2),
               padding='valid', use_bias=True,
               kernel_initializer='he_normal',
               name='conv1_conv')(x)
    x = BatchNormalization(axis=bn_axis, epsilon=1.001e-5, name='conv1_bn')(x)
    x = Activation('relu', name='conv1_relu')(x)
    x = ZeroPadding2D(padding=(1, 1), name='pool1_pad')(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), name='pool1_pool')(x)

    # Stage 2
    x = conv_block(x, 3, [64, 64, 256], stage=2, block=1, strides=(1, 1))
    x = identity_block(x, 3, [64, 64, 256], stage=2, block=2)
    x = identity_block(x, 3, [64, 64, 256], stage=2, block=3)

    # Stage 3
    x = conv_block(x, 3, [128, 128, 512], stage=3, block=1)
    x = identity_block(x, 3, [128, 128, 512], stage=3, block=2)
    x = identity_block(x, 3, [128, 128, 512], stage=3, block=3)
    x = identity_block(x, 3, [128, 128, 512], stage=3, block=4)

    # Stage 4
    x = conv_block(x, 3, [256, 256, 1024], stage=4, block=1)
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block=2)
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block=3)
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block=4)
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block=5)
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block=6)

    # Stage 5
    x = conv_block(x, 3, [512, 512, 2048], stage=5, block=1)
    x = identity_block(x, 3, [512, 512, 2048], stage=5, block=2)
    x = identity_block(x, 3, [512, 512, 2048], stage=5, block=3)

    # Global Pooling & Classifier
    x = GlobalAveragePooling2D(name='avg_pool')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax', name='predictions')(x)

    model = Model(inputs, outputs, name='resnet50')
    return model

def transfer_weights(base_model, target_model):
    """
    Transfer weights from a Keras ResNet50 base_model into the custom ResNet50
    architecture whenever layer names match.
    """
    for layer in target_model.layers:
        try:
            pretrained_layer = base_model.get_layer(layer.name)
            layer.set_weights(pretrained_layer.get_weights())
        except Exception:
            # If layer doesn't exist in pretrained base, skip
            pass

# %%
def focal_loss(alpha=0.25, gamma=2.0):
    def focal_loss_fixed(y_true, y_pred):
        y_pred = tf.clip_by_value(y_pred, tf.keras.backend.epsilon(), 1. - tf.keras.backend.epsilon())
        cross_entropy = -y_true * tf.math.log(y_pred)
        weights = alpha * y_true * tf.math.pow((1 - y_pred), gamma)
        return tf.reduce_mean(tf.reduce_sum(weights * cross_entropy, axis=-1))
    return focal_loss_fixed

# %%
k_folds = 5
skf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=42)

# For tracking the best fold, to later evaluate performance
best_fold = None
best_auc_across_folds = 0.0

# For collecting metrics across folds
fold_accuracies = []
fold_aucs = []
fold_losses = []

# Epochs for each phase
EPOCHS_PHASE1 = 20   # Freeze the backbone
EPOCHS_PHASE2 = 200  # Fine-tuning

IMG_SIZE = 224
BATCH_SIZE = 32
NUM_CLASSES = 7

base_resnet50 = ResNet50(weights='imagenet', include_top=False, pooling=None)

# Data augmentation
datagen_train = ImageDataGenerator(
    rescale=1.0/255.0,
    rotation_range=5,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    brightness_range=[0.9, 1.1],
    horizontal_flip=True,
    fill_mode='nearest'
)
datagen_val = ImageDataGenerator(rescale=1.0/255.0)

# Get unique class labels (strings)
all_class_labels = sorted(df['dx'].unique())

# Compute global class weights for the entire dataset
class_weights_array = compute_class_weight(
    class_weight='balanced',
    classes=np.array(all_class_labels),
    y=df['dx'].values
)
# Map to dictionary: {class_index: weight}
class_weights_dict = {}
for label, w in zip(all_class_labels, class_weights_array):
    # Index of this label in the alphabetical-sorted list
    idx = all_class_labels.index(label)
    class_weights_dict[idx] = w
print("Class weights dict:", class_weights_dict)

fold_index = 1
for train_idx, val_idx in skf.split(df, df['dx']):
    print(f"\n\n===== FOLD {fold_index}/{k_folds} =====")

    # ------------------------------------------------------
    # 4.1) CREATE DATAFRAMES FOR THIS FOLD
    # ------------------------------------------------------
    train_df = df.iloc[train_idx].reset_index(drop=True)
    val_df = df.iloc[val_idx].reset_index(drop=True)

    print("Train size:", len(train_df), "Val size:", len(val_df))
    print("Train distribution:\n", train_df['dx'].value_counts())
    print("Val distribution:\n", val_df['dx'].value_counts())

    # ------------------------------------------------------
    # 4.2) FLOW FROM DATAFRAME: TRAIN & VAL
    # ------------------------------------------------------
    train_generator = datagen_train.flow_from_dataframe(
        dataframe=train_df,
        x_col='image_path',
        y_col='dx',
        target_size=(IMG_SIZE, IMG_SIZE),
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=True
    )
    val_generator = datagen_val.flow_from_dataframe(
        dataframe=val_df,
        x_col='image_path',
        y_col='dx',
        target_size=(IMG_SIZE, IMG_SIZE),
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=False
    )

    # Extract class names from the train_generator
    # The generator creates an internal mapping of classes -> indices
    class_names = list(train_generator.class_indices.keys())

    # ------------------------------------------------------
    # 4.3) BUILD & COMPILE MODEL FROM SCRATCH FOR EACH FOLD
    # ------------------------------------------------------
    custom_resnet = build_resnet50(input_shape=(IMG_SIZE, IMG_SIZE, 3), num_classes=NUM_CLASSES)
    # Transfer weights from base Keras ResNet50 (ImageNet) to custom ResNet
    transfer_weights(base_resnet50, custom_resnet)

    # Freeze layers in the main body
    for layer in custom_resnet.layers:
        if layer.name.startswith('conv'):
            layer.trainable = False
        else:
            layer.trainable = True

    custom_resnet.compile(
        optimizer=Adam(learning_rate=1e-3),
        loss=focal_loss(),
        metrics=['accuracy', tf.keras.metrics.AUC(name='auc')]
    )

    # ------------------------------------------------------
    # 4.4) CALLBACKS & TRAIN (PHASE 1)
    # ------------------------------------------------------
    model_path_phase1 = f"resnet50_cbam_stage5_fold{fold_index}_phase1.keras"
    callbacks_phase1 = [
        EarlyStopping(monitor='val_auc', patience=3, restore_best_weights=True, mode='max', verbose=1),
        ModelCheckpoint(model_path_phase1, monitor='val_auc', save_best_only=True, mode='max', verbose=1)
    ]

    history_phase1 = custom_resnet.fit(
        train_generator,
        validation_data=val_generator,
        epochs=EPOCHS_PHASE1,
        class_weight=class_weights_dict,
        callbacks=callbacks_phase1
    )

    # Load best weights from Phase 1
    custom_resnet.load_weights(model_path_phase1)

    # ------------------------------------------------------
    # 4.5) UNFREEZE & FINE-TUNING (PHASE 2)
    # ------------------------------------------------------
    for layer in custom_resnet.layers:
        layer.trainable = True

    custom_resnet.compile(
        optimizer=Adam(learning_rate=1e-5),
        loss=focal_loss(),
        metrics=['accuracy', tf.keras.metrics.AUC(name='auc')]
    )

    model_path_phase2 = f"resnet50_cbam_stage5_fold{fold_index}_phase2.keras"
    callbacks_phase2 = [
        ReduceLROnPlateau(monitor='val_auc', factor=0.1, patience=3, mode='max', verbose=1),
        EarlyStopping(monitor='val_auc', patience=7, restore_best_weights=True, mode='max', verbose=1),
        ModelCheckpoint(model_path_phase2, monitor='val_auc', save_best_only=True, mode='max', verbose=1)
    ]

    history_phase2 = custom_resnet.fit(
        train_generator,
        validation_data=val_generator,
        epochs=EPOCHS_PHASE2,
        class_weight=class_weights_dict,
        callbacks=callbacks_phase2
    )

    # Load best weights from Phase 2
    custom_resnet.load_weights(model_path_phase2)

    # ------------------------------------------------------
    # 4.6) EVALUATE ON THIS FOLD
    # ------------------------------------------------------
    loss, accuracy, auc_val = custom_resnet.evaluate(val_generator, verbose=0)
    print(f"FOLD {fold_index} - Loss: {loss:.4f}, Accuracy: {accuracy:.4f}, AUC: {auc_val:.4f}")

    fold_losses.append(loss)
    fold_accuracies.append(accuracy)
    fold_aucs.append(auc_val)

    # Check if this fold is the best so far
    if auc_val > best_auc_across_folds:
        best_auc_across_folds = auc_val
        best_fold = fold_index

    # Move to next fold
    fold_index += 1

# -------------------------------------------------------------------------
# 5) CROSS-VALIDATION RESULTS
# -------------------------------------------------------------------------
print("\n=== CROSS-VALIDATION RESULTS ===")
print(f"Average Loss over {k_folds} folds  : {np.mean(fold_losses):.4f} (± {np.std(fold_losses):.4f})")
print(f"Average Accuracy over {k_folds} folds: {np.mean(fold_accuracies):.4f} (± {np.std(fold_accuracies):.4f})")
print(f"Average AUC over {k_folds} folds     : {np.mean(fold_aucs):.4f} (± {np.std(fold_aucs):.4f})")
# Out:
# Class weights dict: {0: 4.375273044997815, 1: 2.78349082823791, 2: 1.301832835044846, 3: 12.440993788819876, 4: 1.2854575792581184, 5: 0.21338020666879728, 6: 10.075452716297788}
#
#
# ===== FOLD 1/5 =====
# Train size: 8012 Val size: 2003
# Train distribution:
#  dx
# nv       5364
# mel       890
# bkl       879
# bcc       411
# akiec     262
# vasc      114
# df         92
# Name: count, dtype: int64
# Val distribution:
#  dx
# nv       1341
# mel       223
# bkl       220
# bcc       103
# akiec      65
# vasc       28
# df         23
# Name: count, dtype: int64
# Found 8012 validated image filenames belonging to 7 classes.
# Found 2003 validated image filenames belonging to 7 classes.
# /Users/robp/scm/personal/github.com/robpickerill/thesis/.venv/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.6266 - auc: 0.8580 - loss: 0.2000
# Epoch 1: val_auc improved from -inf to 0.88516, saving model to resnet50_cbam_stage5_fold1_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 90s 334ms/step - accuracy: 0.6267 - auc: 0.8581 - loss: 0.2000 - val_accuracy: 0.6695 - val_auc: 0.8852 - val_loss: 0.1719
# Epoch 2/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.6724 - auc: 0.8738 - loss: 0.1863
# Epoch 2: val_auc improved from 0.88516 to 0.88757, saving model to resnet50_cbam_stage5_fold1_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 84s 332ms/step - accuracy: 0.6724 - auc: 0.8738 - loss: 0.1863 - val_accuracy: 0.6695 - val_auc: 0.8876 - val_loss: 0.1714
# Epoch 3/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.6723 - auc: 0.8734 - loss: 0.1940
# Epoch 3: val_auc improved from 0.88757 to 0.88857, saving model to resnet50_cbam_stage5_fold1_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 82s 325ms/step - accuracy: 0.6723 - auc: 0.8734 - loss: 0.1939 - val_accuracy: 0.6695 - val_auc: 0.8886 - val_loss: 0.1710
# Epoch 4/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.6541 - auc: 0.8660 - loss: 0.2125
# Epoch 4: val_auc improved from 0.88857 to 0.89137, saving model to resnet50_cbam_stage5_fold1_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 78s 312ms/step - accuracy: 0.6542 - auc: 0.8660 - loss: 0.2124 - val_accuracy: 0.6695 - val_auc: 0.8914 - val_loss: 0.1721
# Epoch 5/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.6654 - auc: 0.8716 - loss: 0.1958
# Epoch 5: val_auc improved from 0.89137 to 0.89238, saving model to resnet50_cbam_stage5_fold1_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 78s 310ms/step - accuracy: 0.6654 - auc: 0.8716 - loss: 0.1958 - val_accuracy: 0.6695 - val_auc: 0.8924 - val_loss: 0.1713
# Epoch 6/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.6596 - auc: 0.8728 - loss: 0.1954
# Epoch 6: val_auc did not improve from 0.89238
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 80s 318ms/step - accuracy: 0.6597 - auc: 0.8728 - loss: 0.1954 - val_accuracy: 0.6695 - val_auc: 0.8913 - val_loss: 0.1703
# Epoch 7/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.6706 - auc: 0.8765 - loss: 0.1918
# Epoch 7: val_auc did not improve from 0.89238
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 78s 310ms/step - accuracy: 0.6706 - auc: 0.8765 - loss: 0.1917 - val_accuracy: 0.6695 - val_auc: 0.8886 - val_loss: 0.1753
# Epoch 8/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.6659 - auc: 0.8761 - loss: 0.1846
# Epoch 8: val_auc improved from 0.89238 to 0.89384, saving model to resnet50_cbam_stage5_fold1_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 77s 305ms/step - accuracy: 0.6659 - auc: 0.8761 - loss: 0.1847 - val_accuracy: 0.6695 - val_auc: 0.8938 - val_loss: 0.1725
# Epoch 9/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.6730 - auc: 0.8811 - loss: 0.1751
# Epoch 9: val_auc improved from 0.89384 to 0.89423, saving model to resnet50_cbam_stage5_fold1_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 78s 308ms/step - accuracy: 0.6730 - auc: 0.8811 - loss: 0.1752 - val_accuracy: 0.6695 - val_auc: 0.8942 - val_loss: 0.1692
# Epoch 10/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.6685 - auc: 0.8742 - loss: 0.1956
# Epoch 10: val_auc improved from 0.89423 to 0.89733, saving model to resnet50_cbam_stage5_fold1_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 79s 313ms/step - accuracy: 0.6685 - auc: 0.8743 - loss: 0.1956 - val_accuracy: 0.6695 - val_auc: 0.8973 - val_loss: 0.1690
# Epoch 11/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.6721 - auc: 0.8791 - loss: 0.1842
# Epoch 11: val_auc improved from 0.89733 to 0.90117, saving model to resnet50_cbam_stage5_fold1_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 79s 314ms/step - accuracy: 0.6721 - auc: 0.8791 - loss: 0.1842 - val_accuracy: 0.6695 - val_auc: 0.9012 - val_loss: 0.1703
# Epoch 12/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.6699 - auc: 0.8800 - loss: 0.1910
# Epoch 12: val_auc did not improve from 0.90117
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 79s 312ms/step - accuracy: 0.6699 - auc: 0.8800 - loss: 0.1909 - val_accuracy: 0.6695 - val_auc: 0.8962 - val_loss: 0.1670
# Epoch 13/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.6610 - auc: 0.8818 - loss: 0.1805
# Epoch 13: val_auc did not improve from 0.90117
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 80s 317ms/step - accuracy: 0.6611 - auc: 0.8818 - loss: 0.1805 - val_accuracy: 0.6695 - val_auc: 0.8960 - val_loss: 0.1676
# Epoch 14/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.6660 - auc: 0.8791 - loss: 0.1858
# Epoch 14: val_auc improved from 0.90117 to 0.90160, saving model to resnet50_cbam_stage5_fold1_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 80s 319ms/step - accuracy: 0.6661 - auc: 0.8791 - loss: 0.1858 - val_accuracy: 0.6700 - val_auc: 0.9016 - val_loss: 0.1702
# Epoch 15/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.6712 - auc: 0.8814 - loss: 0.1823
# Epoch 15: val_auc did not improve from 0.90160
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 80s 317ms/step - accuracy: 0.6712 - auc: 0.8814 - loss: 0.1823 - val_accuracy: 0.6695 - val_auc: 0.8949 - val_loss: 0.1673
# Epoch 16/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.6635 - auc: 0.8786 - loss: 0.1910
# Epoch 16: val_auc did not improve from 0.90160
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 78s 311ms/step - accuracy: 0.6635 - auc: 0.8786 - loss: 0.1910 - val_accuracy: 0.6695 - val_auc: 0.8959 - val_loss: 0.1676
# Epoch 17/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.6674 - auc: 0.8813 - loss: 0.1831
# Epoch 17: val_auc did not improve from 0.90160
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 88s 351ms/step - accuracy: 0.6674 - auc: 0.8813 - loss: 0.1831 - val_accuracy: 0.6695 - val_auc: 0.9007 - val_loss: 0.1661
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Epoch 1/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6526 - auc: 0.8464 - loss: 0.8068
# Epoch 1: val_auc improved from -inf to 0.80721, saving model to resnet50_cbam_stage5_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 357s 1s/step - accuracy: 0.6526 - auc: 0.8465 - loss: 0.8061 - val_accuracy: 0.6695 - val_auc: 0.8072 - val_loss: 1.3318 - learning_rate: 1.0000e-05
# Epoch 2/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6433 - auc: 0.9032 - loss: 0.3764
# Epoch 2: val_auc did not improve from 0.80721
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 316s 1s/step - accuracy: 0.6434 - auc: 0.9032 - loss: 0.3762 - val_accuracy: 0.6695 - val_auc: 0.8072 - val_loss: 1.3318 - learning_rate: 1.0000e-05
# Epoch 3/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6857 - auc: 0.9265 - loss: 0.2296
# Epoch 3: val_auc improved from 0.80721 to 0.81054, saving model to resnet50_cbam_stage5_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 318s 1s/step - accuracy: 0.6857 - auc: 0.9265 - loss: 0.2295 - val_accuracy: 0.6705 - val_auc: 0.8105 - val_loss: 1.2632 - learning_rate: 1.0000e-05
# Epoch 4/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7055 - auc: 0.9435 - loss: 0.1509
# Epoch 4: val_auc improved from 0.81054 to 0.93355, saving model to resnet50_cbam_stage5_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 318s 1s/step - accuracy: 0.7056 - auc: 0.9435 - loss: 0.1509 - val_accuracy: 0.7159 - val_auc: 0.9335 - val_loss: 0.1576 - learning_rate: 1.0000e-05
# Epoch 5/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7437 - auc: 0.9571 - loss: 0.1151
# Epoch 5: val_auc improved from 0.93355 to 0.96633, saving model to resnet50_cbam_stage5_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 318s 1s/step - accuracy: 0.7437 - auc: 0.9571 - loss: 0.1151 - val_accuracy: 0.7728 - val_auc: 0.9663 - val_loss: 0.0932 - learning_rate: 1.0000e-05
# Epoch 6/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7691 - auc: 0.9656 - loss: 0.0954
# Epoch 6: val_auc improved from 0.96633 to 0.97359, saving model to resnet50_cbam_stage5_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 319s 1s/step - accuracy: 0.7690 - auc: 0.9656 - loss: 0.0954 - val_accuracy: 0.8008 - val_auc: 0.9736 - val_loss: 0.0768 - learning_rate: 1.0000e-05
# Epoch 7/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7789 - auc: 0.9688 - loss: 0.0921
# Epoch 7: val_auc improved from 0.97359 to 0.97585, saving model to resnet50_cbam_stage5_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 318s 1s/step - accuracy: 0.7789 - auc: 0.9688 - loss: 0.0921 - val_accuracy: 0.8068 - val_auc: 0.9759 - val_loss: 0.0715 - learning_rate: 1.0000e-05
# Epoch 8/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7863 - auc: 0.9704 - loss: 0.0848
# Epoch 8: val_auc improved from 0.97585 to 0.97714, saving model to resnet50_cbam_stage5_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 317s 1s/step - accuracy: 0.7863 - auc: 0.9704 - loss: 0.0848 - val_accuracy: 0.8133 - val_auc: 0.9771 - val_loss: 0.0675 - learning_rate: 1.0000e-05
# Epoch 9/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8124 - auc: 0.9767 - loss: 0.0713
# Epoch 9: val_auc improved from 0.97714 to 0.97873, saving model to resnet50_cbam_stage5_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 318s 1s/step - accuracy: 0.8124 - auc: 0.9767 - loss: 0.0713 - val_accuracy: 0.8138 - val_auc: 0.9787 - val_loss: 0.0640 - learning_rate: 1.0000e-05
# Epoch 10/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8197 - auc: 0.9794 - loss: 0.0646
# Epoch 10: val_auc improved from 0.97873 to 0.97909, saving model to resnet50_cbam_stage5_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 317s 1s/step - accuracy: 0.8197 - auc: 0.9794 - loss: 0.0646 - val_accuracy: 0.8213 - val_auc: 0.9791 - val_loss: 0.0625 - learning_rate: 1.0000e-05
# Epoch 11/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8138 - auc: 0.9784 - loss: 0.0679
# Epoch 11: val_auc improved from 0.97909 to 0.97960, saving model to resnet50_cbam_stage5_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 315s 1s/step - accuracy: 0.8138 - auc: 0.9784 - loss: 0.0679 - val_accuracy: 0.8218 - val_auc: 0.9796 - val_loss: 0.0613 - learning_rate: 1.0000e-05
# Epoch 12/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8310 - auc: 0.9812 - loss: 0.0623
# Epoch 12: val_auc improved from 0.97960 to 0.98087, saving model to resnet50_cbam_stage5_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 318s 1s/step - accuracy: 0.8311 - auc: 0.9812 - loss: 0.0623 - val_accuracy: 0.8357 - val_auc: 0.9809 - val_loss: 0.0590 - learning_rate: 1.0000e-05
# Epoch 13/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8397 - auc: 0.9840 - loss: 0.0538
# Epoch 13: val_auc did not improve from 0.98087
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 316s 1s/step - accuracy: 0.8397 - auc: 0.9840 - loss: 0.0538 - val_accuracy: 0.8342 - val_auc: 0.9801 - val_loss: 0.0609 - learning_rate: 1.0000e-05
# Epoch 14/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8514 - auc: 0.9863 - loss: 0.0494
# Epoch 14: val_auc did not improve from 0.98087
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 315s 1s/step - accuracy: 0.8514 - auc: 0.9863 - loss: 0.0494 - val_accuracy: 0.8238 - val_auc: 0.9800 - val_loss: 0.0599 - learning_rate: 1.0000e-05
# Epoch 15/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8537 - auc: 0.9868 - loss: 0.0471
# Epoch 15: val_auc improved from 0.98087 to 0.98336, saving model to resnet50_cbam_stage5_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 318s 1s/step - accuracy: 0.8537 - auc: 0.9868 - loss: 0.0471 - val_accuracy: 0.8407 - val_auc: 0.9834 - val_loss: 0.0557 - learning_rate: 1.0000e-05
# Epoch 16/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8609 - auc: 0.9871 - loss: 0.0490
# Epoch 16: val_auc did not improve from 0.98336
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 317s 1s/step - accuracy: 0.8609 - auc: 0.9871 - loss: 0.0489 - val_accuracy: 0.8268 - val_auc: 0.9804 - val_loss: 0.0610 - learning_rate: 1.0000e-05
# Epoch 17/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8741 - auc: 0.9901 - loss: 0.0391
# Epoch 17: val_auc did not improve from 0.98336
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 313s 1s/step - accuracy: 0.8741 - auc: 0.9901 - loss: 0.0391 - val_accuracy: 0.8362 - val_auc: 0.9815 - val_loss: 0.0581 - learning_rate: 1.0000e-05
# Epoch 18/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8806 - auc: 0.9909 - loss: 0.0361
# Epoch 18: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 18: val_auc did not improve from 0.98336
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 319s 1s/step - accuracy: 0.8805 - auc: 0.9909 - loss: 0.0361 - val_accuracy: 0.8347 - val_auc: 0.9829 - val_loss: 0.0565 - learning_rate: 1.0000e-05
# Epoch 19/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8871 - auc: 0.9915 - loss: 0.0349
# Epoch 19: val_auc did not improve from 0.98336
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 312s 1s/step - accuracy: 0.8871 - auc: 0.9915 - loss: 0.0349 - val_accuracy: 0.8407 - val_auc: 0.9832 - val_loss: 0.0551 - learning_rate: 1.0000e-06
# Epoch 20/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8875 - auc: 0.9919 - loss: 0.0361
# Epoch 20: val_auc did not improve from 0.98336
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 315s 1s/step - accuracy: 0.8875 - auc: 0.9919 - loss: 0.0360 - val_accuracy: 0.8357 - val_auc: 0.9829 - val_loss: 0.0558 - learning_rate: 1.0000e-06
# Epoch 21/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8878 - auc: 0.9924 - loss: 0.0330
# Epoch 21: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
#
# Epoch 21: val_auc improved from 0.98336 to 0.98346, saving model to resnet50_cbam_stage5_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 317s 1s/step - accuracy: 0.8878 - auc: 0.9924 - loss: 0.0330 - val_accuracy: 0.8407 - val_auc: 0.9835 - val_loss: 0.0549 - learning_rate: 1.0000e-06
# Epoch 22/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8960 - auc: 0.9932 - loss: 0.0278
# Epoch 22: val_auc did not improve from 0.98346
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 315s 1s/step - accuracy: 0.8960 - auc: 0.9932 - loss: 0.0278 - val_accuracy: 0.8432 - val_auc: 0.9834 - val_loss: 0.0547 - learning_rate: 1.0000e-07
# Epoch 23/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8951 - auc: 0.9929 - loss: 0.0309
# Epoch 23: val_auc did not improve from 0.98346
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 314s 1s/step - accuracy: 0.8951 - auc: 0.9929 - loss: 0.0309 - val_accuracy: 0.8407 - val_auc: 0.9830 - val_loss: 0.0552 - learning_rate: 1.0000e-07
# Epoch 24/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8973 - auc: 0.9930 - loss: 0.0313
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
#
# Epoch 24: val_auc did not improve from 0.98346
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 315s 1s/step - accuracy: 0.8973 - auc: 0.9930 - loss: 0.0313 - val_accuracy: 0.8397 - val_auc: 0.9829 - val_loss: 0.0553 - learning_rate: 1.0000e-07
# Epoch 25/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8950 - auc: 0.9932 - loss: 0.0301
# Epoch 25: val_auc did not improve from 0.98346
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 314s 1s/step - accuracy: 0.8950 - auc: 0.9932 - loss: 0.0301 - val_accuracy: 0.8422 - val_auc: 0.9832 - val_loss: 0.0550 - learning_rate: 1.0000e-08
# Epoch 26/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8977 - auc: 0.9929 - loss: 0.0320
# Epoch 26: val_auc did not improve from 0.98346
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 314s 1s/step - accuracy: 0.8977 - auc: 0.9929 - loss: 0.0320 - val_accuracy: 0.8397 - val_auc: 0.9831 - val_loss: 0.0553 - learning_rate: 1.0000e-08
# Epoch 27/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8942 - auc: 0.9933 - loss: 0.0302
# Epoch 27: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
#
# Epoch 27: val_auc did not improve from 0.98346
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 315s 1s/step - accuracy: 0.8942 - auc: 0.9933 - loss: 0.0302 - val_accuracy: 0.8382 - val_auc: 0.9828 - val_loss: 0.0554 - learning_rate: 1.0000e-08
# Epoch 28/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9006 - auc: 0.9932 - loss: 0.0309
# Epoch 28: val_auc did not improve from 0.98346
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 315s 1s/step - accuracy: 0.9006 - auc: 0.9932 - loss: 0.0309 - val_accuracy: 0.8407 - val_auc: 0.9829 - val_loss: 0.0552 - learning_rate: 1.0000e-09
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 21.
# FOLD 1 - Loss: 0.0549, Accuracy: 0.8407, AUC: 0.9835
#
#
# ===== FOLD 2/5 =====
# Train size: 8012 Val size: 2003
# Train distribution:
#  dx
# nv       5364
# mel       890
# bkl       879
# bcc       411
# akiec     262
# vasc      114
# df         92
# Name: count, dtype: int64
# Val distribution:
#  dx
# nv       1341
# mel       223
# bkl       220
# bcc       103
# akiec      65
# vasc       28
# df         23
# Name: count, dtype: int64
# Found 8012 validated image filenames belonging to 7 classes.
# Found 2003 validated image filenames belonging to 7 classes.
# /Users/robp/scm/personal/github.com/robpickerill/thesis/.venv/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.6275 - auc: 0.8524 - loss: 0.2260
# Epoch 1: val_auc improved from -inf to 0.88546, saving model to resnet50_cbam_stage5_fold2_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 89s 332ms/step - accuracy: 0.6276 - auc: 0.8525 - loss: 0.2259 - val_accuracy: 0.6695 - val_auc: 0.8855 - val_loss: 0.1724
# Epoch 2/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.6767 - auc: 0.8766 - loss: 0.1843
# Epoch 2: val_auc improved from 0.88546 to 0.88702, saving model to resnet50_cbam_stage5_fold2_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 79s 316ms/step - accuracy: 0.6767 - auc: 0.8766 - loss: 0.1844 - val_accuracy: 0.6695 - val_auc: 0.8870 - val_loss: 0.1763
# Epoch 3/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.6683 - auc: 0.8709 - loss: 0.1966
# Epoch 3: val_auc improved from 0.88702 to 0.88814, saving model to resnet50_cbam_stage5_fold2_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 79s 312ms/step - accuracy: 0.6683 - auc: 0.8709 - loss: 0.1966 - val_accuracy: 0.6695 - val_auc: 0.8881 - val_loss: 0.1757
# Epoch 4/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.6652 - auc: 0.8763 - loss: 0.1848
# Epoch 4: val_auc improved from 0.88814 to 0.89586, saving model to resnet50_cbam_stage5_fold2_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 78s 310ms/step - accuracy: 0.6652 - auc: 0.8763 - loss: 0.1848 - val_accuracy: 0.6695 - val_auc: 0.8959 - val_loss: 0.1713
# Epoch 5/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.6679 - auc: 0.8751 - loss: 0.1844
# Epoch 5: val_auc did not improve from 0.89586
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 77s 307ms/step - accuracy: 0.6679 - auc: 0.8751 - loss: 0.1844 - val_accuracy: 0.6695 - val_auc: 0.8866 - val_loss: 0.1772
# Epoch 6/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.6765 - auc: 0.8806 - loss: 0.1744
# Epoch 6: val_auc did not improve from 0.89586
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 77s 307ms/step - accuracy: 0.6765 - auc: 0.8806 - loss: 0.1744 - val_accuracy: 0.6695 - val_auc: 0.8932 - val_loss: 0.1706
# Epoch 7/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.6817 - auc: 0.8823 - loss: 0.1717
# Epoch 7: val_auc did not improve from 0.89586
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 77s 306ms/step - accuracy: 0.6816 - auc: 0.8823 - loss: 0.1717 - val_accuracy: 0.6695 - val_auc: 0.8912 - val_loss: 0.1741
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Epoch 1/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6500 - auc: 0.8676 - loss: 0.4388
# Epoch 1: val_auc improved from -inf to 0.80721, saving model to resnet50_cbam_stage5_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 350s 1s/step - accuracy: 0.6500 - auc: 0.8677 - loss: 0.4383 - val_accuracy: 0.6695 - val_auc: 0.8072 - val_loss: 1.3318 - learning_rate: 1.0000e-05
# Epoch 2/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6756 - auc: 0.9266 - loss: 0.1874
# Epoch 2: val_auc did not improve from 0.80721
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 319s 1s/step - accuracy: 0.6756 - auc: 0.9266 - loss: 0.1873 - val_accuracy: 0.6695 - val_auc: 0.8071 - val_loss: 1.3235 - learning_rate: 1.0000e-05
# Epoch 3/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7139 - auc: 0.9511 - loss: 0.1207
# Epoch 3: val_auc improved from 0.80721 to 0.81828, saving model to resnet50_cbam_stage5_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 323s 1s/step - accuracy: 0.7139 - auc: 0.9511 - loss: 0.1208 - val_accuracy: 0.6695 - val_auc: 0.8183 - val_loss: 1.0321 - learning_rate: 1.0000e-05
# Epoch 4/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7511 - auc: 0.9613 - loss: 0.1013
# Epoch 4: val_auc improved from 0.81828 to 0.94568, saving model to resnet50_cbam_stage5_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 320s 1s/step - accuracy: 0.7511 - auc: 0.9613 - loss: 0.1013 - val_accuracy: 0.7344 - val_auc: 0.9457 - val_loss: 0.1275 - learning_rate: 1.0000e-05
# Epoch 5/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7753 - auc: 0.9693 - loss: 0.0862
# Epoch 5: val_auc improved from 0.94568 to 0.97436, saving model to resnet50_cbam_stage5_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 320s 1s/step - accuracy: 0.7753 - auc: 0.9693 - loss: 0.0862 - val_accuracy: 0.7998 - val_auc: 0.9744 - val_loss: 0.0754 - learning_rate: 1.0000e-05
# Epoch 6/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8040 - auc: 0.9769 - loss: 0.0686
# Epoch 6: val_auc improved from 0.97436 to 0.97918, saving model to resnet50_cbam_stage5_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 322s 1s/step - accuracy: 0.8040 - auc: 0.9769 - loss: 0.0686 - val_accuracy: 0.8233 - val_auc: 0.9792 - val_loss: 0.0632 - learning_rate: 1.0000e-05
# Epoch 7/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8069 - auc: 0.9776 - loss: 0.0683
# Epoch 7: val_auc improved from 0.97918 to 0.98079, saving model to resnet50_cbam_stage5_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 328s 1s/step - accuracy: 0.8070 - auc: 0.9776 - loss: 0.0683 - val_accuracy: 0.8298 - val_auc: 0.9808 - val_loss: 0.0602 - learning_rate: 1.0000e-05
# Epoch 8/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8090 - auc: 0.9794 - loss: 0.0693
# Epoch 8: val_auc improved from 0.98079 to 0.98211, saving model to resnet50_cbam_stage5_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 323s 1s/step - accuracy: 0.8091 - auc: 0.9794 - loss: 0.0693 - val_accuracy: 0.8328 - val_auc: 0.9821 - val_loss: 0.0569 - learning_rate: 1.0000e-05
# Epoch 9/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8376 - auc: 0.9839 - loss: 0.0564
# Epoch 9: val_auc did not improve from 0.98211
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 322s 1s/step - accuracy: 0.8376 - auc: 0.9839 - loss: 0.0564 - val_accuracy: 0.8108 - val_auc: 0.9793 - val_loss: 0.0625 - learning_rate: 1.0000e-05
# Epoch 10/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8485 - auc: 0.9859 - loss: 0.0506
# Epoch 10: val_auc improved from 0.98211 to 0.98274, saving model to resnet50_cbam_stage5_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 322s 1s/step - accuracy: 0.8485 - auc: 0.9859 - loss: 0.0506 - val_accuracy: 0.8333 - val_auc: 0.9827 - val_loss: 0.0573 - learning_rate: 1.0000e-05
# Epoch 11/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8510 - auc: 0.9870 - loss: 0.0456
# Epoch 11: val_auc did not improve from 0.98274
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 326s 1s/step - accuracy: 0.8510 - auc: 0.9870 - loss: 0.0456 - val_accuracy: 0.8248 - val_auc: 0.9823 - val_loss: 0.0596 - learning_rate: 1.0000e-05
# Epoch 12/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8679 - auc: 0.9893 - loss: 0.0430
# Epoch 12: val_auc improved from 0.98274 to 0.98289, saving model to resnet50_cbam_stage5_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 325s 1s/step - accuracy: 0.8679 - auc: 0.9893 - loss: 0.0430 - val_accuracy: 0.8328 - val_auc: 0.9829 - val_loss: 0.0579 - learning_rate: 1.0000e-05
# Epoch 13/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8725 - auc: 0.9907 - loss: 0.0393
# Epoch 13: val_auc did not improve from 0.98289
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 327s 1s/step - accuracy: 0.8725 - auc: 0.9907 - loss: 0.0393 - val_accuracy: 0.8303 - val_auc: 0.9817 - val_loss: 0.0613 - learning_rate: 1.0000e-05
# Epoch 14/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8867 - auc: 0.9923 - loss: 0.0336
# Epoch 14: val_auc did not improve from 0.98289
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 345s 1s/step - accuracy: 0.8867 - auc: 0.9923 - loss: 0.0336 - val_accuracy: 0.7868 - val_auc: 0.9755 - val_loss: 0.0753 - learning_rate: 1.0000e-05
# Epoch 15/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8966 - auc: 0.9934 - loss: 0.0313
# Epoch 15: val_auc improved from 0.98289 to 0.98329, saving model to resnet50_cbam_stage5_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 346s 1s/step - accuracy: 0.8966 - auc: 0.9934 - loss: 0.0313 - val_accuracy: 0.8387 - val_auc: 0.9833 - val_loss: 0.0608 - learning_rate: 1.0000e-05
# Epoch 16/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9094 - auc: 0.9945 - loss: 0.0261
# Epoch 16: val_auc did not improve from 0.98329
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 320s 1s/step - accuracy: 0.9094 - auc: 0.9945 - loss: 0.0261 - val_accuracy: 0.8108 - val_auc: 0.9783 - val_loss: 0.0744 - learning_rate: 1.0000e-05
# Epoch 17/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9075 - auc: 0.9948 - loss: 0.0257
# Epoch 17: val_auc did not improve from 0.98329
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 321s 1s/step - accuracy: 0.9075 - auc: 0.9948 - loss: 0.0257 - val_accuracy: 0.8138 - val_auc: 0.9769 - val_loss: 0.0800 - learning_rate: 1.0000e-05
# Epoch 18/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9199 - auc: 0.9959 - loss: 0.0219
# Epoch 18: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 18: val_auc did not improve from 0.98329
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 318s 1s/step - accuracy: 0.9199 - auc: 0.9959 - loss: 0.0219 - val_accuracy: 0.8238 - val_auc: 0.9794 - val_loss: 0.0717 - learning_rate: 1.0000e-05
# Epoch 19/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9274 - auc: 0.9962 - loss: 0.0214
# Epoch 19: val_auc did not improve from 0.98329
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 315s 1s/step - accuracy: 0.9274 - auc: 0.9962 - loss: 0.0214 - val_accuracy: 0.8238 - val_auc: 0.9803 - val_loss: 0.0699 - learning_rate: 1.0000e-06
# Epoch 20/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9328 - auc: 0.9968 - loss: 0.0195
# Epoch 20: val_auc did not improve from 0.98329
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 330s 1s/step - accuracy: 0.9328 - auc: 0.9968 - loss: 0.0195 - val_accuracy: 0.8208 - val_auc: 0.9792 - val_loss: 0.0732 - learning_rate: 1.0000e-06
# Epoch 21/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9355 - auc: 0.9970 - loss: 0.0183
# Epoch 21: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
#
# Epoch 21: val_auc did not improve from 0.98329
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 317s 1s/step - accuracy: 0.9355 - auc: 0.9970 - loss: 0.0183 - val_accuracy: 0.8273 - val_auc: 0.9794 - val_loss: 0.0735 - learning_rate: 1.0000e-06
# Epoch 22/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9252 - auc: 0.9967 - loss: 0.0202
# Epoch 22: val_auc did not improve from 0.98329
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 313s 1s/step - accuracy: 0.9252 - auc: 0.9967 - loss: 0.0202 - val_accuracy: 0.8253 - val_auc: 0.9795 - val_loss: 0.0735 - learning_rate: 1.0000e-07
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 15.
# FOLD 2 - Loss: 0.0608, Accuracy: 0.8387, AUC: 0.9833
#
#
# ===== FOLD 3/5 =====
# Train size: 8012 Val size: 2003
# Train distribution:
#  dx
# nv       5364
# mel       891
# bkl       879
# bcc       411
# akiec     262
# vasc      113
# df         92
# Name: count, dtype: int64
# Val distribution:
#  dx
# nv       1341
# mel       222
# bkl       220
# bcc       103
# akiec      65
# vasc       29
# df         23
# Name: count, dtype: int64
# Found 8012 validated image filenames belonging to 7 classes.
# Found 2003 validated image filenames belonging to 7 classes.
# /Users/robp/scm/personal/github.com/robpickerill/thesis/.venv/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.6225 - auc: 0.8482 - loss: 0.2173
# Epoch 1: val_auc improved from -inf to 0.88426, saving model to resnet50_cbam_stage5_fold3_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 91s 333ms/step - accuracy: 0.6226 - auc: 0.8483 - loss: 0.2172 - val_accuracy: 0.6695 - val_auc: 0.8843 - val_loss: 0.1730
# Epoch 2/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.6695 - auc: 0.8742 - loss: 0.1873
# Epoch 2: val_auc improved from 0.88426 to 0.88632, saving model to resnet50_cbam_stage5_fold3_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 78s 309ms/step - accuracy: 0.6695 - auc: 0.8742 - loss: 0.1873 - val_accuracy: 0.6695 - val_auc: 0.8863 - val_loss: 0.1742
# Epoch 3/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.6771 - auc: 0.8798 - loss: 0.1756
# Epoch 3: val_auc improved from 0.88632 to 0.88866, saving model to resnet50_cbam_stage5_fold3_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 80s 317ms/step - accuracy: 0.6770 - auc: 0.8798 - loss: 0.1757 - val_accuracy: 0.6695 - val_auc: 0.8887 - val_loss: 0.1728
# Epoch 4/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.6604 - auc: 0.8743 - loss: 0.1878
# Epoch 4: val_auc improved from 0.88866 to 0.89054, saving model to resnet50_cbam_stage5_fold3_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 80s 317ms/step - accuracy: 0.6604 - auc: 0.8743 - loss: 0.1878 - val_accuracy: 0.6695 - val_auc: 0.8905 - val_loss: 0.1757
# Epoch 5/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.6739 - auc: 0.8790 - loss: 0.1752
# Epoch 5: val_auc did not improve from 0.89054
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 80s 317ms/step - accuracy: 0.6739 - auc: 0.8790 - loss: 0.1752 - val_accuracy: 0.6695 - val_auc: 0.8880 - val_loss: 0.1712
# Epoch 6/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.6745 - auc: 0.8789 - loss: 0.1810
# Epoch 6: val_auc improved from 0.89054 to 0.89061, saving model to resnet50_cbam_stage5_fold3_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 81s 321ms/step - accuracy: 0.6745 - auc: 0.8789 - loss: 0.1810 - val_accuracy: 0.6695 - val_auc: 0.8906 - val_loss: 0.1711
# Epoch 7/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.6741 - auc: 0.8790 - loss: 0.1820
# Epoch 7: val_auc improved from 0.89061 to 0.89946, saving model to resnet50_cbam_stage5_fold3_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 80s 316ms/step - accuracy: 0.6741 - auc: 0.8789 - loss: 0.1820 - val_accuracy: 0.6695 - val_auc: 0.8995 - val_loss: 0.1710
# Epoch 8/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.6717 - auc: 0.8785 - loss: 0.1834
# Epoch 8: val_auc did not improve from 0.89946
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 82s 328ms/step - accuracy: 0.6717 - auc: 0.8785 - loss: 0.1834 - val_accuracy: 0.6695 - val_auc: 0.8923 - val_loss: 0.1703
# Epoch 9/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.6660 - auc: 0.8750 - loss: 0.1907
# Epoch 9: val_auc did not improve from 0.89946
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 78s 309ms/step - accuracy: 0.6660 - auc: 0.8750 - loss: 0.1907 - val_accuracy: 0.6695 - val_auc: 0.8930 - val_loss: 0.1698
# Epoch 10/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.6655 - auc: 0.8795 - loss: 0.1845
# Epoch 10: val_auc did not improve from 0.89946
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 77s 308ms/step - accuracy: 0.6655 - auc: 0.8795 - loss: 0.1845 - val_accuracy: 0.6695 - val_auc: 0.8966 - val_loss: 0.1707
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Epoch 1/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6486 - auc: 0.8628 - loss: 0.4562
# Epoch 1: val_auc improved from -inf to 0.80721, saving model to resnet50_cbam_stage5_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 405s 1s/step - accuracy: 0.6486 - auc: 0.8629 - loss: 0.4558 - val_accuracy: 0.6695 - val_auc: 0.8072 - val_loss: 1.3318 - learning_rate: 1.0000e-05
# Epoch 2/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6762 - auc: 0.9252 - loss: 0.1964
# Epoch 2: val_auc improved from 0.80721 to 0.80733, saving model to resnet50_cbam_stage5_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 339s 1s/step - accuracy: 0.6762 - auc: 0.9252 - loss: 0.1963 - val_accuracy: 0.6695 - val_auc: 0.8073 - val_loss: 1.3259 - learning_rate: 1.0000e-05
# Epoch 3/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7374 - auc: 0.9554 - loss: 0.1157
# Epoch 3: val_auc improved from 0.80733 to 0.81584, saving model to resnet50_cbam_stage5_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 330s 1s/step - accuracy: 0.7374 - auc: 0.9554 - loss: 0.1157 - val_accuracy: 0.6685 - val_auc: 0.8158 - val_loss: 1.1209 - learning_rate: 1.0000e-05
# Epoch 4/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7521 - auc: 0.9617 - loss: 0.1038
# Epoch 4: val_auc improved from 0.81584 to 0.93744, saving model to resnet50_cbam_stage5_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 341s 1s/step - accuracy: 0.7521 - auc: 0.9617 - loss: 0.1038 - val_accuracy: 0.6940 - val_auc: 0.9374 - val_loss: 0.1386 - learning_rate: 1.0000e-05
# Epoch 5/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7884 - auc: 0.9716 - loss: 0.0806
# Epoch 5: val_auc improved from 0.93744 to 0.97113, saving model to resnet50_cbam_stage5_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 346s 1s/step - accuracy: 0.7884 - auc: 0.9715 - loss: 0.0806 - val_accuracy: 0.7913 - val_auc: 0.9711 - val_loss: 0.0828 - learning_rate: 1.0000e-05
# Epoch 6/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7916 - auc: 0.9743 - loss: 0.0730
# Epoch 6: val_auc improved from 0.97113 to 0.97525, saving model to resnet50_cbam_stage5_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 326s 1s/step - accuracy: 0.7916 - auc: 0.9743 - loss: 0.0730 - val_accuracy: 0.8138 - val_auc: 0.9753 - val_loss: 0.0711 - learning_rate: 1.0000e-05
# Epoch 7/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8252 - auc: 0.9799 - loss: 0.0642
# Epoch 7: val_auc improved from 0.97525 to 0.97675, saving model to resnet50_cbam_stage5_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 339s 1s/step - accuracy: 0.8252 - auc: 0.9799 - loss: 0.0642 - val_accuracy: 0.8103 - val_auc: 0.9768 - val_loss: 0.0684 - learning_rate: 1.0000e-05
# Epoch 8/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8329 - auc: 0.9820 - loss: 0.0604
# Epoch 8: val_auc did not improve from 0.97675
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 332s 1s/step - accuracy: 0.8329 - auc: 0.9820 - loss: 0.0604 - val_accuracy: 0.8063 - val_auc: 0.9752 - val_loss: 0.0716 - learning_rate: 1.0000e-05
# Epoch 9/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8428 - auc: 0.9835 - loss: 0.0536
# Epoch 9: val_auc improved from 0.97675 to 0.97738, saving model to resnet50_cbam_stage5_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 325s 1s/step - accuracy: 0.8428 - auc: 0.9835 - loss: 0.0536 - val_accuracy: 0.8173 - val_auc: 0.9774 - val_loss: 0.0661 - learning_rate: 1.0000e-05
# Epoch 10/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8518 - auc: 0.9861 - loss: 0.0526
# Epoch 10: val_auc did not improve from 0.97738
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 332s 1s/step - accuracy: 0.8518 - auc: 0.9861 - loss: 0.0525 - val_accuracy: 0.8028 - val_auc: 0.9749 - val_loss: 0.0699 - learning_rate: 1.0000e-05
# Epoch 11/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8601 - auc: 0.9873 - loss: 0.0451
# Epoch 11: val_auc improved from 0.97738 to 0.97819, saving model to resnet50_cbam_stage5_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 331s 1s/step - accuracy: 0.8601 - auc: 0.9873 - loss: 0.0451 - val_accuracy: 0.8223 - val_auc: 0.9782 - val_loss: 0.0658 - learning_rate: 1.0000e-05
# Epoch 12/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8658 - auc: 0.9879 - loss: 0.0455
# Epoch 12: val_auc did not improve from 0.97819
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 360s 1s/step - accuracy: 0.8658 - auc: 0.9879 - loss: 0.0455 - val_accuracy: 0.8198 - val_auc: 0.9768 - val_loss: 0.0680 - learning_rate: 1.0000e-05
# Epoch 13/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8710 - auc: 0.9892 - loss: 0.0422
# Epoch 13: val_auc improved from 0.97819 to 0.97927, saving model to resnet50_cbam_stage5_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 348s 1s/step - accuracy: 0.8710 - auc: 0.9892 - loss: 0.0422 - val_accuracy: 0.8313 - val_auc: 0.9793 - val_loss: 0.0639 - learning_rate: 1.0000e-05
# Epoch 14/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8965 - auc: 0.9917 - loss: 0.0341
# Epoch 14: val_auc did not improve from 0.97927
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 326s 1s/step - accuracy: 0.8964 - auc: 0.9917 - loss: 0.0341 - val_accuracy: 0.8168 - val_auc: 0.9765 - val_loss: 0.0709 - learning_rate: 1.0000e-05
# Epoch 15/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8968 - auc: 0.9933 - loss: 0.0306
# Epoch 15: val_auc did not improve from 0.97927
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 339s 1s/step - accuracy: 0.8968 - auc: 0.9933 - loss: 0.0306 - val_accuracy: 0.8053 - val_auc: 0.9773 - val_loss: 0.0699 - learning_rate: 1.0000e-05
# Epoch 16/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8973 - auc: 0.9933 - loss: 0.0313
# Epoch 16: val_auc improved from 0.97927 to 0.98013, saving model to resnet50_cbam_stage5_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 331s 1s/step - accuracy: 0.8973 - auc: 0.9933 - loss: 0.0313 - val_accuracy: 0.8397 - val_auc: 0.9801 - val_loss: 0.0638 - learning_rate: 1.0000e-05
# Epoch 17/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9013 - auc: 0.9940 - loss: 0.0295
# Epoch 17: val_auc did not improve from 0.98013
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 339s 1s/step - accuracy: 0.9013 - auc: 0.9940 - loss: 0.0295 - val_accuracy: 0.8303 - val_auc: 0.9791 - val_loss: 0.0692 - learning_rate: 1.0000e-05
# Epoch 18/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9074 - auc: 0.9946 - loss: 0.0263
# Epoch 18: val_auc did not improve from 0.98013
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 357s 1s/step - accuracy: 0.9074 - auc: 0.9946 - loss: 0.0263 - val_accuracy: 0.8298 - val_auc: 0.9788 - val_loss: 0.0714 - learning_rate: 1.0000e-05
# Epoch 19/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9103 - auc: 0.9950 - loss: 0.0250
# Epoch 19: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 19: val_auc did not improve from 0.98013
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 346s 1s/step - accuracy: 0.9103 - auc: 0.9950 - loss: 0.0250 - val_accuracy: 0.8113 - val_auc: 0.9761 - val_loss: 0.0775 - learning_rate: 1.0000e-05
# Epoch 20/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9203 - auc: 0.9960 - loss: 0.0217
# Epoch 20: val_auc did not improve from 0.98013
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 335s 1s/step - accuracy: 0.9203 - auc: 0.9960 - loss: 0.0217 - val_accuracy: 0.8253 - val_auc: 0.9788 - val_loss: 0.0728 - learning_rate: 1.0000e-06
# Epoch 21/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9268 - auc: 0.9963 - loss: 0.0213
# Epoch 21: val_auc did not improve from 0.98013
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 386s 2s/step - accuracy: 0.9268 - auc: 0.9963 - loss: 0.0213 - val_accuracy: 0.8243 - val_auc: 0.9791 - val_loss: 0.0725 - learning_rate: 1.0000e-06
# Epoch 22/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9347 - auc: 0.9969 - loss: 0.0191
# Epoch 22: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
#
# Epoch 22: val_auc did not improve from 0.98013
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 376s 1s/step - accuracy: 0.9347 - auc: 0.9969 - loss: 0.0191 - val_accuracy: 0.8288 - val_auc: 0.9796 - val_loss: 0.0717 - learning_rate: 1.0000e-06
# Epoch 23/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9347 - auc: 0.9970 - loss: 0.0184
# Epoch 23: val_auc did not improve from 0.98013
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 391s 2s/step - accuracy: 0.9347 - auc: 0.9970 - loss: 0.0184 - val_accuracy: 0.8263 - val_auc: 0.9791 - val_loss: 0.0728 - learning_rate: 1.0000e-07
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 16.
# FOLD 3 - Loss: 0.0638, Accuracy: 0.8397, AUC: 0.9801
#
#
# ===== FOLD 4/5 =====
# Train size: 8012 Val size: 2003
# Train distribution:
#  dx
# nv       5364
# mel       891
# bkl       879
# bcc       412
# akiec     261
# vasc      113
# df         92
# Name: count, dtype: int64
# Val distribution:
#  dx
# nv       1341
# mel       222
# bkl       220
# bcc       102
# akiec      66
# vasc       29
# df         23
# Name: count, dtype: int64
# Found 8012 validated image filenames belonging to 7 classes.
# Found 2003 validated image filenames belonging to 7 classes.
# /Users/robp/scm/personal/github.com/robpickerill/thesis/.venv/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.6421 - auc: 0.8524 - loss: 0.2103
# Epoch 1: val_auc improved from -inf to 0.88405, saving model to resnet50_cbam_stage5_fold4_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 128s 383ms/step - accuracy: 0.6421 - auc: 0.8524 - loss: 0.2103 - val_accuracy: 0.6695 - val_auc: 0.8840 - val_loss: 0.1733
# Epoch 2/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.6671 - auc: 0.8732 - loss: 0.1846
# Epoch 2: val_auc improved from 0.88405 to 0.88719, saving model to resnet50_cbam_stage5_fold4_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 85s 338ms/step - accuracy: 0.6671 - auc: 0.8732 - loss: 0.1847 - val_accuracy: 0.6695 - val_auc: 0.8872 - val_loss: 0.1733
# Epoch 3/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.6660 - auc: 0.8748 - loss: 0.1871
# Epoch 3: val_auc improved from 0.88719 to 0.88837, saving model to resnet50_cbam_stage5_fold4_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 84s 335ms/step - accuracy: 0.6660 - auc: 0.8748 - loss: 0.1871 - val_accuracy: 0.6695 - val_auc: 0.8884 - val_loss: 0.1734
# Epoch 4/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.6781 - auc: 0.8790 - loss: 0.1785
# Epoch 4: val_auc improved from 0.88837 to 0.88975, saving model to resnet50_cbam_stage5_fold4_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 87s 345ms/step - accuracy: 0.6781 - auc: 0.8790 - loss: 0.1785 - val_accuracy: 0.6695 - val_auc: 0.8897 - val_loss: 0.1721
# Epoch 5/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.6674 - auc: 0.8790 - loss: 0.1792
# Epoch 5: val_auc improved from 0.88975 to 0.89103, saving model to resnet50_cbam_stage5_fold4_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 89s 355ms/step - accuracy: 0.6674 - auc: 0.8790 - loss: 0.1792 - val_accuracy: 0.6695 - val_auc: 0.8910 - val_loss: 0.1709
# Epoch 6/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.6778 - auc: 0.8752 - loss: 0.1862
# Epoch 6: val_auc did not improve from 0.89103
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 91s 363ms/step - accuracy: 0.6777 - auc: 0.8752 - loss: 0.1862 - val_accuracy: 0.6695 - val_auc: 0.8903 - val_loss: 0.1718
# Epoch 7/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.6719 - auc: 0.8774 - loss: 0.1826
# Epoch 7: val_auc improved from 0.89103 to 0.89225, saving model to resnet50_cbam_stage5_fold4_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 87s 347ms/step - accuracy: 0.6719 - auc: 0.8774 - loss: 0.1826 - val_accuracy: 0.6695 - val_auc: 0.8923 - val_loss: 0.1698
# Epoch 8/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.6660 - auc: 0.8747 - loss: 0.1927
# Epoch 8: val_auc did not improve from 0.89225
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 86s 343ms/step - accuracy: 0.6660 - auc: 0.8748 - loss: 0.1927 - val_accuracy: 0.6695 - val_auc: 0.8911 - val_loss: 0.1720
# Epoch 9/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.6709 - auc: 0.8788 - loss: 0.1831
# Epoch 9: val_auc improved from 0.89225 to 0.89484, saving model to resnet50_cbam_stage5_fold4_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 87s 345ms/step - accuracy: 0.6709 - auc: 0.8788 - loss: 0.1831 - val_accuracy: 0.6695 - val_auc: 0.8948 - val_loss: 0.1701
# Epoch 10/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.6729 - auc: 0.8807 - loss: 0.1798
# Epoch 10: val_auc did not improve from 0.89484
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 81s 323ms/step - accuracy: 0.6729 - auc: 0.8807 - loss: 0.1799 - val_accuracy: 0.6695 - val_auc: 0.8922 - val_loss: 0.1707
# Epoch 11/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.6666 - auc: 0.8792 - loss: 0.1842
# Epoch 11: val_auc did not improve from 0.89484
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 80s 320ms/step - accuracy: 0.6666 - auc: 0.8792 - loss: 0.1842 - val_accuracy: 0.6695 - val_auc: 0.8913 - val_loss: 0.1697
# Epoch 12/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.6768 - auc: 0.8808 - loss: 0.1821
# Epoch 12: val_auc did not improve from 0.89484
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 83s 330ms/step - accuracy: 0.6768 - auc: 0.8808 - loss: 0.1822 - val_accuracy: 0.6695 - val_auc: 0.8932 - val_loss: 0.1697
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Epoch 1/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5859 - auc: 0.8615 - loss: 0.4136
# Epoch 1: val_auc improved from -inf to 0.80721, saving model to resnet50_cbam_stage5_fold4_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 384s 1s/step - accuracy: 0.5860 - auc: 0.8616 - loss: 0.4134 - val_accuracy: 0.6695 - val_auc: 0.8072 - val_loss: 1.3318 - learning_rate: 1.0000e-05
# Epoch 2/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6511 - auc: 0.9115 - loss: 0.2481
# Epoch 2: val_auc did not improve from 0.80721
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 341s 1s/step - accuracy: 0.6512 - auc: 0.9115 - loss: 0.2480 - val_accuracy: 0.6695 - val_auc: 0.8072 - val_loss: 1.3313 - learning_rate: 1.0000e-05
# Epoch 3/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6926 - auc: 0.9372 - loss: 0.1682
# Epoch 3: val_auc improved from 0.80721 to 0.81513, saving model to resnet50_cbam_stage5_fold4_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 371s 1s/step - accuracy: 0.6927 - auc: 0.9372 - loss: 0.1681 - val_accuracy: 0.6685 - val_auc: 0.8151 - val_loss: 1.1294 - learning_rate: 1.0000e-05
# Epoch 4/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7255 - auc: 0.9521 - loss: 0.1251
# Epoch 4: val_auc improved from 0.81513 to 0.94057, saving model to resnet50_cbam_stage5_fold4_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 363s 1s/step - accuracy: 0.7255 - auc: 0.9521 - loss: 0.1251 - val_accuracy: 0.7154 - val_auc: 0.9406 - val_loss: 0.1337 - learning_rate: 1.0000e-05
# Epoch 5/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7533 - auc: 0.9614 - loss: 0.1062
# ...
# Epoch 9/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8167 - auc: 0.9803 - loss: 0.0659
# Epoch 9: val_auc improved from 0.97904 to 0.97968, saving model to resnet50_cbam_stage5_fold4_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 371s 1s/step - accuracy: 0.8167 - auc: 0.9803 - loss: 0.0659 - val_accuracy: 0.8228 - val_auc: 0.9797 - val_loss: 0.0638 - learning_rate: 1.0000e-05
# Epoch 10/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8262 - auc: 0.9825 - loss: 0.0573
# Epoch 10: val_auc did not improve from 0.97968
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 367s 1s/step - accuracy: 0.8262 - auc: 0.9825 - loss: 0.0573 - val_accuracy: 0.8268 - val_auc: 0.9794 - val_loss: 0.0629 - learning_rate: 1.0000e-05
# Epoch 11/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8438 - auc: 0.9852 - loss: 0.0510
# Epoch 11: val_auc did not improve from 0.97968
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 373s 1s/step - accuracy: 0.8437 - auc: 0.9852 - loss: 0.0510 - val_accuracy: 0.8233 - val_auc: 0.9791 - val_loss: 0.0653 - learning_rate: 1.0000e-05
# Epoch 12/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8595 - auc: 0.9870 - loss: 0.0478
# Epoch 12: val_auc improved from 0.97968 to 0.98057, saving model to resnet50_cbam_stage5_fold4_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 368s 1s/step - accuracy: 0.8595 - auc: 0.9870 - loss: 0.0478 - val_accuracy: 0.8377 - val_auc: 0.9806 - val_loss: 0.0619 - learning_rate: 1.0000e-05
# Epoch 13/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8625 - auc: 0.9883 - loss: 0.0453
# Epoch 13: val_auc improved from 0.98057 to 0.98098, saving model to resnet50_cbam_stage5_fold4_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 345s 1s/step - accuracy: 0.8625 - auc: 0.9883 - loss: 0.0453 - val_accuracy: 0.8342 - val_auc: 0.9810 - val_loss: 0.0617 - learning_rate: 1.0000e-05
# Epoch 14/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8658 - auc: 0.9880 - loss: 0.0450
# Epoch 14: val_auc improved from 0.98098 to 0.98210, saving model to resnet50_cbam_stage5_fold4_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 332s 1s/step - accuracy: 0.8659 - auc: 0.9880 - loss: 0.0450 - val_accuracy: 0.8342 - val_auc: 0.9821 - val_loss: 0.0590 - learning_rate: 1.0000e-05
# Epoch 15/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8750 - auc: 0.9903 - loss: 0.0424
# Epoch 15: val_auc improved from 0.98210 to 0.98212, saving model to resnet50_cbam_stage5_fold4_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 324s 1s/step - accuracy: 0.8750 - auc: 0.9903 - loss: 0.0424 - val_accuracy: 0.8422 - val_auc: 0.9821 - val_loss: 0.0608 - learning_rate: 1.0000e-05
# Epoch 16/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8868 - auc: 0.9919 - loss: 0.0341
# Epoch 16: val_auc did not improve from 0.98212
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 325s 1s/step - accuracy: 0.8868 - auc: 0.9919 - loss: 0.0341 - val_accuracy: 0.8347 - val_auc: 0.9811 - val_loss: 0.0636 - learning_rate: 1.0000e-05
# Epoch 17/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8955 - auc: 0.9928 - loss: 0.0307
# Epoch 17: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 17: val_auc did not improve from 0.98212
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 324s 1s/step - accuracy: 0.8955 - auc: 0.9928 - loss: 0.0307 - val_accuracy: 0.8407 - val_auc: 0.9817 - val_loss: 0.0610 - learning_rate: 1.0000e-05
# Epoch 18/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9022 - auc: 0.9935 - loss: 0.0310
# Epoch 18: val_auc did not improve from 0.98212
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 319s 1s/step - accuracy: 0.9022 - auc: 0.9935 - loss: 0.0310 - val_accuracy: 0.8357 - val_auc: 0.9817 - val_loss: 0.0619 - learning_rate: 1.0000e-06
# Epoch 19/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9071 - auc: 0.9942 - loss: 0.0286
# Epoch 19: val_auc did not improve from 0.98212
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 328s 1s/step - accuracy: 0.9071 - auc: 0.9942 - loss: 0.0286 - val_accuracy: 0.8417 - val_auc: 0.9820 - val_loss: 0.0617 - learning_rate: 1.0000e-06
# Epoch 20/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9107 - auc: 0.9942 - loss: 0.0286
# Epoch 20: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
#
# Epoch 20: val_auc did not improve from 0.98212
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 327s 1s/step - accuracy: 0.9107 - auc: 0.9942 - loss: 0.0285 - val_accuracy: 0.8422 - val_auc: 0.9821 - val_loss: 0.0620 - learning_rate: 1.0000e-06
# Epoch 21/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9093 - auc: 0.9947 - loss: 0.0262
# Epoch 21: val_auc did not improve from 0.98212
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 322s 1s/step - accuracy: 0.9093 - auc: 0.9947 - loss: 0.0261 - val_accuracy: 0.8402 - val_auc: 0.9816 - val_loss: 0.0633 - learning_rate: 1.0000e-07
# Epoch 22/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9082 - auc: 0.9946 - loss: 0.0270
# Epoch 22: val_auc did not improve from 0.98212
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 324s 1s/step - accuracy: 0.9082 - auc: 0.9946 - loss: 0.0270 - val_accuracy: 0.8407 - val_auc: 0.9818 - val_loss: 0.0627 - learning_rate: 1.0000e-07
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 15.
# FOLD 4 - Loss: 0.0608, Accuracy: 0.8422, AUC: 0.9821
#
#
# ===== FOLD 5/5 =====
# Train size: 8012 Val size: 2003
# Train distribution:
#  dx
# nv       5364
# mel       890
# bkl       880
# bcc       411
# akiec     261
# vasc      114
# df         92
# Name: count, dtype: int64
# Val distribution:
#  dx
# nv       1341
# mel       223
# bkl       219
# bcc       103
# akiec      66
# vasc       28
# df         23
# Name: count, dtype: int64
# Found 8012 validated image filenames belonging to 7 classes.
# Found 2003 validated image filenames belonging to 7 classes.
# /Users/robp/scm/personal/github.com/robpickerill/thesis/.venv/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.6360 - auc: 0.8521 - loss: 0.2047
# Epoch 1: val_auc improved from -inf to 0.88187, saving model to resnet50_cbam_stage5_fold5_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 106s 380ms/step - accuracy: 0.6361 - auc: 0.8521 - loss: 0.2047 - val_accuracy: 0.6695 - val_auc: 0.8819 - val_loss: 0.1730
# Epoch 2/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.6693 - auc: 0.8685 - loss: 0.2000
# Epoch 2: val_auc improved from 0.88187 to 0.88996, saving model to resnet50_cbam_stage5_fold5_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 85s 336ms/step - accuracy: 0.6693 - auc: 0.8685 - loss: 0.2000 - val_accuracy: 0.6695 - val_auc: 0.8900 - val_loss: 0.1720
# Epoch 3/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.6626 - auc: 0.8694 - loss: 0.1936
# Epoch 3: val_auc improved from 0.88996 to 0.89192, saving model to resnet50_cbam_stage5_fold5_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 84s 334ms/step - accuracy: 0.6626 - auc: 0.8695 - loss: 0.1936 - val_accuracy: 0.6695 - val_auc: 0.8919 - val_loss: 0.1711
# Epoch 4/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.6685 - auc: 0.8720 - loss: 0.1954
# Epoch 4: val_auc did not improve from 0.89192
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 81s 324ms/step - accuracy: 0.6685 - auc: 0.8720 - loss: 0.1953 - val_accuracy: 0.6695 - val_auc: 0.8864 - val_loss: 0.1745
# Epoch 5/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.6613 - auc: 0.8732 - loss: 0.1899
# Epoch 5: val_auc improved from 0.89192 to 0.89375, saving model to resnet50_cbam_stage5_fold5_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 79s 313ms/step - accuracy: 0.6613 - auc: 0.8732 - loss: 0.1899 - val_accuracy: 0.6695 - val_auc: 0.8938 - val_loss: 0.1708
# Epoch 6/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.6798 - auc: 0.8828 - loss: 0.1739
# Epoch 6: val_auc did not improve from 0.89375
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 78s 311ms/step - accuracy: 0.6798 - auc: 0.8828 - loss: 0.1740 - val_accuracy: 0.6695 - val_auc: 0.8923 - val_loss: 0.1723
# Epoch 7/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.6711 - auc: 0.8790 - loss: 0.1805
# Epoch 7: val_auc did not improve from 0.89375
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 80s 318ms/step - accuracy: 0.6711 - auc: 0.8790 - loss: 0.1805 - val_accuracy: 0.6695 - val_auc: 0.8919 - val_loss: 0.1722
# Epoch 8/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.6676 - auc: 0.8781 - loss: 0.1775
# Epoch 8: val_auc did not improve from 0.89375
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 82s 328ms/step - accuracy: 0.6676 - auc: 0.8781 - loss: 0.1776 - val_accuracy: 0.6695 - val_auc: 0.8923 - val_loss: 0.1704
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Epoch 1/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6541 - auc: 0.8893 - loss: 0.3078
# Epoch 1: val_auc improved from -inf to 0.80721, saving model to resnet50_cbam_stage5_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 413s 1s/step - accuracy: 0.6541 - auc: 0.8894 - loss: 0.3076 - val_accuracy: 0.6695 - val_auc: 0.8072 - val_loss: 1.3073 - learning_rate: 1.0000e-05
# Epoch 2/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6859 - auc: 0.9314 - loss: 0.1658
# Epoch 2: val_auc improved from 0.80721 to 0.80754, saving model to resnet50_cbam_stage5_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 332s 1s/step - accuracy: 0.6859 - auc: 0.9314 - loss: 0.1658 - val_accuracy: 0.6695 - val_auc: 0.8075 - val_loss: 1.2583 - learning_rate: 1.0000e-05
# Epoch 3/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7159 - auc: 0.9472 - loss: 0.1360
# Epoch 3: val_auc improved from 0.80754 to 0.87789, saving model to resnet50_cbam_stage5_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 320s 1s/step - accuracy: 0.7159 - auc: 0.9472 - loss: 0.1360 - val_accuracy: 0.6700 - val_auc: 0.8779 - val_loss: 0.4689 - learning_rate: 1.0000e-05
# Epoch 4/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7489 - auc: 0.9616 - loss: 0.1021
# Epoch 4: val_auc improved from 0.87789 to 0.94386, saving model to resnet50_cbam_stage5_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 337s 1s/step - accuracy: 0.7489 - auc: 0.9616 - loss: 0.1021 - val_accuracy: 0.7294 - val_auc: 0.9439 - val_loss: 0.1366 - learning_rate: 1.0000e-05
# Epoch 5/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7687 - auc: 0.9684 - loss: 0.0909
# Epoch 5: val_auc improved from 0.94386 to 0.97596, saving model to resnet50_cbam_stage5_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 328s 1s/step - accuracy: 0.7687 - auc: 0.9684 - loss: 0.0909 - val_accuracy: 0.7998 - val_auc: 0.9760 - val_loss: 0.0718 - learning_rate: 1.0000e-05
# Epoch 6/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7893 - auc: 0.9735 - loss: 0.0770
# Epoch 6: val_auc improved from 0.97596 to 0.98064, saving model to resnet50_cbam_stage5_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 324s 1s/step - accuracy: 0.7893 - auc: 0.9735 - loss: 0.0770 - val_accuracy: 0.8278 - val_auc: 0.9806 - val_loss: 0.0610 - learning_rate: 1.0000e-05
# Epoch 7/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8088 - auc: 0.9783 - loss: 0.0691
# Epoch 7: val_auc improved from 0.98064 to 0.98078, saving model to resnet50_cbam_stage5_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 329s 1s/step - accuracy: 0.8088 - auc: 0.9783 - loss: 0.0691 - val_accuracy: 0.8168 - val_auc: 0.9808 - val_loss: 0.0601 - learning_rate: 1.0000e-05
# Epoch 8/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8212 - auc: 0.9812 - loss: 0.0600
# Epoch 8: val_auc did not improve from 0.98078
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 337s 1s/step - accuracy: 0.8212 - auc: 0.9812 - loss: 0.0600 - val_accuracy: 0.8223 - val_auc: 0.9806 - val_loss: 0.0600 - learning_rate: 1.0000e-05
# Epoch 9/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8360 - auc: 0.9824 - loss: 0.0606
# Epoch 9: val_auc improved from 0.98078 to 0.98308, saving model to resnet50_cbam_stage5_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 337s 1s/step - accuracy: 0.8360 - auc: 0.9824 - loss: 0.0606 - val_accuracy: 0.8298 - val_auc: 0.9831 - val_loss: 0.0562 - learning_rate: 1.0000e-05
# Epoch 10/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8445 - auc: 0.9850 - loss: 0.0516
# Epoch 10: val_auc did not improve from 0.98308
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 336s 1s/step - accuracy: 0.8445 - auc: 0.9850 - loss: 0.0516 - val_accuracy: 0.8143 - val_auc: 0.9808 - val_loss: 0.0597 - learning_rate: 1.0000e-05
# Epoch 11/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8495 - auc: 0.9866 - loss: 0.0484
# Epoch 11: val_auc did not improve from 0.98308
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 323s 1s/step - accuracy: 0.8495 - auc: 0.9866 - loss: 0.0484 - val_accuracy: 0.8158 - val_auc: 0.9810 - val_loss: 0.0596 - learning_rate: 1.0000e-05
# Epoch 12/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8609 - auc: 0.9882 - loss: 0.0437
# Epoch 12: val_auc improved from 0.98308 to 0.98415, saving model to resnet50_cbam_stage5_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 331s 1s/step - accuracy: 0.8609 - auc: 0.9882 - loss: 0.0437 - val_accuracy: 0.8377 - val_auc: 0.9841 - val_loss: 0.0559 - learning_rate: 1.0000e-05
# Epoch 13/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8698 - auc: 0.9902 - loss: 0.0382
# Epoch 13: val_auc did not improve from 0.98415
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 331s 1s/step - accuracy: 0.8698 - auc: 0.9902 - loss: 0.0382 - val_accuracy: 0.8328 - val_auc: 0.9829 - val_loss: 0.0575 - learning_rate: 1.0000e-05
# Epoch 14/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8900 - auc: 0.9922 - loss: 0.0347
# Epoch 14: val_auc did not improve from 0.98415
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 324s 1s/step - accuracy: 0.8900 - auc: 0.9922 - loss: 0.0347 - val_accuracy: 0.8233 - val_auc: 0.9817 - val_loss: 0.0608 - learning_rate: 1.0000e-05
# Epoch 15/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8975 - auc: 0.9934 - loss: 0.0315
# Epoch 15: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 15: val_auc did not improve from 0.98415
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 332s 1s/step - accuracy: 0.8974 - auc: 0.9934 - loss: 0.0315 - val_accuracy: 0.8367 - val_auc: 0.9836 - val_loss: 0.0577 - learning_rate: 1.0000e-05
# Epoch 16/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9081 - auc: 0.9949 - loss: 0.0247
# Epoch 16: val_auc did not improve from 0.98415
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 331s 1s/step - accuracy: 0.9081 - auc: 0.9949 - loss: 0.0247 - val_accuracy: 0.8308 - val_auc: 0.9827 - val_loss: 0.0586 - learning_rate: 1.0000e-06
# Epoch 17/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9108 - auc: 0.9946 - loss: 0.0245
# Epoch 17: val_auc did not improve from 0.98415
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 324s 1s/step - accuracy: 0.9108 - auc: 0.9946 - loss: 0.0245 - val_accuracy: 0.8318 - val_auc: 0.9829 - val_loss: 0.0587 - learning_rate: 1.0000e-06
# Epoch 18/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9053 - auc: 0.9947 - loss: 0.0260
# Epoch 18: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
#
# Epoch 18: val_auc did not improve from 0.98415
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 325s 1s/step - accuracy: 0.9053 - auc: 0.9947 - loss: 0.0260 - val_accuracy: 0.8298 - val_auc: 0.9829 - val_loss: 0.0583 - learning_rate: 1.0000e-06
# Epoch 19/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9102 - auc: 0.9948 - loss: 0.0265
# Epoch 19: val_auc did not improve from 0.98415
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 341s 1s/step - accuracy: 0.9102 - auc: 0.9948 - loss: 0.0265 - val_accuracy: 0.8248 - val_auc: 0.9825 - val_loss: 0.0592 - learning_rate: 1.0000e-07
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 12.
# FOLD 5 - Loss: 0.0559, Accuracy: 0.8377, AUC: 0.9841
#
# === CROSS-VALIDATION RESULTS ===
# Average Loss over 5 folds  : 0.0592 (± 0.0034)
# Average Accuracy over 5 folds: 0.8398 (± 0.0016)
# Average AUC over 5 folds     : 0.9826 (± 0.0014)

# %%
best_model_path = f"resnet50_fold{best_fold}_phase2.keras"

# -------------------------------------------------------------------------
# 6) EVALUATE BEST MODEL ON TEST SET
# -------------------------------------------------------------------------

# Load best model
best_model = tf.keras.models.load_model(best_model_path, compile=False)

# %%
# Classification report

# Get predictions
y_pred = np.argmax(best_model.predict(test_generator), axis=-1)
y_true = test_generator.classes

# Classification report
print("Classification Report:\n", classification_report(y_true, y_pred, target_names=class_names))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 # Classification report
#       2
#       3 # Get predictions
# ----> 4 y_pred = np.argmax(best_model.predict(test_generator), axis=-1)
#       5 y_true = test_generator.classes
#       7 # Classification report
#
# NameError: name 'test_generator' is not defined

# %%
# Confusion matrix
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
