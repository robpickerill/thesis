# %%
import os
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Layer, Reshape, Multiply, Conv2D, BatchNormalization, Activation, Add, Input, ZeroPadding2D, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import glorot_uniform
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.utils import register_keras_serializable


os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

tf.keras.mixed_precision.set_global_policy('mixed_float16')

# %%
base = '/Users/robp/scm/personal/github.com/robpickerill/thesis'
csv_file = os.path.join(base, 'ham10000_data/HAM10000_metadata.csv')
img_dir = os.path.join(base, 'ham10000_data/images')
file_ext = '.jpg'

df = pd.read_csv(csv_file)
df['image_path'] = df['image_id'].apply(lambda x: os.path.join(img_dir, x + file_ext))

print(df.head())
print(f"Total samples in dataset: {len(df)}")
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#                                           image_path
# 0  /Users/robp/scm/personal/github.com/robpickeri...
# 1  /Users/robp/scm/personal/github.com/robpickeri...
# 2  /Users/robp/scm/personal/github.com/robpickeri...
# 3  /Users/robp/scm/personal/github.com/robpickeri...
# 4  /Users/robp/scm/personal/github.com/robpickeri...
# Total samples in dataset: 10015

# %%
import tensorflow as tf
from tensorflow.keras import layers

class SEBlock(layers.Layer):
    """
    Squeeze-and-Excitation (SE) Block

    The SE block recalibrates channel-wise feature responses by explicitly modeling
    interdependencies between channels. Given an input feature map of shape
    (batch, height, width, channels), it:

    1. Squeezes global spatial information into a channel descriptor by using
       global average pooling.
    2. Excites each channel by passing this descriptor through a fully-connected
       bottleneck and expanding transformation, utilizing a sigmoid activation
       to generate channel-wise weights.
    3. Scales the original feature map by these learned weights,
       reinforcing channels that are relevant and suppressing those that are not.

    Parameters
    ----------
    reduction_ratio : int, optional (default=16)
        The reduction ratio used to compute the size of the bottleneck layer.
        For an input with `C` channels, the bottleneck layer will have
        `C // reduction_ratio` channels.

    name : str, optional
        String name for the layer.

    Attributes
    ----------
    fc1 : Dense layer
        The first fully connected layer that reduces the channel dimension.
    fc2 : Dense layer
        The second fully connected layer that expands back to the original channel dimension.
    """
    def __init__(self, reduction_ratio=16, name=None, **kwargs):
        super(SEBlock, self).__init__(name=name, **kwargs)
        self.reduction_ratio = reduction_ratio

    def build(self, input_shape):
        """
        Build the internal layers of the SE block. This method is called
        automatically once the shape of the inputs is known.

        Parameters
        ----------
        input_shape : TensorShape
            The shape of the input tensor. Typically (batch, height, width, channels).
        """
        if len(input_shape) != 4:
            raise ValueError("SEBlock only supports inputs with shape (batch, height, width, channels).")

        channels = input_shape[-1]
        reduced_channels = max(channels // self.reduction_ratio, 1)

        # First FC layer for reduction (C -> C//r)
        self.fc1 = layers.Dense(units=reduced_channels,
                                activation='relu',  # Non-linear activation
                                use_bias=True,
                                name='se_fc1')

        # Second FC layer to restore original dimension (C//r -> C)
        self.fc2 = layers.Dense(units=channels,
                                activation='sigmoid',  # Outputs channel-wise gating weights
                                use_bias=True,
                                name='se_fc2')

        super(SEBlock, self).build(input_shape)

    def call(self, inputs, training=False):
        """
        Forward pass of the SE block.

        Steps:
        1. Global average pooling to get channel-wise statistics of shape (batch, channels).
        2. Pass through the first FC layer (reduction).
        3. Pass through the second FC layer (expansion) with sigmoid activation to get weights.
        4. Reshape weights to (batch, 1, 1, channels) to match the input shape.
        5. Multiply the original inputs by these weights (channel-wise scaling).

        Parameters
        ----------
        inputs : tf.Tensor
            The input tensor with shape (batch, height, width, channels).

        training : bool, optional
            Specifies if the layer should behave in training mode or inference mode.
            This parameter can be used by certain layers that behave differently
            during training and inference.

        Returns
        -------
        tf.Tensor
            The output tensor with the same shape as `inputs`, after channel-wise rescaling.
        """
        # Step 1: Squeeze
        # Global average pooling: (batch, H, W, C) -> (batch, C)
        squeeze_tensor = tf.reduce_mean(inputs, axis=[1, 2], keepdims=False)

        # Step 2 & 3: Excitation
        # FC reduce: (batch, C) -> (batch, C//r)
        reduced = self.fc1(squeeze_tensor, training=training)
        # FC expand: (batch, C//r) -> (batch, C)
        excitation = self.fc2(reduced, training=training)

        # Reshape excitation to (batch, 1, 1, C) for broadcasting
        excitation = tf.reshape(excitation, [-1, 1, 1, tf.shape(inputs)[-1]])

        # Step 4: Scale
        # Scale input by the learned weights: (batch, H, W, C)
        scaled_inputs = inputs * excitation
        return scaled_inputs

    def compute_output_shape(self, input_shape):
        """
        Compute the output shape of the SE block. It remains the same as the input shape.

        Parameters
        ----------
        input_shape : Tuple[int]
            Shape of the input tensor.

        Returns
        -------
        Tuple[int]
            The output shape, identical to the input shape.
        """
        return input_shape

    def get_config(self):
        """
        Returns the configuration of the layer. This enables the layer
        to be serialized and deserialized, for example, when saving and loading models.

        Returns
        -------
        dict
            A dictionary containing the layer configuration.
        """
        config = super(SEBlock, self).get_config()
        config.update({
            'reduction_ratio': self.reduction_ratio
        })
        return config

# %%
def identity_block(input_tensor, kernel_size, filters, stage, block):
    bn_axis = 3
    filters1, filters2, filters3 = filters
    conv_name_base = f'conv{stage}_block{block}_'

    x = Conv2D(filters1, (1, 1),
               use_bias=True,
               kernel_initializer='he_normal',
               name=conv_name_base + '1_conv')(input_tensor)
    x = BatchNormalization(axis=bn_axis, epsilon=1.001e-5, name=conv_name_base + '1_bn')(x)
    x = Activation('relu', name=conv_name_base + '1_relu')(x)

    x = Conv2D(filters2, kernel_size,
               padding='same',
               use_bias=True,
               kernel_initializer='he_normal',
               name=conv_name_base + '2_conv')(x)
    x = BatchNormalization(axis=bn_axis, epsilon=1.001e-5, name=conv_name_base + '2_bn')(x)
    x = Activation('relu', name=conv_name_base + '2_relu')(x)

    x = Conv2D(filters3, (1, 1),
               use_bias=True,
               kernel_initializer='he_normal',
               name=conv_name_base + '3_conv')(x)
    x = BatchNormalization(axis=bn_axis, epsilon=1.001e-5, name=conv_name_base + '3_bn')(x)

    x = SEBlock()(x)

    x = Add(name=conv_name_base + 'add')([x, input_tensor])
    x = Activation('relu', name=conv_name_base + 'out')(x)
    return x

def conv_block(input_tensor, kernel_size, filters, stage, block, strides=(2, 2)):
    bn_axis = 3
    filters1, filters2, filters3 = filters
    conv_name_base = f'conv{stage}_block{block}_'

    x = Conv2D(filters1, (1, 1), strides=strides,
               use_bias=True,
               kernel_initializer='he_normal',
               name=conv_name_base + '1_conv')(input_tensor)
    x = BatchNormalization(axis=bn_axis, epsilon=1.001e-5, name=conv_name_base + '1_bn')(x)
    x = Activation('relu', name=conv_name_base + '1_relu')(x)

    x = Conv2D(filters2, kernel_size, padding='same',
               use_bias=True,
               kernel_initializer='he_normal',
               name=conv_name_base + '2_conv')(x)
    x = BatchNormalization(axis=bn_axis, epsilon=1.001e-5, name=conv_name_base + '2_bn')(x)
    x = Activation('relu', name=conv_name_base + '2_relu')(x)

    x = Conv2D(filters3, (1, 1),
               use_bias=True,
               kernel_initializer='he_normal',
               name=conv_name_base + '3_conv')(x)
    x = BatchNormalization(axis=bn_axis, epsilon=1.001e-5, name=conv_name_base + '3_bn')(x)

    shortcut = Conv2D(filters3, (1, 1), strides=strides,
                      use_bias=True,
                      kernel_initializer='he_normal',
                      name=conv_name_base + '0_conv')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, epsilon=1.001e-5, name=conv_name_base + '0_bn')(shortcut)

    x = SEBlock()(x)

    x = Add(name=conv_name_base + 'add')([x, shortcut])
    x = Activation('relu', name=conv_name_base + 'out')(x)
    return x

def build_resnet50(input_shape, num_classes):
    inputs = Input(shape=input_shape, name='input_1')
    bn_axis = 3  # channels_last

    # Stage 1
    x = ZeroPadding2D(padding=(3, 3), name='conv1_pad')(inputs)
    x = Conv2D(64, (7, 7), strides=(2, 2),
               padding='valid', use_bias=True,
               kernel_initializer='he_normal',
               name='conv1_conv')(x)
    x = BatchNormalization(axis=bn_axis, epsilon=1.001e-5, name='conv1_bn')(x)
    x = Activation('relu', name='conv1_relu')(x)
    x = ZeroPadding2D(padding=(1, 1), name='pool1_pad')(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), name='pool1_pool')(x)

    # Stage 2
    x = conv_block(x, 3, [64, 64, 256], stage=2, block=1, strides=(1, 1))
    x = identity_block(x, 3, [64, 64, 256], stage=2, block=2)
    x = identity_block(x, 3, [64, 64, 256], stage=2, block=3)

    # Stage 3
    x = conv_block(x, 3, [128, 128, 512], stage=3, block=1)
    x = identity_block(x, 3, [128, 128, 512], stage=3, block=2)
    x = identity_block(x, 3, [128, 128, 512], stage=3, block=3)
    x = identity_block(x, 3, [128, 128, 512], stage=3, block=4)

    # Stage 4
    x = conv_block(x, 3, [256, 256, 1024], stage=4, block=1)
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block=2)
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block=3)
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block=4)
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block=5)
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block=6)

    # Stage 5
    x = conv_block(x, 3, [512, 512, 2048], stage=5, block=1)
    x = identity_block(x, 3, [512, 512, 2048], stage=5, block=2)
    x = identity_block(x, 3, [512, 512, 2048], stage=5, block=3)

    # Global Pooling & Classifier
    x = GlobalAveragePooling2D(name='avg_pool')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax', name='predictions')(x)

    model = Model(inputs, outputs, name='resnet50')
    return model

def transfer_weights(base_model, target_model):
    """
    Transfer weights from a Keras ResNet50 base_model into the custom ResNet50
    architecture whenever layer names match.
    """
    for layer in target_model.layers:
        try:
            pretrained_layer = base_model.get_layer(layer.name)
            layer.set_weights(pretrained_layer.get_weights())
        except Exception:
            # If layer doesn't exist in pretrained base, skip
            pass

# %%
def focal_loss(alpha=0.25, gamma=2.0):
    def focal_loss_fixed(y_true, y_pred):
        y_pred = tf.clip_by_value(y_pred, tf.keras.backend.epsilon(), 1. - tf.keras.backend.epsilon())
        cross_entropy = -y_true * tf.math.log(y_pred)
        weights = alpha * y_true * tf.math.pow((1 - y_pred), gamma)
        return tf.reduce_mean(tf.reduce_sum(weights * cross_entropy, axis=-1))
    return focal_loss_fixed

# %%
k_folds = 5
skf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=42)

# For tracking the best fold, to later evaluate performance
best_fold = None
best_auc_across_folds = 0.0

# For collecting metrics across folds
fold_accuracies = []
fold_aucs = []
fold_losses = []

# Epochs for each phase
EPOCHS_PHASE1 = 20   # Freeze the backbone
EPOCHS_PHASE2 = 200  # Fine-tuning

IMG_SIZE = 224
BATCH_SIZE = 32
NUM_CLASSES = 7

base_resnet50 = ResNet50(weights='imagenet', include_top=False, pooling=None)

# Data augmentation
datagen_train = ImageDataGenerator(
    rescale=1.0/255.0,
    rotation_range=5,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    brightness_range=[0.9, 1.1],
    horizontal_flip=True,
    fill_mode='nearest'
)
datagen_val = ImageDataGenerator(rescale=1.0/255.0)

# Get unique class labels (strings)
all_class_labels = sorted(df['dx'].unique())

# Compute global class weights for the entire dataset
class_weights_array = compute_class_weight(
    class_weight='balanced',
    classes=np.array(all_class_labels),
    y=df['dx'].values
)
# Map to dictionary: {class_index: weight}
class_weights_dict = {}
for label, w in zip(all_class_labels, class_weights_array):
    # Index of this label in the alphabetical-sorted list
    idx = all_class_labels.index(label)
    class_weights_dict[idx] = w
print("Class weights dict:", class_weights_dict)

fold_index = 1
for train_idx, val_idx in skf.split(df, df['dx']):
    print(f"\n\n===== FOLD {fold_index}/{k_folds} =====")

    # ------------------------------------------------------
    # 4.1) CREATE DATAFRAMES FOR THIS FOLD
    # ------------------------------------------------------
    train_df = df.iloc[train_idx].reset_index(drop=True)
    val_df = df.iloc[val_idx].reset_index(drop=True)

    print("Train size:", len(train_df), "Val size:", len(val_df))
    print("Train distribution:\n", train_df['dx'].value_counts())
    print("Val distribution:\n", val_df['dx'].value_counts())

    # ------------------------------------------------------
    # 4.2) FLOW FROM DATAFRAME: TRAIN & VAL
    # ------------------------------------------------------
    train_generator = datagen_train.flow_from_dataframe(
        dataframe=train_df,
        x_col='image_path',
        y_col='dx',
        target_size=(IMG_SIZE, IMG_SIZE),
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=True
    )
    val_generator = datagen_val.flow_from_dataframe(
        dataframe=val_df,
        x_col='image_path',
        y_col='dx',
        target_size=(IMG_SIZE, IMG_SIZE),
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=False
    )

    # Extract class names from the train_generator
    # The generator creates an internal mapping of classes -> indices
    class_names = list(train_generator.class_indices.keys())

    # ------------------------------------------------------
    # 4.3) BUILD & COMPILE MODEL FROM SCRATCH FOR EACH FOLD
    # ------------------------------------------------------
    custom_resnet = build_resnet50(input_shape=(IMG_SIZE, IMG_SIZE, 3), num_classes=NUM_CLASSES)
    # Transfer weights from base Keras ResNet50 (ImageNet) to custom ResNet
    transfer_weights(base_resnet50, custom_resnet)

    # Freeze layers in the main body
    for layer in custom_resnet.layers:
        if layer.name.startswith('conv'):
            layer.trainable = False
        else:
            layer.trainable = True

    custom_resnet.compile(
        optimizer=Adam(learning_rate=1e-3),
        loss=focal_loss(),
        metrics=['accuracy', tf.keras.metrics.AUC(name='auc')]
    )

    # ------------------------------------------------------
    # 4.4) CALLBACKS & TRAIN (PHASE 1)
    # ------------------------------------------------------
    model_path_phase1 = f"resnet50_cbam_classificationhead_fold{fold_index}_phase1.keras"
    callbacks_phase1 = [
        EarlyStopping(monitor='val_auc', patience=3, restore_best_weights=True, mode='max', verbose=1),
        ModelCheckpoint(model_path_phase1, monitor='val_auc', save_best_only=True, mode='max', verbose=1)
    ]

    history_phase1 = custom_resnet.fit(
        train_generator,
        validation_data=val_generator,
        epochs=EPOCHS_PHASE1,
        class_weight=class_weights_dict,
        callbacks=callbacks_phase1
    )

    # Load best weights from Phase 1
    custom_resnet.load_weights(model_path_phase1)

    # ------------------------------------------------------
    # 4.5) UNFREEZE & FINE-TUNING (PHASE 2)
    # ------------------------------------------------------
    for layer in custom_resnet.layers:
        layer.trainable = True

    custom_resnet.compile(
        optimizer=Adam(learning_rate=1e-5),
        loss=focal_loss(),
        metrics=['accuracy', tf.keras.metrics.AUC(name='auc')]
    )

    model_path_phase2 = f"resnet50_cbam_classificationhead_fold{fold_index}_phase2.keras"
    callbacks_phase2 = [
        ReduceLROnPlateau(monitor='val_auc', factor=0.1, patience=3, mode='max', verbose=1),
        EarlyStopping(monitor='val_auc', patience=7, restore_best_weights=True, mode='max', verbose=1),
        ModelCheckpoint(model_path_phase2, monitor='val_auc', save_best_only=True, mode='max', verbose=1)
    ]

    history_phase2 = custom_resnet.fit(
        train_generator,
        validation_data=val_generator,
        epochs=EPOCHS_PHASE2,
        class_weight=class_weights_dict,
        callbacks=callbacks_phase2
    )

    # Load best weights from Phase 2
    custom_resnet.load_weights(model_path_phase2)

    # ------------------------------------------------------
    # 4.6) EVALUATE ON THIS FOLD
    # ------------------------------------------------------
    loss, accuracy, auc_val = custom_resnet.evaluate(val_generator, verbose=0)
    print(f"FOLD {fold_index} - Loss: {loss:.4f}, Accuracy: {accuracy:.4f}, AUC: {auc_val:.4f}")

    fold_losses.append(loss)
    fold_accuracies.append(accuracy)
    fold_aucs.append(auc_val)

    # Check if this fold is the best so far
    if auc_val > best_auc_across_folds:
        best_auc_across_folds = auc_val
        best_fold = fold_index

    # Move to next fold
    fold_index += 1

# -------------------------------------------------------------------------
# 5) CROSS-VALIDATION RESULTS
# -------------------------------------------------------------------------
print("\n=== CROSS-VALIDATION RESULTS ===")
print(f"Average Loss over {k_folds} folds  : {np.mean(fold_losses):.4f} (± {np.std(fold_losses):.4f})")
print(f"Average Accuracy over {k_folds} folds: {np.mean(fold_accuracies):.4f} (± {np.std(fold_accuracies):.4f})")
print(f"Average AUC over {k_folds} folds     : {np.mean(fold_aucs):.4f} (± {np.std(fold_aucs):.4f})")
# Out:
# Class weights dict: {0: np.float64(4.375273044997815), 1: np.float64(2.78349082823791), 2: np.float64(1.301832835044846), 3: np.float64(12.440993788819876), 4: np.float64(1.2854575792581184), 5: np.float64(0.21338020666879728), 6: np.float64(10.075452716297788)}
#
#
# ===== FOLD 1/5 =====
# Train size: 8012 Val size: 2003
# Train distribution:
#  dx
# nv       5364
# mel       890
# bkl       879
# bcc       411
# akiec     262
# vasc      114
# df         92
# Name: count, dtype: int64
# Val distribution:
#  dx
# nv       1341
# mel       223
# bkl       220
# bcc       103
# akiec      65
# vasc       28
# df         23
# Name: count, dtype: int64
# Found 8012 validated image filenames belonging to 7 classes.
# Found 2003 validated image filenames belonging to 7 classes.
# /Users/robp/.local/share/virtualenvs/account-management-Kww3qb6U/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6222 - auc: 0.8426 - loss: 0.2248
# Epoch 1: val_auc improved from -inf to 0.87622, saving model to resnet50_cbam_classificationhead_fold1_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 415s 2s/step - accuracy: 0.6223 - auc: 0.8427 - loss: 0.2246 - val_accuracy: 0.6695 - val_auc: 0.8762 - val_loss: 0.1723
# Epoch 2/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6694 - auc: 0.8728 - loss: 0.1895
# Epoch 2: val_auc did not improve from 0.87622
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 408s 2s/step - accuracy: 0.6694 - auc: 0.8728 - loss: 0.1895 - val_accuracy: 0.6695 - val_auc: 0.8742 - val_loss: 0.1716
# Epoch 3/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6669 - auc: 0.8725 - loss: 0.1894
# Epoch 3: val_auc did not improve from 0.87622
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 413s 2s/step - accuracy: 0.6669 - auc: 0.8725 - loss: 0.1893 - val_accuracy: 0.6695 - val_auc: 0.8755 - val_loss: 0.1750
# Epoch 4/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6696 - auc: 0.8705 - loss: 0.1905
# Epoch 4: val_auc did not improve from 0.87622
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 420s 2s/step - accuracy: 0.6696 - auc: 0.8706 - loss: 0.1904 - val_accuracy: 0.6695 - val_auc: 0.8744 - val_loss: 0.1723
# Epoch 4: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Epoch 1/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5813 - auc: 0.8727 - loss: 0.2366
# Epoch 1: val_auc improved from -inf to 0.86802, saving model to resnet50_cbam_classificationhead_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 737s 3s/step - accuracy: 0.5815 - auc: 0.8728 - loss: 0.2365 - val_accuracy: 0.6695 - val_auc: 0.8680 - val_loss: 0.3437 - learning_rate: 1.0000e-05
# Epoch 2/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6914 - auc: 0.9377 - loss: 0.1426
# Epoch 2: val_auc improved from 0.86802 to 0.87867, saving model to resnet50_cbam_classificationhead_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 712s 3s/step - accuracy: 0.6914 - auc: 0.9377 - loss: 0.1426 - val_accuracy: 0.6695 - val_auc: 0.8787 - val_loss: 0.3543 - learning_rate: 1.0000e-05
# Epoch 3/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7283 - auc: 0.9524 - loss: 0.1208
# Epoch 3: val_auc improved from 0.87867 to 0.88425, saving model to resnet50_cbam_classificationhead_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 707s 3s/step - accuracy: 0.7283 - auc: 0.9525 - loss: 0.1207 - val_accuracy: 0.6695 - val_auc: 0.8843 - val_loss: 0.2877 - learning_rate: 1.0000e-05
# Epoch 4/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7416 - auc: 0.9598 - loss: 0.1098
# Epoch 4: val_auc improved from 0.88425 to 0.91436, saving model to resnet50_cbam_classificationhead_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 703s 3s/step - accuracy: 0.7417 - auc: 0.9598 - loss: 0.1098 - val_accuracy: 0.6860 - val_auc: 0.9144 - val_loss: 0.2056 - learning_rate: 1.0000e-05
# Epoch 5/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7721 - auc: 0.9682 - loss: 0.0888
# Epoch 5: val_auc improved from 0.91436 to 0.97571, saving model to resnet50_cbam_classificationhead_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 705s 3s/step - accuracy: 0.7721 - auc: 0.9682 - loss: 0.0888 - val_accuracy: 0.7968 - val_auc: 0.9757 - val_loss: 0.0733 - learning_rate: 1.0000e-05
# Epoch 6/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7853 - auc: 0.9723 - loss: 0.0849
# Epoch 6: val_auc improved from 0.97571 to 0.97736, saving model to resnet50_cbam_classificationhead_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 707s 3s/step - accuracy: 0.7853 - auc: 0.9723 - loss: 0.0849 - val_accuracy: 0.8053 - val_auc: 0.9774 - val_loss: 0.0660 - learning_rate: 1.0000e-05
# Epoch 7/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8026 - auc: 0.9773 - loss: 0.0731
# Epoch 7: val_auc improved from 0.97736 to 0.97848, saving model to resnet50_cbam_classificationhead_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 705s 3s/step - accuracy: 0.8026 - auc: 0.9773 - loss: 0.0731 - val_accuracy: 0.8143 - val_auc: 0.9785 - val_loss: 0.0668 - learning_rate: 1.0000e-05
# Epoch 8/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8187 - auc: 0.9810 - loss: 0.0620
# Epoch 8: val_auc did not improve from 0.97848
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 709s 3s/step - accuracy: 0.8187 - auc: 0.9810 - loss: 0.0620 - val_accuracy: 0.8073 - val_auc: 0.9782 - val_loss: 0.0661 - learning_rate: 1.0000e-05
# Epoch 9/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8285 - auc: 0.9826 - loss: 0.0577
# Epoch 9: val_auc did not improve from 0.97848
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 744s 3s/step - accuracy: 0.8285 - auc: 0.9826 - loss: 0.0577 - val_accuracy: 0.8043 - val_auc: 0.9775 - val_loss: 0.0678 - learning_rate: 1.0000e-05
# Epoch 10/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8446 - auc: 0.9847 - loss: 0.0516
# Epoch 10: val_auc improved from 0.97848 to 0.97890, saving model to resnet50_cbam_classificationhead_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 731s 3s/step - accuracy: 0.8445 - auc: 0.9847 - loss: 0.0516 - val_accuracy: 0.8128 - val_auc: 0.9789 - val_loss: 0.0666 - learning_rate: 1.0000e-05
# Epoch 11/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8460 - auc: 0.9858 - loss: 0.0510
# Epoch 11: val_auc improved from 0.97890 to 0.97990, saving model to resnet50_cbam_classificationhead_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 763s 3s/step - accuracy: 0.8460 - auc: 0.9858 - loss: 0.0510 - val_accuracy: 0.8168 - val_auc: 0.9799 - val_loss: 0.0646 - learning_rate: 1.0000e-05
# Epoch 12/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8567 - auc: 0.9882 - loss: 0.0433
# Epoch 12: val_auc did not improve from 0.97990
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 823s 3s/step - accuracy: 0.8567 - auc: 0.9882 - loss: 0.0433 - val_accuracy: 0.8153 - val_auc: 0.9786 - val_loss: 0.0692 - learning_rate: 1.0000e-05
# Epoch 13/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8735 - auc: 0.9902 - loss: 0.0382
# Epoch 13: val_auc improved from 0.97990 to 0.98149, saving model to resnet50_cbam_classificationhead_fold1_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 789s 3s/step - accuracy: 0.8735 - auc: 0.9902 - loss: 0.0382 - val_accuracy: 0.8228 - val_auc: 0.9815 - val_loss: 0.0634 - learning_rate: 1.0000e-05
# Epoch 14/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8776 - auc: 0.9916 - loss: 0.0329
# Epoch 14: val_auc did not improve from 0.98149
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 766s 3s/step - accuracy: 0.8776 - auc: 0.9916 - loss: 0.0329 - val_accuracy: 0.8153 - val_auc: 0.9797 - val_loss: 0.0685 - learning_rate: 1.0000e-05
# Epoch 15/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8825 - auc: 0.9918 - loss: 0.0342
# Epoch 15: val_auc did not improve from 0.98149
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 806s 3s/step - accuracy: 0.8825 - auc: 0.9918 - loss: 0.0342 - val_accuracy: 0.8113 - val_auc: 0.9789 - val_loss: 0.0715 - learning_rate: 1.0000e-05
# Epoch 16/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8969 - auc: 0.9931 - loss: 0.0299
# Epoch 16: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 16: val_auc did not improve from 0.98149
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 818s 3s/step - accuracy: 0.8969 - auc: 0.9931 - loss: 0.0299 - val_accuracy: 0.8268 - val_auc: 0.9801 - val_loss: 0.0680 - learning_rate: 1.0000e-05
# Epoch 17/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9046 - auc: 0.9943 - loss: 0.0256
# Epoch 17: val_auc did not improve from 0.98149
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 833s 3s/step - accuracy: 0.9046 - auc: 0.9943 - loss: 0.0256 - val_accuracy: 0.8223 - val_auc: 0.9802 - val_loss: 0.0681 - learning_rate: 1.0000e-06
# Epoch 18/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9153 - auc: 0.9952 - loss: 0.0240
# Epoch 18: val_auc did not improve from 0.98149
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 873s 3s/step - accuracy: 0.9152 - auc: 0.9952 - loss: 0.0240 - val_accuracy: 0.8188 - val_auc: 0.9794 - val_loss: 0.0693 - learning_rate: 1.0000e-06
# Epoch 19/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9108 - auc: 0.9947 - loss: 0.0262
# Epoch 19: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
#
# Epoch 19: val_auc did not improve from 0.98149
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 805s 3s/step - accuracy: 0.9108 - auc: 0.9947 - loss: 0.0262 - val_accuracy: 0.8218 - val_auc: 0.9799 - val_loss: 0.0687 - learning_rate: 1.0000e-06
# Epoch 20/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9148 - auc: 0.9955 - loss: 0.0229
# Epoch 20: val_auc did not improve from 0.98149
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 991s 4s/step - accuracy: 0.9148 - auc: 0.9955 - loss: 0.0229 - val_accuracy: 0.8218 - val_auc: 0.9801 - val_loss: 0.0683 - learning_rate: 1.0000e-07
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 13.
# FOLD 1 - Loss: 0.0634, Accuracy: 0.8228, AUC: 0.9815
#
#
# ===== FOLD 2/5 =====
# Train size: 8012 Val size: 2003
# Train distribution:
#  dx
# nv       5364
# mel       890
# bkl       879
# bcc       411
# akiec     262
# vasc      114
# df         92
# Name: count, dtype: int64
# Val distribution:
#  dx
# nv       1341
# mel       223
# bkl       220
# bcc       103
# akiec      65
# vasc       28
# df         23
# Name: count, dtype: int64
# Found 8012 validated image filenames belonging to 7 classes.
# Found 2003 validated image filenames belonging to 7 classes.
# /Users/robp/.local/share/virtualenvs/account-management-Kww3qb6U/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6362 - auc: 0.8536 - loss: 0.2133
# Epoch 1: val_auc improved from -inf to 0.87413, saving model to resnet50_cbam_classificationhead_fold2_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 545s 2s/step - accuracy: 0.6363 - auc: 0.8536 - loss: 0.2132 - val_accuracy: 0.6695 - val_auc: 0.8741 - val_loss: 0.1724
# Epoch 2/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6733 - auc: 0.8720 - loss: 0.1850
# Epoch 2: val_auc improved from 0.87413 to 0.87438, saving model to resnet50_cbam_classificationhead_fold2_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 519s 2s/step - accuracy: 0.6733 - auc: 0.8720 - loss: 0.1851 - val_accuracy: 0.6695 - val_auc: 0.8744 - val_loss: 0.1722
# Epoch 3/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6638 - auc: 0.8718 - loss: 0.1899
# Epoch 3: val_auc improved from 0.87438 to 0.87594, saving model to resnet50_cbam_classificationhead_fold2_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 483s 2s/step - accuracy: 0.6638 - auc: 0.8718 - loss: 0.1899 - val_accuracy: 0.6695 - val_auc: 0.8759 - val_loss: 0.1752
# Epoch 4/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6711 - auc: 0.8717 - loss: 0.1898
# Epoch 4: val_auc did not improve from 0.87594
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 419s 2s/step - accuracy: 0.6711 - auc: 0.8717 - loss: 0.1898 - val_accuracy: 0.6695 - val_auc: 0.8739 - val_loss: 0.1730
# Epoch 5/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6596 - auc: 0.8692 - loss: 0.1921
# Epoch 5: val_auc improved from 0.87594 to 0.88171, saving model to resnet50_cbam_classificationhead_fold2_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 402s 2s/step - accuracy: 0.6596 - auc: 0.8692 - loss: 0.1921 - val_accuracy: 0.6695 - val_auc: 0.8817 - val_loss: 0.1719
# Epoch 6/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6672 - auc: 0.8719 - loss: 0.1846
# Epoch 6: val_auc did not improve from 0.88171
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 387s 2s/step - accuracy: 0.6673 - auc: 0.8719 - loss: 0.1846 - val_accuracy: 0.6695 - val_auc: 0.8741 - val_loss: 0.1722
# Epoch 7/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6710 - auc: 0.8724 - loss: 0.1859
# Epoch 7: val_auc improved from 0.88171 to 0.88324, saving model to resnet50_cbam_classificationhead_fold2_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 405s 2s/step - accuracy: 0.6710 - auc: 0.8724 - loss: 0.1859 - val_accuracy: 0.6695 - val_auc: 0.8832 - val_loss: 0.1732
# Epoch 8/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6684 - auc: 0.8699 - loss: 0.1929
# Epoch 8: val_auc did not improve from 0.88324
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 425s 2s/step - accuracy: 0.6684 - auc: 0.8699 - loss: 0.1929 - val_accuracy: 0.6695 - val_auc: 0.8742 - val_loss: 0.1722
# Epoch 9/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6731 - auc: 0.8749 - loss: 0.1782
# Epoch 9: val_auc did not improve from 0.88324
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 443s 2s/step - accuracy: 0.6731 - auc: 0.8749 - loss: 0.1782 - val_accuracy: 0.6695 - val_auc: 0.8816 - val_loss: 0.1727
# Epoch 10/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6639 - auc: 0.8715 - loss: 0.1876
# Epoch 10: val_auc did not improve from 0.88324
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 439s 2s/step - accuracy: 0.6640 - auc: 0.8715 - loss: 0.1876 - val_accuracy: 0.6695 - val_auc: 0.8744 - val_loss: 0.1727
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Epoch 1/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6531 - auc: 0.8960 - loss: 0.2865
# Epoch 1: val_auc improved from -inf to 0.86445, saving model to resnet50_cbam_classificationhead_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 771s 3s/step - accuracy: 0.6530 - auc: 0.8961 - loss: 0.2863 - val_accuracy: 0.6695 - val_auc: 0.8644 - val_loss: 0.4741 - learning_rate: 1.0000e-05
# Epoch 2/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6920 - auc: 0.9382 - loss: 0.1513
# Epoch 2: val_auc improved from 0.86445 to 0.87910, saving model to resnet50_cbam_classificationhead_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 733s 3s/step - accuracy: 0.6920 - auc: 0.9382 - loss: 0.1512 - val_accuracy: 0.6695 - val_auc: 0.8791 - val_loss: 0.4893 - learning_rate: 1.0000e-05
# Epoch 3/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7199 - auc: 0.9518 - loss: 0.1211
# Epoch 3: val_auc did not improve from 0.87910
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 723s 3s/step - accuracy: 0.7200 - auc: 0.9519 - loss: 0.1210 - val_accuracy: 0.6695 - val_auc: 0.8747 - val_loss: 0.3847 - learning_rate: 1.0000e-05
# Epoch 4/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7620 - auc: 0.9660 - loss: 0.0928
# Epoch 4: val_auc improved from 0.87910 to 0.93072, saving model to resnet50_cbam_classificationhead_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 707s 3s/step - accuracy: 0.7620 - auc: 0.9660 - loss: 0.0928 - val_accuracy: 0.6795 - val_auc: 0.9307 - val_loss: 0.2448 - learning_rate: 1.0000e-05
# Epoch 5/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7771 - auc: 0.9693 - loss: 0.0853
# Epoch 5: val_auc improved from 0.93072 to 0.97478, saving model to resnet50_cbam_classificationhead_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 724s 3s/step - accuracy: 0.7771 - auc: 0.9694 - loss: 0.0853 - val_accuracy: 0.8023 - val_auc: 0.9748 - val_loss: 0.0754 - learning_rate: 1.0000e-05
# Epoch 6/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7944 - auc: 0.9747 - loss: 0.0738
# Epoch 6: val_auc improved from 0.97478 to 0.97868, saving model to resnet50_cbam_classificationhead_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 729s 3s/step - accuracy: 0.7944 - auc: 0.9747 - loss: 0.0738 - val_accuracy: 0.8213 - val_auc: 0.9787 - val_loss: 0.0666 - learning_rate: 1.0000e-05
# Epoch 7/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8103 - auc: 0.9786 - loss: 0.0664
# Epoch 7: val_auc improved from 0.97868 to 0.97903, saving model to resnet50_cbam_classificationhead_fold2_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 760s 3s/step - accuracy: 0.8103 - auc: 0.9786 - loss: 0.0664 - val_accuracy: 0.8213 - val_auc: 0.9790 - val_loss: 0.0675 - learning_rate: 1.0000e-05
# Epoch 8/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8236 - auc: 0.9810 - loss: 0.0598
# Epoch 8: val_auc did not improve from 0.97903
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 718s 3s/step - accuracy: 0.8236 - auc: 0.9810 - loss: 0.0598 - val_accuracy: 0.7968 - val_auc: 0.9749 - val_loss: 0.0767 - learning_rate: 1.0000e-05
# Epoch 9/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8262 - auc: 0.9826 - loss: 0.0565
# Epoch 9: val_auc did not improve from 0.97903
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 747s 3s/step - accuracy: 0.8263 - auc: 0.9826 - loss: 0.0565 - val_accuracy: 0.8148 - val_auc: 0.9772 - val_loss: 0.0724 - learning_rate: 1.0000e-05
# Epoch 10/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8417 - auc: 0.9851 - loss: 0.0512
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 10: val_auc did not improve from 0.97903
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 726s 3s/step - accuracy: 0.8417 - auc: 0.9851 - loss: 0.0512 - val_accuracy: 0.8093 - val_auc: 0.9786 - val_loss: 0.0671 - learning_rate: 1.0000e-05
# Epoch 11/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8546 - auc: 0.9870 - loss: 0.0469
# Epoch 11: val_auc did not improve from 0.97903
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 706s 3s/step - accuracy: 0.8546 - auc: 0.9870 - loss: 0.0469 - val_accuracy: 0.8123 - val_auc: 0.9780 - val_loss: 0.0697 - learning_rate: 1.0000e-06
# Epoch 12/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8570 - auc: 0.9872 - loss: 0.0457
# Epoch 12: val_auc did not improve from 0.97903
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 724s 3s/step - accuracy: 0.8570 - auc: 0.9872 - loss: 0.0457 - val_accuracy: 0.8133 - val_auc: 0.9785 - val_loss: 0.0690 - learning_rate: 1.0000e-06
# Epoch 13/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8559 - auc: 0.9875 - loss: 0.0468
# Epoch 13: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
#
# Epoch 13: val_auc did not improve from 0.97903
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 723s 3s/step - accuracy: 0.8559 - auc: 0.9875 - loss: 0.0468 - val_accuracy: 0.8123 - val_auc: 0.9783 - val_loss: 0.0693 - learning_rate: 1.0000e-06
# Epoch 14/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8642 - auc: 0.9888 - loss: 0.0415
# Epoch 14: val_auc did not improve from 0.97903
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 735s 3s/step - accuracy: 0.8642 - auc: 0.9888 - loss: 0.0415 - val_accuracy: 0.8123 - val_auc: 0.9784 - val_loss: 0.0690 - learning_rate: 1.0000e-07
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 7.
# FOLD 2 - Loss: 0.0675, Accuracy: 0.8213, AUC: 0.9790
#
#
# ===== FOLD 3/5 =====
# Train size: 8012 Val size: 2003
# Train distribution:
#  dx
# nv       5364
# mel       891
# bkl       879
# bcc       411
# akiec     262
# vasc      113
# df         92
# Name: count, dtype: int64
# Val distribution:
#  dx
# nv       1341
# mel       222
# bkl       220
# bcc       103
# akiec      65
# vasc       29
# df         23
# Name: count, dtype: int64
# Found 8012 validated image filenames belonging to 7 classes.
# Found 2003 validated image filenames belonging to 7 classes.
# /Users/robp/.local/share/virtualenvs/account-management-Kww3qb6U/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6206 - auc: 0.8441 - loss: 0.2338
# Epoch 1: val_auc improved from -inf to 0.87670, saving model to resnet50_cbam_classificationhead_fold3_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 382s 2s/step - accuracy: 0.6207 - auc: 0.8442 - loss: 0.2337 - val_accuracy: 0.6695 - val_auc: 0.8767 - val_loss: 0.1726
# Epoch 2/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6665 - auc: 0.8717 - loss: 0.1881
# Epoch 2: val_auc did not improve from 0.87670
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 376s 1s/step - accuracy: 0.6665 - auc: 0.8717 - loss: 0.1881 - val_accuracy: 0.6695 - val_auc: 0.8734 - val_loss: 0.1734
# Epoch 3/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6708 - auc: 0.8702 - loss: 0.1898
# Epoch 3: val_auc did not improve from 0.87670
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 380s 2s/step - accuracy: 0.6708 - auc: 0.8702 - loss: 0.1897 - val_accuracy: 0.6695 - val_auc: 0.8743 - val_loss: 0.1729
# Epoch 4/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6618 - auc: 0.8708 - loss: 0.1916
# Epoch 4: val_auc improved from 0.87670 to 0.87952, saving model to resnet50_cbam_classificationhead_fold3_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 382s 2s/step - accuracy: 0.6619 - auc: 0.8708 - loss: 0.1916 - val_accuracy: 0.6695 - val_auc: 0.8795 - val_loss: 0.1725
# Epoch 5/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6783 - auc: 0.8790 - loss: 0.1743
# Epoch 5: val_auc did not improve from 0.87952
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 381s 2s/step - accuracy: 0.6783 - auc: 0.8790 - loss: 0.1743 - val_accuracy: 0.6695 - val_auc: 0.8740 - val_loss: 0.1747
# Epoch 6/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6739 - auc: 0.8772 - loss: 0.1742
# Epoch 6: val_auc did not improve from 0.87952
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 384s 2s/step - accuracy: 0.6739 - auc: 0.8772 - loss: 0.1743 - val_accuracy: 0.6695 - val_auc: 0.8738 - val_loss: 0.1729
# Epoch 7/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6713 - auc: 0.8738 - loss: 0.1837
# Epoch 7: val_auc did not improve from 0.87952
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 380s 2s/step - accuracy: 0.6713 - auc: 0.8738 - loss: 0.1837 - val_accuracy: 0.6695 - val_auc: 0.8749 - val_loss: 0.1723
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Epoch 1/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6295 - auc: 0.8881 - loss: 0.2935
# Epoch 1: val_auc improved from -inf to 0.82230, saving model to resnet50_cbam_classificationhead_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 709s 3s/step - accuracy: 0.6296 - auc: 0.8882 - loss: 0.2934 - val_accuracy: 0.6695 - val_auc: 0.8223 - val_loss: 0.8385 - learning_rate: 1.0000e-05
# Epoch 2/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6902 - auc: 0.9392 - loss: 0.1489
# Epoch 2: val_auc did not improve from 0.82230
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 703s 3s/step - accuracy: 0.6903 - auc: 0.9392 - loss: 0.1489 - val_accuracy: 0.6695 - val_auc: 0.8164 - val_loss: 0.7531 - learning_rate: 1.0000e-05
# Epoch 3/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7300 - auc: 0.9558 - loss: 0.1071
# Epoch 3: val_auc improved from 0.82230 to 0.88486, saving model to resnet50_cbam_classificationhead_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 699s 3s/step - accuracy: 0.7300 - auc: 0.9558 - loss: 0.1071 - val_accuracy: 0.6695 - val_auc: 0.8849 - val_loss: 0.3391 - learning_rate: 1.0000e-05
# Epoch 4/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7502 - auc: 0.9619 - loss: 0.1001
# Epoch 4: val_auc improved from 0.88486 to 0.92782, saving model to resnet50_cbam_classificationhead_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 699s 3s/step - accuracy: 0.7502 - auc: 0.9619 - loss: 0.1001 - val_accuracy: 0.6750 - val_auc: 0.9278 - val_loss: 0.2132 - learning_rate: 1.0000e-05
# Epoch 5/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7722 - auc: 0.9680 - loss: 0.0888
# Epoch 5: val_auc improved from 0.92782 to 0.96992, saving model to resnet50_cbam_classificationhead_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 702s 3s/step - accuracy: 0.7722 - auc: 0.9680 - loss: 0.0888 - val_accuracy: 0.7843 - val_auc: 0.9699 - val_loss: 0.0837 - learning_rate: 1.0000e-05
# Epoch 6/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7856 - auc: 0.9723 - loss: 0.0776
# Epoch 6: val_auc improved from 0.96992 to 0.97450, saving model to resnet50_cbam_classificationhead_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 700s 3s/step - accuracy: 0.7856 - auc: 0.9723 - loss: 0.0776 - val_accuracy: 0.7993 - val_auc: 0.9745 - val_loss: 0.0742 - learning_rate: 1.0000e-05
# Epoch 7/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7978 - auc: 0.9774 - loss: 0.0670
# Epoch 7: val_auc improved from 0.97450 to 0.97463, saving model to resnet50_cbam_classificationhead_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 714s 3s/step - accuracy: 0.7978 - auc: 0.9774 - loss: 0.0671 - val_accuracy: 0.7928 - val_auc: 0.9746 - val_loss: 0.0737 - learning_rate: 1.0000e-05
# Epoch 8/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8093 - auc: 0.9790 - loss: 0.0638
# Epoch 8: val_auc improved from 0.97463 to 0.97601, saving model to resnet50_cbam_classificationhead_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 694s 3s/step - accuracy: 0.8094 - auc: 0.9790 - loss: 0.0638 - val_accuracy: 0.8008 - val_auc: 0.9760 - val_loss: 0.0716 - learning_rate: 1.0000e-05
# Epoch 9/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8287 - auc: 0.9824 - loss: 0.0593
# Epoch 9: val_auc improved from 0.97601 to 0.97631, saving model to resnet50_cbam_classificationhead_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 702s 3s/step - accuracy: 0.8287 - auc: 0.9824 - loss: 0.0593 - val_accuracy: 0.8018 - val_auc: 0.9763 - val_loss: 0.0701 - learning_rate: 1.0000e-05
# Epoch 10/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8417 - auc: 0.9851 - loss: 0.0498
# Epoch 10: val_auc did not improve from 0.97631
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 694s 3s/step - accuracy: 0.8417 - auc: 0.9851 - loss: 0.0499 - val_accuracy: 0.7993 - val_auc: 0.9755 - val_loss: 0.0712 - learning_rate: 1.0000e-05
# Epoch 11/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8428 - auc: 0.9861 - loss: 0.0488
# Epoch 11: val_auc did not improve from 0.97631
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 701s 3s/step - accuracy: 0.8428 - auc: 0.9861 - loss: 0.0488 - val_accuracy: 0.8008 - val_auc: 0.9762 - val_loss: 0.0722 - learning_rate: 1.0000e-05
# Epoch 12/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8627 - auc: 0.9878 - loss: 0.0440
# Epoch 12: val_auc improved from 0.97631 to 0.97750, saving model to resnet50_cbam_classificationhead_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 695s 3s/step - accuracy: 0.8627 - auc: 0.9878 - loss: 0.0440 - val_accuracy: 0.8108 - val_auc: 0.9775 - val_loss: 0.0723 - learning_rate: 1.0000e-05
# Epoch 13/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8691 - auc: 0.9894 - loss: 0.0392
# Epoch 13: val_auc improved from 0.97750 to 0.97758, saving model to resnet50_cbam_classificationhead_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 702s 3s/step - accuracy: 0.8691 - auc: 0.9894 - loss: 0.0393 - val_accuracy: 0.8033 - val_auc: 0.9776 - val_loss: 0.0725 - learning_rate: 1.0000e-05
# Epoch 14/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8829 - auc: 0.9908 - loss: 0.0380
# Epoch 14: val_auc improved from 0.97758 to 0.97775, saving model to resnet50_cbam_classificationhead_fold3_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 704s 3s/step - accuracy: 0.8829 - auc: 0.9908 - loss: 0.0380 - val_accuracy: 0.8008 - val_auc: 0.9778 - val_loss: 0.0726 - learning_rate: 1.0000e-05
# Epoch 15/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8786 - auc: 0.9907 - loss: 0.0364
# Epoch 15: val_auc did not improve from 0.97775
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 701s 3s/step - accuracy: 0.8786 - auc: 0.9907 - loss: 0.0364 - val_accuracy: 0.8073 - val_auc: 0.9774 - val_loss: 0.0727 - learning_rate: 1.0000e-05
# Epoch 16/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8954 - auc: 0.9928 - loss: 0.0314
# Epoch 16: val_auc did not improve from 0.97775
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 694s 3s/step - accuracy: 0.8954 - auc: 0.9928 - loss: 0.0314 - val_accuracy: 0.7589 - val_auc: 0.9662 - val_loss: 0.1023 - learning_rate: 1.0000e-05
# Epoch 17/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8969 - auc: 0.9932 - loss: 0.0299
# Epoch 17: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 17: val_auc did not improve from 0.97775
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 696s 3s/step - accuracy: 0.8969 - auc: 0.9932 - loss: 0.0299 - val_accuracy: 0.7908 - val_auc: 0.9722 - val_loss: 0.0884 - learning_rate: 1.0000e-05
# Epoch 18/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9058 - auc: 0.9940 - loss: 0.0291
# Epoch 18: val_auc did not improve from 0.97775
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 700s 3s/step - accuracy: 0.9058 - auc: 0.9940 - loss: 0.0291 - val_accuracy: 0.7988 - val_auc: 0.9745 - val_loss: 0.0814 - learning_rate: 1.0000e-06
# Epoch 19/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9141 - auc: 0.9955 - loss: 0.0223
# Epoch 19: val_auc did not improve from 0.97775
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 698s 3s/step - accuracy: 0.9141 - auc: 0.9955 - loss: 0.0223 - val_accuracy: 0.7958 - val_auc: 0.9746 - val_loss: 0.0828 - learning_rate: 1.0000e-06
# Epoch 20/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9111 - auc: 0.9947 - loss: 0.0253
# Epoch 20: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
#
# Epoch 20: val_auc did not improve from 0.97775
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 699s 3s/step - accuracy: 0.9111 - auc: 0.9947 - loss: 0.0253 - val_accuracy: 0.7973 - val_auc: 0.9745 - val_loss: 0.0836 - learning_rate: 1.0000e-06
# Epoch 21/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9092 - auc: 0.9950 - loss: 0.0259
# Epoch 21: val_auc did not improve from 0.97775
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 702s 3s/step - accuracy: 0.9092 - auc: 0.9950 - loss: 0.0259 - val_accuracy: 0.7958 - val_auc: 0.9744 - val_loss: 0.0836 - learning_rate: 1.0000e-07
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 14.
# FOLD 3 - Loss: 0.0726, Accuracy: 0.8008, AUC: 0.9778
#
#
# ===== FOLD 4/5 =====
# Train size: 8012 Val size: 2003
# Train distribution:
#  dx
# nv       5364
# mel       891
# bkl       879
# bcc       412
# akiec     261
# vasc      113
# df         92
# Name: count, dtype: int64
# Val distribution:
#  dx
# nv       1341
# mel       222
# bkl       220
# bcc       102
# akiec      66
# vasc       29
# df         23
# Name: count, dtype: int64
# Found 8012 validated image filenames belonging to 7 classes.
# Found 2003 validated image filenames belonging to 7 classes.
# /Users/robp/.local/share/virtualenvs/account-management-Kww3qb6U/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6456 - auc: 0.8596 - loss: 0.2044
# Epoch 1: val_auc improved from -inf to 0.87531, saving model to resnet50_cbam_classificationhead_fold4_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 382s 1s/step - accuracy: 0.6457 - auc: 0.8597 - loss: 0.2044 - val_accuracy: 0.6695 - val_auc: 0.8753 - val_loss: 0.1733
# Epoch 2/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6780 - auc: 0.8684 - loss: 0.1961
# Epoch 2: val_auc improved from 0.87531 to 0.87532, saving model to resnet50_cbam_classificationhead_fold4_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 385s 2s/step - accuracy: 0.6779 - auc: 0.8684 - loss: 0.1961 - val_accuracy: 0.6695 - val_auc: 0.8753 - val_loss: 0.1727
# Epoch 3/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6745 - auc: 0.8775 - loss: 0.1778
# Epoch 3: val_auc did not improve from 0.87532
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 381s 2s/step - accuracy: 0.6744 - auc: 0.8775 - loss: 0.1779 - val_accuracy: 0.6695 - val_auc: 0.8733 - val_loss: 0.1732
# Epoch 4/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6683 - auc: 0.8748 - loss: 0.1848
# Epoch 4: val_auc did not improve from 0.87532
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 385s 2s/step - accuracy: 0.6683 - auc: 0.8748 - loss: 0.1849 - val_accuracy: 0.6695 - val_auc: 0.8738 - val_loss: 0.1743
# Epoch 5/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6721 - auc: 0.8733 - loss: 0.1845
# Epoch 5: val_auc did not improve from 0.87532
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 382s 2s/step - accuracy: 0.6720 - auc: 0.8733 - loss: 0.1845 - val_accuracy: 0.6695 - val_auc: 0.8745 - val_loss: 0.1728
# Epoch 5: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Epoch 1/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6556 - auc: 0.8883 - loss: 0.2897
# Epoch 1: val_auc improved from -inf to 0.85782, saving model to resnet50_cbam_classificationhead_fold4_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 729s 3s/step - accuracy: 0.6556 - auc: 0.8884 - loss: 0.2894 - val_accuracy: 0.6695 - val_auc: 0.8578 - val_loss: 0.3544 - learning_rate: 1.0000e-05
# Epoch 2/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6891 - auc: 0.9407 - loss: 0.1457
# Epoch 2: val_auc improved from 0.85782 to 0.86379, saving model to resnet50_cbam_classificationhead_fold4_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 705s 3s/step - accuracy: 0.6892 - auc: 0.9408 - loss: 0.1456 - val_accuracy: 0.6695 - val_auc: 0.8638 - val_loss: 0.3474 - learning_rate: 1.0000e-05
# Epoch 3/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7357 - auc: 0.9576 - loss: 0.1088
# Epoch 3: val_auc improved from 0.86379 to 0.89843, saving model to resnet50_cbam_classificationhead_fold4_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 704s 3s/step - accuracy: 0.7357 - auc: 0.9576 - loss: 0.1088 - val_accuracy: 0.6695 - val_auc: 0.8984 - val_loss: 0.2643 - learning_rate: 1.0000e-05
# Epoch 4/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7620 - auc: 0.9667 - loss: 0.0885
# Epoch 4: val_auc improved from 0.89843 to 0.93409, saving model to resnet50_cbam_classificationhead_fold4_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 715s 3s/step - accuracy: 0.7621 - auc: 0.9667 - loss: 0.0885 - val_accuracy: 0.6915 - val_auc: 0.9341 - val_loss: 0.1868 - learning_rate: 1.0000e-05
# Epoch 5/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7882 - auc: 0.9718 - loss: 0.0801
# Epoch 5: val_auc improved from 0.93409 to 0.97335, saving model to resnet50_cbam_classificationhead_fold4_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 706s 3s/step - accuracy: 0.7882 - auc: 0.9718 - loss: 0.0801 - val_accuracy: 0.7958 - val_auc: 0.9734 - val_loss: 0.0765 - learning_rate: 1.0000e-05
# Epoch 6/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7895 - auc: 0.9739 - loss: 0.0767
# Epoch 6: val_auc improved from 0.97335 to 0.97446, saving model to resnet50_cbam_classificationhead_fold4_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 711s 3s/step - accuracy: 0.7895 - auc: 0.9739 - loss: 0.0767 - val_accuracy: 0.8038 - val_auc: 0.9745 - val_loss: 0.0766 - learning_rate: 1.0000e-05
# Epoch 7/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8172 - auc: 0.9789 - loss: 0.0651
# Epoch 7: val_auc improved from 0.97446 to 0.97710, saving model to resnet50_cbam_classificationhead_fold4_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 717s 3s/step - accuracy: 0.8172 - auc: 0.9789 - loss: 0.0651 - val_accuracy: 0.8143 - val_auc: 0.9771 - val_loss: 0.0705 - learning_rate: 1.0000e-05
# Epoch 8/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8198 - auc: 0.9807 - loss: 0.0618
# Epoch 8: val_auc did not improve from 0.97710
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 720s 3s/step - accuracy: 0.8199 - auc: 0.9807 - loss: 0.0618 - val_accuracy: 0.8013 - val_auc: 0.9753 - val_loss: 0.0739 - learning_rate: 1.0000e-05
# Epoch 9/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8356 - auc: 0.9845 - loss: 0.0521
# Epoch 9: val_auc did not improve from 0.97710
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 730s 3s/step - accuracy: 0.8356 - auc: 0.9845 - loss: 0.0521 - val_accuracy: 0.8028 - val_auc: 0.9737 - val_loss: 0.0779 - learning_rate: 1.0000e-05
# Epoch 10/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8459 - auc: 0.9856 - loss: 0.0500
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 10: val_auc did not improve from 0.97710
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 728s 3s/step - accuracy: 0.8459 - auc: 0.9856 - loss: 0.0500 - val_accuracy: 0.8118 - val_auc: 0.9759 - val_loss: 0.0726 - learning_rate: 1.0000e-05
# Epoch 11/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8584 - auc: 0.9880 - loss: 0.0428
# Epoch 11: val_auc did not improve from 0.97710
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 748s 3s/step - accuracy: 0.8584 - auc: 0.9880 - loss: 0.0428 - val_accuracy: 0.8143 - val_auc: 0.9758 - val_loss: 0.0738 - learning_rate: 1.0000e-06
# Epoch 12/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8609 - auc: 0.9883 - loss: 0.0440
# Epoch 12: val_auc did not improve from 0.97710
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 763s 3s/step - accuracy: 0.8609 - auc: 0.9883 - loss: 0.0440 - val_accuracy: 0.8123 - val_auc: 0.9756 - val_loss: 0.0755 - learning_rate: 1.0000e-06
# Epoch 13/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8527 - auc: 0.9880 - loss: 0.0444
# Epoch 13: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
#
# Epoch 13: val_auc did not improve from 0.97710
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 783s 3s/step - accuracy: 0.8527 - auc: 0.9880 - loss: 0.0444 - val_accuracy: 0.8113 - val_auc: 0.9756 - val_loss: 0.0748 - learning_rate: 1.0000e-06
# Epoch 14/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8614 - auc: 0.9889 - loss: 0.0400
# Epoch 14: val_auc did not improve from 0.97710
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 771s 3s/step - accuracy: 0.8614 - auc: 0.9889 - loss: 0.0400 - val_accuracy: 0.8143 - val_auc: 0.9760 - val_loss: 0.0749 - learning_rate: 1.0000e-07
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 7.
# FOLD 4 - Loss: 0.0705, Accuracy: 0.8143, AUC: 0.9771
#
#
# ===== FOLD 5/5 =====
# Train size: 8012 Val size: 2003
# Train distribution:
#  dx
# nv       5364
# mel       890
# bkl       880
# bcc       411
# akiec     261
# vasc      114
# df         92
# Name: count, dtype: int64
# Val distribution:
#  dx
# nv       1341
# mel       223
# bkl       219
# bcc       103
# akiec      66
# vasc       28
# df         23
# Name: count, dtype: int64
# Found 8012 validated image filenames belonging to 7 classes.
# Found 2003 validated image filenames belonging to 7 classes.
# /Users/robp/.local/share/virtualenvs/account-management-Kww3qb6U/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6312 - auc: 0.8384 - loss: 0.2297
# Epoch 1: val_auc improved from -inf to 0.87649, saving model to resnet50_cbam_classificationhead_fold5_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 436s 2s/step - accuracy: 0.6313 - auc: 0.8385 - loss: 0.2296 - val_accuracy: 0.6695 - val_auc: 0.8765 - val_loss: 0.1738
# Epoch 2/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6669 - auc: 0.8703 - loss: 0.1880
# Epoch 2: val_auc did not improve from 0.87649
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 453s 2s/step - accuracy: 0.6669 - auc: 0.8703 - loss: 0.1880 - val_accuracy: 0.6695 - val_auc: 0.8740 - val_loss: 0.1733
# Epoch 3/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6662 - auc: 0.8697 - loss: 0.1952
# Epoch 3: val_auc did not improve from 0.87649
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 442s 2s/step - accuracy: 0.6662 - auc: 0.8698 - loss: 0.1951 - val_accuracy: 0.6695 - val_auc: 0.8738 - val_loss: 0.1751
# Epoch 4/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6721 - auc: 0.8756 - loss: 0.1811
# Epoch 4: val_auc improved from 0.87649 to 0.88124, saving model to resnet50_cbam_classificationhead_fold5_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 477s 2s/step - accuracy: 0.6721 - auc: 0.8756 - loss: 0.1812 - val_accuracy: 0.6695 - val_auc: 0.8812 - val_loss: 0.1723
# Epoch 5/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6776 - auc: 0.8771 - loss: 0.1744
# Epoch 5: val_auc did not improve from 0.88124
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 427s 2s/step - accuracy: 0.6776 - auc: 0.8771 - loss: 0.1744 - val_accuracy: 0.6695 - val_auc: 0.8743 - val_loss: 0.1730
# Epoch 6/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6664 - auc: 0.8738 - loss: 0.1889
# Epoch 6: val_auc improved from 0.88124 to 0.88231, saving model to resnet50_cbam_classificationhead_fold5_phase1.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 367s 1s/step - accuracy: 0.6664 - auc: 0.8738 - loss: 0.1888 - val_accuracy: 0.6695 - val_auc: 0.8823 - val_loss: 0.1722
# Epoch 7/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6743 - auc: 0.8752 - loss: 0.1827
# Epoch 7: val_auc did not improve from 0.88231
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 369s 1s/step - accuracy: 0.6743 - auc: 0.8752 - loss: 0.1827 - val_accuracy: 0.6695 - val_auc: 0.8743 - val_loss: 0.1722
# Epoch 8/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6642 - auc: 0.8735 - loss: 0.1894
# Epoch 8: val_auc did not improve from 0.88231
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 371s 1s/step - accuracy: 0.6642 - auc: 0.8735 - loss: 0.1893 - val_accuracy: 0.6695 - val_auc: 0.8743 - val_loss: 0.1722
# Epoch 9/20
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6746 - auc: 0.8755 - loss: 0.1857
# Epoch 9: val_auc did not improve from 0.88231
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 371s 1s/step - accuracy: 0.6746 - auc: 0.8755 - loss: 0.1858 - val_accuracy: 0.6695 - val_auc: 0.8744 - val_loss: 0.1720
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Epoch 1/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6512 - auc: 0.8723 - loss: 0.3946
# Epoch 1: val_auc improved from -inf to 0.86658, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 687s 3s/step - accuracy: 0.6512 - auc: 0.8724 - loss: 0.3941 - val_accuracy: 0.6695 - val_auc: 0.8666 - val_loss: 0.5577 - learning_rate: 1.0000e-05
# Epoch 2/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6816 - auc: 0.9375 - loss: 0.1457
# Epoch 2: val_auc did not improve from 0.86658
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 674s 3s/step - accuracy: 0.6817 - auc: 0.9375 - loss: 0.1457 - val_accuracy: 0.6695 - val_auc: 0.8604 - val_loss: 0.4665 - learning_rate: 1.0000e-05
# Epoch 3/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7182 - auc: 0.9524 - loss: 0.1216
# Epoch 3: val_auc improved from 0.86658 to 0.87366, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 677s 3s/step - accuracy: 0.7183 - auc: 0.9524 - loss: 0.1216 - val_accuracy: 0.6695 - val_auc: 0.8737 - val_loss: 0.4015 - learning_rate: 1.0000e-05
# Epoch 4/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7392 - auc: 0.9602 - loss: 0.1031
# Epoch 4: val_auc improved from 0.87366 to 0.93596, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 675s 3s/step - accuracy: 0.7392 - auc: 0.9602 - loss: 0.1030 - val_accuracy: 0.6835 - val_auc: 0.9360 - val_loss: 0.1996 - learning_rate: 1.0000e-05
# Epoch 5/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7694 - auc: 0.9691 - loss: 0.0856
# Epoch 5: val_auc improved from 0.93596 to 0.97538, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 673s 3s/step - accuracy: 0.7694 - auc: 0.9691 - loss: 0.0856 - val_accuracy: 0.7973 - val_auc: 0.9754 - val_loss: 0.0736 - learning_rate: 1.0000e-05
# Epoch 6/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7841 - auc: 0.9721 - loss: 0.0798
# Epoch 6: val_auc improved from 0.97538 to 0.97836, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 676s 3s/step - accuracy: 0.7841 - auc: 0.9721 - loss: 0.0798 - val_accuracy: 0.8093 - val_auc: 0.9784 - val_loss: 0.0672 - learning_rate: 1.0000e-05
# Epoch 7/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7978 - auc: 0.9761 - loss: 0.0709
# Epoch 7: val_auc did not improve from 0.97836
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 672s 3s/step - accuracy: 0.7979 - auc: 0.9761 - loss: 0.0709 - val_accuracy: 0.8118 - val_auc: 0.9774 - val_loss: 0.0700 - learning_rate: 1.0000e-05
# Epoch 8/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8139 - auc: 0.9787 - loss: 0.0669
# Epoch 8: val_auc improved from 0.97836 to 0.97876, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 675s 3s/step - accuracy: 0.8139 - auc: 0.9787 - loss: 0.0669 - val_accuracy: 0.8133 - val_auc: 0.9788 - val_loss: 0.0693 - learning_rate: 1.0000e-05
# Epoch 9/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8354 - auc: 0.9826 - loss: 0.0567
# Epoch 9: val_auc did not improve from 0.97876
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 678s 3s/step - accuracy: 0.8354 - auc: 0.9826 - loss: 0.0567 - val_accuracy: 0.8083 - val_auc: 0.9763 - val_loss: 0.0777 - learning_rate: 1.0000e-05
# Epoch 10/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8422 - auc: 0.9841 - loss: 0.0528
# Epoch 10: val_auc did not improve from 0.97876
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 680s 3s/step - accuracy: 0.8422 - auc: 0.9841 - loss: 0.0528 - val_accuracy: 0.8148 - val_auc: 0.9769 - val_loss: 0.0755 - learning_rate: 1.0000e-05
# Epoch 11/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8493 - auc: 0.9866 - loss: 0.0460
# Epoch 11: val_auc improved from 0.97876 to 0.97941, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 678s 3s/step - accuracy: 0.8493 - auc: 0.9866 - loss: 0.0460 - val_accuracy: 0.8163 - val_auc: 0.9794 - val_loss: 0.0685 - learning_rate: 1.0000e-05
# Epoch 12/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8683 - auc: 0.9890 - loss: 0.0414
# Epoch 12: val_auc did not improve from 0.97941
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 678s 3s/step - accuracy: 0.8683 - auc: 0.9890 - loss: 0.0414 - val_accuracy: 0.8178 - val_auc: 0.9766 - val_loss: 0.0757 - learning_rate: 1.0000e-05
# Epoch 13/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8670 - auc: 0.9891 - loss: 0.0423
# Epoch 13: val_auc improved from 0.97941 to 0.98129, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 678s 3s/step - accuracy: 0.8670 - auc: 0.9891 - loss: 0.0423 - val_accuracy: 0.8318 - val_auc: 0.9813 - val_loss: 0.0652 - learning_rate: 1.0000e-05
# Epoch 14/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8746 - auc: 0.9904 - loss: 0.0380
# Epoch 14: val_auc did not improve from 0.98129
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 678s 3s/step - accuracy: 0.8746 - auc: 0.9904 - loss: 0.0380 - val_accuracy: 0.8153 - val_auc: 0.9779 - val_loss: 0.0767 - learning_rate: 1.0000e-05
# Epoch 15/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8933 - auc: 0.9924 - loss: 0.0348
# Epoch 15: val_auc improved from 0.98129 to 0.98228, saving model to resnet50_cbam_classificationhead_fold5_phase2.keras
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 678s 3s/step - accuracy: 0.8933 - auc: 0.9924 - loss: 0.0348 - val_accuracy: 0.8328 - val_auc: 0.9823 - val_loss: 0.0622 - learning_rate: 1.0000e-05
# Epoch 16/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8969 - auc: 0.9933 - loss: 0.0297
# Epoch 16: val_auc did not improve from 0.98228
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 678s 3s/step - accuracy: 0.8969 - auc: 0.9933 - loss: 0.0297 - val_accuracy: 0.8193 - val_auc: 0.9768 - val_loss: 0.0806 - learning_rate: 1.0000e-05
# Epoch 17/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9010 - auc: 0.9937 - loss: 0.0296
# Epoch 17: val_auc did not improve from 0.98228
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 679s 3s/step - accuracy: 0.9010 - auc: 0.9937 - loss: 0.0296 - val_accuracy: 0.8173 - val_auc: 0.9759 - val_loss: 0.0870 - learning_rate: 1.0000e-05
# Epoch 18/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9019 - auc: 0.9941 - loss: 0.0278
# Epoch 18: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 18: val_auc did not improve from 0.98228
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 681s 3s/step - accuracy: 0.9019 - auc: 0.9941 - loss: 0.0278 - val_accuracy: 0.8128 - val_auc: 0.9762 - val_loss: 0.0871 - learning_rate: 1.0000e-05
# Epoch 19/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9229 - auc: 0.9959 - loss: 0.0216
# Epoch 19: val_auc did not improve from 0.98228
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 678s 3s/step - accuracy: 0.9229 - auc: 0.9959 - loss: 0.0216 - val_accuracy: 0.8228 - val_auc: 0.9780 - val_loss: 0.0795 - learning_rate: 1.0000e-06
# Epoch 20/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9206 - auc: 0.9959 - loss: 0.0216
# Epoch 20: val_auc did not improve from 0.98228
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 693s 3s/step - accuracy: 0.9206 - auc: 0.9959 - loss: 0.0216 - val_accuracy: 0.8243 - val_auc: 0.9778 - val_loss: 0.0797 - learning_rate: 1.0000e-06
# Epoch 21/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9250 - auc: 0.9962 - loss: 0.0200
# Epoch 21: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
#
# Epoch 21: val_auc did not improve from 0.98228
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 693s 3s/step - accuracy: 0.9250 - auc: 0.9962 - loss: 0.0200 - val_accuracy: 0.8228 - val_auc: 0.9781 - val_loss: 0.0794 - learning_rate: 1.0000e-06
# Epoch 22/200
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9240 - auc: 0.9959 - loss: 0.0215
# Epoch 22: val_auc did not improve from 0.98228
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 695s 3s/step - accuracy: 0.9241 - auc: 0.9959 - loss: 0.0215 - val_accuracy: 0.8228 - val_auc: 0.9775 - val_loss: 0.0805 - learning_rate: 1.0000e-07
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 15.
# FOLD 5 - Loss: 0.0622, Accuracy: 0.8328, AUC: 0.9823
#
# === CROSS-VALIDATION RESULTS ===
# Average Loss over 5 folds  : 0.0672 (± 0.0040)
# Average Accuracy over 5 folds: 0.8184 (± 0.0106)
# Average AUC over 5 folds     : 0.9795 (± 0.0020)
