# %%
import os
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling1D, Dropout, Conv2D, Reshape, MultiHeadAttention, LayerNormalization, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import StratifiedShuffleSplit

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# Out:
# 2024-12-10 07:36:58.203896: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733816218.226774   21499 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733816218.233389   21499 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-10 07:36:58.257533: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
base = '/home/rob/'
csv_file = os.path.join(base, 'ham10000_data/HAM10000_metadata.csv')
img_dir = os.path.join(base, 'ham10000_data/images')
file_ext = '.jpg'

df = pd.read_csv(csv_file)
df['image_path'] = df['image_id'].apply(lambda x: os.path.join(img_dir, x + file_ext))

print(df.head())
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#                                         image_path
# 0  /home/rob/ham10000_data/images/ISIC_0027419.jpg
# 1  /home/rob/ham10000_data/images/ISIC_0025030.jpg
# 2  /home/rob/ham10000_data/images/ISIC_0026769.jpg
# 3  /home/rob/ham10000_data/images/ISIC_0025661.jpg
# 4  /home/rob/ham10000_data/images/ISIC_0031633.jpg

# %%
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

for train_idx, test_idx in sss.split(df, df['dx']):
    train_df = df.iloc[train_idx]
    test_df = df.iloc[test_idx]

print("Train size: ", len(train_df))
print("Train sizes per label and percentage:")
train_counts = train_df['dx'].value_counts()
train_percentages = (train_counts / len(train_df)) * 100
print(train_counts)
print(train_percentages)

print("\nTest size: ", len(test_df))
print("Test sizes per label and percentage:")
test_counts = test_df['dx'].value_counts()
test_percentages = (test_counts / len(test_df)) * 100
print(test_counts)
print(test_percentages)
# Out:
# Train size:  8012
# Train sizes per label and percentage:
# dx
# nv       5364
# mel       890
# bkl       879
# bcc       411
# akiec     262
# vasc      114
# df         92
# Name: count, dtype: int64
# dx
# nv       66.949576
# mel      11.108337
# bkl      10.971043
# bcc       5.129805
# akiec     3.270095
# vasc      1.422866
# df        1.148278
# Name: count, dtype: float64
#
# Test size:  2003
# Test sizes per label and percentage:
# dx
# nv       1341
# mel       223
# bkl       220
# bcc       103
# akiec      65
# vasc       28
# df         23
# Name: count, dtype: int64
# dx
# nv       66.949576
# mel      11.133300
# bkl      10.983525
# bcc       5.142287
# akiec     3.245132
# vasc      1.397903
# df        1.148278
# Name: count, dtype: float64

# %%
IMG_SIZE = 224
BATCH_SIZE = 32

datagen_train = ImageDataGenerator(
    rescale=1.0/255.0,
    rotation_range=5,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    brightness_range=[0.9, 1.1],
    horizontal_flip=True,
    fill_mode='nearest'
)

datagen_test = ImageDataGenerator(rescale=1.0/255.0)

train_generator = datagen_train.flow_from_dataframe(
    dataframe=train_df,
    x_col='image_path',
    y_col='dx',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    seed=42
)

test_generator = datagen_test.flow_from_dataframe(
    dataframe=test_df,
    x_col='image_path',
    y_col='dx',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False,
    seed=42,
)

class_names = [key for key, _ in sorted(train_generator.class_indices.items(), key=lambda item: item[1])]

train_dataset = tf.data.Dataset.from_generator(
    lambda: train_generator,
    output_types=(tf.float32, tf.float32),
    output_shapes=([None, IMG_SIZE, IMG_SIZE, 3], [None, len(class_names)])
).repeat()
train_dataset = train_dataset.prefetch(tf.data.AUTOTUNE)

test_dataset = tf.data.Dataset.from_generator(
    lambda: test_generator,
    output_types=(tf.float32, tf.float32),
    output_shapes=([None, IMG_SIZE, IMG_SIZE, 3], [None, len(class_names)])
).repeat()
test_dataset = test_dataset.prefetch(tf.data.AUTOTUNE)

print("Class Names:", class_names)
print("Train Generator Class Indices:", train_generator.class_indices)
print("Test Generator Class Indices:", test_generator.class_indices)
# Out:
# Found 8012 validated image filenames belonging to 7 classes.
# Found 2003 validated image filenames belonging to 7 classes.
# WARNING:tensorflow:From /tmp/ipykernel_21499/3736262318.py:42: calling DatasetV2.from_generator (from tensorflow.python.data.ops.dataset_ops) with output_types is deprecated and will be removed in a future version.
# Instructions for updating:
# Use output_signature instead
# WARNING:tensorflow:From /tmp/ipykernel_21499/3736262318.py:42: calling DatasetV2.from_generator (from tensorflow.python.data.ops.dataset_ops) with output_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# Use output_signature instead
# Class Names: ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']
# Train Generator Class Indices: {'akiec': 0, 'bcc': 1, 'bkl': 2, 'df': 3, 'mel': 4, 'nv': 5, 'vasc': 6}
# Test Generator Class Indices: {'akiec': 0, 'bcc': 1, 'bkl': 2, 'df': 3, 'mel': 4, 'nv': 5, 'vasc': 6}
# I0000 00:00:1733816221.662932   21499 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:0b:00.0, compute capability: 6.0
# I0000 00:00:1733816221.663522   21499 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 15513 MB memory:  -> device: 1, name: Tesla P100-PCIE-16GB, pci bus id: 0000:13:00.0, compute capability: 6.0

# %%
class TransformerBlockOLD(Layer):
    def __init__(self, num_heads, key_dim, ff_dim, dropout=0.1, **kwargs):
        super(TransformerBlock, self).__init__(**kwargs)
        self.att = MultiHeadAttention(num_heads=num_heads, key_dim=key_dim)
        self.ffn = tf.keras.Sequential([
            Dense(ff_dim, activation='relu'),
            Dense(key_dim),
        ])
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        self.dropout1 = Dropout(dropout)
        self.dropout2 = Dropout(dropout)

    def call(self, inputs, training=False):
        norm_inputs = self.layernorm1(inputs) # Added pre-layer normalization
        attn_output = self.att(norm_inputs, norm_inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)  # Residual connection
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)  # Residual connection


class TransformerBlock(Layer):
    def __init__(self, num_heads, key_dim, ff_dim, dropout=0.1, **kwargs):
        super(TransformerBlock, self).__init__(**kwargs)
        self.att = MultiHeadAttention(num_heads=num_heads, key_dim=key_dim)
        self.ffn = tf.keras.Sequential([
            Dense(ff_dim, activation='relu'),
            Dense(key_dim),
        ])
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        self.dropout1 = Dropout(dropout)
        self.dropout2 = Dropout(dropout)
        self.pos_embedding = None  # Initialize as None; will be created dynamically in `build`.

    def build(self, input_shape):
        seq_len = input_shape[1]
        key_dim = input_shape[2]
        self.pos_embedding = self.add_weight(
            shape=(1, seq_len, key_dim),
            initializer="random_normal",
            trainable=True,
            name="positional_embedding"
        )
        super(TransformerBlock, self).build(input_shape)

    def call(self, inputs, training=False):
        inputs += self.pos_embedding
        norm_inputs = self.layernorm1(inputs)
        attn_output = self.att(norm_inputs, norm_inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = inputs + attn_output  # Residual connection
        ffn_norm_inputs = self.layernorm2(out1)
        ffn_output = self.ffn(ffn_norm_inputs)
        ffn_output = self.dropout2(ffn_output, training=training)
        return out1 + ffn_output  # Residual connection

# %%
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))
base_model.trainable = False

resnet_output = base_model.output

x = Conv2D(256, 1)(resnet_output)  # Project to desired embedding size
x = Reshape((-1, 256))(x)          # Flatten feature maps

transformer_block = TransformerBlock(num_heads=8, key_dim=256, ff_dim=512, dropout=0.1)(x)
x = GlobalAveragePooling1D()(transformer_block)

# Classification head
x = Dropout(0.5)(x)
output = Dense(len(class_names), activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

# %%
def focal_loss(alpha=0.25, gamma=2.0):
    """
    Focal Loss for one-hot encoded multi-class data.

    Parameters:
    - alpha: Weighting factor for positive classes, default is 0.25.
    - gamma: Focusing parameter to reduce the loss contribution from well-classified examples, default is 2.0.

    Returns:
    - A callable loss function for use with Keras models.
    """
    def focal_loss_fixed(y_true, y_pred):
        # Clip predictions to prevent log(0)
        y_pred = tf.clip_by_value(y_pred, tf.keras.backend.epsilon(), 1. - tf.keras.backend.epsilon())

        # Compute focal loss components
        cross_entropy = -y_true * tf.math.log(y_pred)
        weights = alpha * y_true * tf.math.pow(1 - y_pred, gamma)

        # Compute weighted loss
        focal_loss = tf.reduce_sum(weights * cross_entropy, axis=-1)
        return tf.reduce_mean(focal_loss)

    return focal_loss_fixed

# %%
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss=focal_loss(),
    metrics=['accuracy']
)

# %%
model_path = 'models/best_model_resnet50_class_weights_focal_loss.keras'

callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=1),
    EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True),
    ModelCheckpoint(filepath=model_path, save_best_only=True, monitor='val_loss', verbose=1)
]

# %%
class_weights_array = compute_class_weight(
    class_weight='balanced',
    classes=np.array(class_names),
    y=df['dx']
)

class_weights_dict = {
    train_generator.class_indices[class_name]: weight
    for class_name, weight in zip(class_names, class_weights_array)
}

print(class_weights_dict)
# Out:
# {0: np.float64(4.375273044997815), 1: np.float64(2.78349082823791), 2: np.float64(1.301832835044846), 3: np.float64(12.440993788819876), 4: np.float64(1.2854575792581184), 5: np.float64(0.21338020666879728), 6: np.float64(10.075452716297788)}

# %%
steps_per_epoch = len(train_df) // BATCH_SIZE
validation_steps = len(test_df) // BATCH_SIZE

history = model.fit(
    train_dataset,
    validation_data=test_dataset,
    epochs=20,
    steps_per_epoch=steps_per_epoch,
    validation_steps=validation_steps,
    callbacks=callbacks,
    class_weight=class_weights_dict
)
# Out:
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733816233.578251   21590 service.cc:148] XLA service 0x77d738002160 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1733816233.578299   21590 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1733816233.578303   21590 service.cc:156]   StreamExecutor device (1): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2024-12-10 07:37:13.884874: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1733816235.387831   21590 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2024-12-10 07:37:16.571476: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{} for conv (f32[32,64,56,56]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,56,56]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2024-12-10 07:37:16.852636: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{} for conv (f32[32,128,28,28]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,28,28]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2024-12-10 07:37:17.162100: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{} for conv (f32[32,256,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,14,14]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2024-12-10 07:37:17.462787: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{} for conv (f32[32,512,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,512,7,7]{3,2,1,0}, f32[512,512,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2024-12-10 07:37:19.115109: W external/local_xla/xla/service/gpu/nvptx_compiler.cc:930] The NVIDIA driver's CUDA version is 12.4 which is older than the PTX compiler version 12.5.82. Because the driver is older than the PTX compiler version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.
#   3/250 ━━━━━━━━━━━━━━━━━━━━ 14s 59ms/step - accuracy: 0.3559 - loss: 0.7543
# I0000 00:00:1733816241.767223   21590 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - accuracy: 0.6421 - loss: 1.3178
# Epoch 1: val_loss improved from inf to 1.33031, saving model to models/best_model_resnet50_class_weights_focal_loss.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 160s 575ms/step - accuracy: 0.6421 - loss: 1.3181 - val_accuracy: 0.6699 - val_loss: 1.3303 - learning_rate: 0.0010
# Epoch 2/20
# 2024-12-10 07:39:47.104790: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{} for conv (f32[12,64,56,56]{3,2,1,0}, u8[0]{0}) custom-call(f32[12,64,56,56]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2024-12-10 07:39:47.269746: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{} for conv (f32[12,128,28,28]{3,2,1,0}, u8[0]{0}) custom-call(f32[12,128,28,28]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2024-12-10 07:39:47.460916: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{} for conv (f32[12,256,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[12,256,14,14]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2024-12-10 07:39:47.665037: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{} for conv (f32[12,512,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[12,512,7,7]{3,2,1,0}, f32[512,512,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step - accuracy: 0.6657 - loss: 1.4318
# 2024-12-10 07:41:54.605975: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{} for conv (f32[19,64,56,56]{3,2,1,0}, u8[0]{0}) custom-call(f32[19,64,56,56]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2024-12-10 07:41:54.795873: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{} for conv (f32[19,128,28,28]{3,2,1,0}, u8[0]{0}) custom-call(f32[19,128,28,28]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2024-12-10 07:41:55.023577: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{} for conv (f32[19,256,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[19,256,14,14]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2024-12-10 07:41:55.238101: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{} for conv (f32[19,512,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[19,512,7,7]{3,2,1,0}, f32[512,512,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# Epoch 2: val_loss did not improve from 1.33031
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 145s 554ms/step - accuracy: 0.6657 - loss: 1.4317 - val_accuracy: 0.6687 - val_loss: 1.3350 - learning_rate: 0.0010
# Epoch 3/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - accuracy: 0.6659 - loss: 1.4498
# Epoch 3: val_loss did not improve from 1.33031
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 131s 525ms/step - accuracy: 0.6660 - loss: 1.4496 - val_accuracy: 0.6677 - val_loss: 1.3391 - learning_rate: 0.0010
# Epoch 4/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - accuracy: 0.6637 - loss: 1.4161
# Epoch 4: val_loss improved from 1.33031 to 1.32682, saving model to models/best_model_resnet50_class_weights_focal_loss.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 132s 530ms/step - accuracy: 0.6638 - loss: 1.4160 - val_accuracy: 0.6707 - val_loss: 1.3268 - learning_rate: 0.0010
# Epoch 5/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.6706 - loss: 1.3705
# Epoch 5: val_loss improved from 1.32682 to 1.32477, saving model to models/best_model_resnet50_class_weights_focal_loss.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 131s 525ms/step - accuracy: 0.6706 - loss: 1.3706 - val_accuracy: 0.6712 - val_loss: 1.3248 - learning_rate: 0.0010
# Epoch 6/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.6673 - loss: 1.4662
# Epoch 6: val_loss did not improve from 1.32477
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 127s 511ms/step - accuracy: 0.6674 - loss: 1.4659 - val_accuracy: 0.6702 - val_loss: 1.3289 - learning_rate: 0.0010
# Epoch 7/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.6643 - loss: 1.4411
# Epoch 7: val_loss did not improve from 1.32477
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 129s 520ms/step - accuracy: 0.6644 - loss: 1.4409 - val_accuracy: 0.6687 - val_loss: 1.3350 - learning_rate: 0.0010
# Epoch 8/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.6764 - loss: 1.3373
# Epoch 8: val_loss did not improve from 1.32477
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 132s 528ms/step - accuracy: 0.6764 - loss: 1.3375 - val_accuracy: 0.6687 - val_loss: 1.3350 - learning_rate: 0.0010
# Epoch 9/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.6648 - loss: 1.3984
# Epoch 9: val_loss did not improve from 1.32477
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 132s 529ms/step - accuracy: 0.6648 - loss: 1.3984 - val_accuracy: 0.6682 - val_loss: 1.3370 - learning_rate: 0.0010
# Epoch 10/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.6771 - loss: 1.3033
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 10: val_loss did not improve from 1.32477
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 131s 526ms/step - accuracy: 0.6771 - loss: 1.3036 - val_accuracy: 0.6687 - val_loss: 1.3350 - learning_rate: 0.0010
# Epoch 11/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.6709 - loss: 1.3564
# Epoch 11: val_loss did not improve from 1.32477
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 131s 527ms/step - accuracy: 0.6709 - loss: 1.3565 - val_accuracy: 0.6692 - val_loss: 1.3330 - learning_rate: 1.0000e-04
# Epoch 12/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.6724 - loss: 1.3635
# Epoch 12: val_loss improved from 1.32477 to 1.32477, saving model to models/best_model_resnet50_class_weights_focal_loss.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 132s 529ms/step - accuracy: 0.6724 - loss: 1.3636 - val_accuracy: 0.6712 - val_loss: 1.3248 - learning_rate: 1.0000e-04
# Epoch 13/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.6632 - loss: 1.4325
# Epoch 13: val_loss did not improve from 1.32477
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 130s 521ms/step - accuracy: 0.6633 - loss: 1.4324 - val_accuracy: 0.6702 - val_loss: 1.3289 - learning_rate: 1.0000e-04
# Epoch 14/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.6685 - loss: 1.3920
# Epoch 14: val_loss did not improve from 1.32477
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 131s 527ms/step - accuracy: 0.6685 - loss: 1.3920 - val_accuracy: 0.6707 - val_loss: 1.3268 - learning_rate: 1.0000e-04
# Epoch 15/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.6731 - loss: 1.3747
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 15: val_loss did not improve from 1.32477
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 131s 525ms/step - accuracy: 0.6731 - loss: 1.3748 - val_accuracy: 0.6707 - val_loss: 1.3268 - learning_rate: 1.0000e-04
# Epoch 16/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.6698 - loss: 1.4075
# Epoch 16: val_loss did not improve from 1.32477
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 131s 527ms/step - accuracy: 0.6698 - loss: 1.4076 - val_accuracy: 0.6687 - val_loss: 1.3350 - learning_rate: 1.0000e-05
# Epoch 17/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.6725 - loss: 1.3991
# Epoch 17: val_loss improved from 1.32477 to 1.32273, saving model to models/best_model_resnet50_class_weights_focal_loss.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 133s 533ms/step - accuracy: 0.6725 - loss: 1.3990 - val_accuracy: 0.6717 - val_loss: 1.3227 - learning_rate: 1.0000e-05
# Epoch 18/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.6655 - loss: 1.4351
# Epoch 18: val_loss did not improve from 1.32273
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 130s 521ms/step - accuracy: 0.6655 - loss: 1.4350 - val_accuracy: 0.6692 - val_loss: 1.3330 - learning_rate: 1.0000e-05
# Epoch 19/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.6709 - loss: 1.3685
# Epoch 19: val_loss did not improve from 1.32273
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 131s 526ms/step - accuracy: 0.6709 - loss: 1.3686 - val_accuracy: 0.6687 - val_loss: 1.3350 - learning_rate: 1.0000e-05
# Epoch 20/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.6643 - loss: 1.4358
# Epoch 20: val_loss did not improve from 1.32273
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 131s 524ms/step - accuracy: 0.6643 - loss: 1.4357 - val_accuracy: 0.6687 - val_loss: 1.3350 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 17.

# %%
base_model.trainable = True

model.compile(
    optimizer=Adam(learning_rate=1e-5),
    loss=focal_loss(),
    metrics=['accuracy']
)

# %%
fine_tune_history = model.fit(
    train_dataset,
    validation_data=test_dataset,
    epochs=100,
    steps_per_epoch=steps_per_epoch,
    validation_steps=validation_steps,
    callbacks=callbacks,
    class_weight=class_weights_dict
)
# Out:
# Epoch 1/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - accuracy: 0.6415 - loss: 1.0945
# Epoch 1: val_loss did not improve from 1.32273
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 215s 629ms/step - accuracy: 0.6415 - loss: 1.0931 - val_accuracy: 0.6702 - val_loss: 1.3289 - learning_rate: 1.0000e-05
# Epoch 2/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.6455 - loss: 0.2763
# Epoch 2: val_loss did not improve from 1.32273
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 130s 520ms/step - accuracy: 0.6456 - loss: 0.2761 - val_accuracy: 0.6687 - val_loss: 1.3350 - learning_rate: 1.0000e-05
# Epoch 3/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step - accuracy: 0.7038 - loss: 0.1751
# Epoch 3: val_loss improved from 1.32273 to 1.31289, saving model to models/best_model_resnet50_class_weights_focal_loss.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 134s 539ms/step - accuracy: 0.7038 - loss: 0.1750 - val_accuracy: 0.6687 - val_loss: 1.3129 - learning_rate: 1.0000e-05
# Epoch 4/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - accuracy: 0.7299 - loss: 0.1423
# Epoch 4: val_loss improved from 1.31289 to 0.59094, saving model to models/best_model_resnet50_class_weights_focal_loss.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 129s 518ms/step - accuracy: 0.7300 - loss: 0.1422 - val_accuracy: 0.6794 - val_loss: 0.5909 - learning_rate: 1.0000e-05
# Epoch 5/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.7616 - loss: 0.0993
# Epoch 5: val_loss improved from 0.59094 to 0.09406, saving model to models/best_model_resnet50_class_weights_focal_loss.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 129s 517ms/step - accuracy: 0.7616 - loss: 0.0993 - val_accuracy: 0.8113 - val_loss: 0.0941 - learning_rate: 1.0000e-05
# Epoch 6/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step - accuracy: 0.7784 - loss: 0.0943
# Epoch 6: val_loss improved from 0.09406 to 0.09279, saving model to models/best_model_resnet50_class_weights_focal_loss.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 129s 517ms/step - accuracy: 0.7784 - loss: 0.0943 - val_accuracy: 0.7600 - val_loss: 0.0928 - learning_rate: 1.0000e-05
# Epoch 7/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.7940 - loss: 0.0812
# Epoch 7: val_loss improved from 0.09279 to 0.07641, saving model to models/best_model_resnet50_class_weights_focal_loss.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 131s 525ms/step - accuracy: 0.7940 - loss: 0.0812 - val_accuracy: 0.8179 - val_loss: 0.0764 - learning_rate: 1.0000e-05
# Epoch 8/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - accuracy: 0.8202 - loss: 0.0727
# Epoch 8: val_loss improved from 0.07641 to 0.07221, saving model to models/best_model_resnet50_class_weights_focal_loss.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 132s 528ms/step - accuracy: 0.8202 - loss: 0.0727 - val_accuracy: 0.8163 - val_loss: 0.0722 - learning_rate: 1.0000e-05
# Epoch 9/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.8214 - loss: 0.0640
# Epoch 9: val_loss did not improve from 0.07221
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 129s 516ms/step - accuracy: 0.8214 - loss: 0.0640 - val_accuracy: 0.8097 - val_loss: 0.0745 - learning_rate: 1.0000e-05
# Epoch 10/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.8317 - loss: 0.0617
# Epoch 10: val_loss improved from 0.07221 to 0.07205, saving model to models/best_model_resnet50_class_weights_focal_loss.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 133s 535ms/step - accuracy: 0.8317 - loss: 0.0617 - val_accuracy: 0.8265 - val_loss: 0.0720 - learning_rate: 1.0000e-05
# Epoch 11/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.8523 - loss: 0.0515
# Epoch 11: val_loss did not improve from 0.07205
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 129s 517ms/step - accuracy: 0.8523 - loss: 0.0514 - val_accuracy: 0.8118 - val_loss: 0.0758 - learning_rate: 1.0000e-05
# Epoch 12/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.8582 - loss: 0.0502
# Epoch 12: val_loss improved from 0.07205 to 0.05909, saving model to models/best_model_resnet50_class_weights_focal_loss.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 134s 537ms/step - accuracy: 0.8582 - loss: 0.0502 - val_accuracy: 0.8402 - val_loss: 0.0591 - learning_rate: 1.0000e-05
# Epoch 13/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.8761 - loss: 0.0454
# Epoch 13: val_loss did not improve from 0.05909
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 130s 520ms/step - accuracy: 0.8761 - loss: 0.0454 - val_accuracy: 0.8072 - val_loss: 0.0714 - learning_rate: 1.0000e-05
# Epoch 14/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.8837 - loss: 0.0398
# Epoch 14: val_loss did not improve from 0.05909
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 131s 525ms/step - accuracy: 0.8837 - loss: 0.0398 - val_accuracy: 0.8148 - val_loss: 0.0774 - learning_rate: 1.0000e-05
# Epoch 15/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - accuracy: 0.8997 - loss: 0.0342
# Epoch 15: val_loss did not improve from 0.05909
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 130s 523ms/step - accuracy: 0.8997 - loss: 0.0342 - val_accuracy: 0.8305 - val_loss: 0.0741 - learning_rate: 1.0000e-05
# Epoch 16/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.8851 - loss: 0.0360
# Epoch 16: val_loss did not improve from 0.05909
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 131s 526ms/step - accuracy: 0.8852 - loss: 0.0360 - val_accuracy: 0.8387 - val_loss: 0.0697 - learning_rate: 1.0000e-05
# Epoch 17/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.9058 - loss: 0.0310
# Epoch 17: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 17: val_loss did not improve from 0.05909
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 131s 526ms/step - accuracy: 0.9058 - loss: 0.0310 - val_accuracy: 0.8285 - val_loss: 0.0786 - learning_rate: 1.0000e-05
# Epoch 18/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.9182 - loss: 0.0254
# Epoch 18: val_loss did not improve from 0.05909
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 131s 527ms/step - accuracy: 0.9182 - loss: 0.0254 - val_accuracy: 0.8371 - val_loss: 0.0726 - learning_rate: 1.0000e-06
# Epoch 19/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.9215 - loss: 0.0233
# Epoch 19: val_loss did not improve from 0.05909
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 131s 526ms/step - accuracy: 0.9216 - loss: 0.0233 - val_accuracy: 0.8311 - val_loss: 0.0732 - learning_rate: 1.0000e-06
# Epoch 20/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.9241 - loss: 0.0227
# Epoch 20: val_loss did not improve from 0.05909
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 131s 527ms/step - accuracy: 0.9241 - loss: 0.0227 - val_accuracy: 0.8336 - val_loss: 0.0729 - learning_rate: 1.0000e-06
# Epoch 21/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.9299 - loss: 0.0213
# Epoch 21: val_loss did not improve from 0.05909
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 132s 528ms/step - accuracy: 0.9299 - loss: 0.0213 - val_accuracy: 0.8321 - val_loss: 0.0745 - learning_rate: 1.0000e-06
# Epoch 22/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.9317 - loss: 0.0199
# Epoch 22: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
#
# Epoch 22: val_loss did not improve from 0.05909
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 132s 531ms/step - accuracy: 0.9316 - loss: 0.0199 - val_accuracy: 0.8305 - val_loss: 0.0752 - learning_rate: 1.0000e-06
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.

# %%
model.load_weights(model_path)

# %%
loss, accuracy = model.evaluate(test_generator, steps=len(test_generator))
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")
print(f"Total Predictions: {len(test_generator) * BATCH_SIZE}")
# Out:
# /home/rob/.notebook/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 192ms/step - accuracy: 0.8389 - loss: 0.0651
# Test Loss: 0.06073018163442612
# Test Accuracy: 0.8377434015274048
# Total Predictions: 2016

# %%
accuracy = history.history['accuracy'] + fine_tune_history.history['accuracy']
val_accuracy = history.history['val_accuracy'] + fine_tune_history.history['val_accuracy']
loss = history.history['loss'] + fine_tune_history.history['loss']
val_loss = history.history['val_loss'] + fine_tune_history.history['val_loss']

epochs = range(1, len(accuracy) + 1)

plt.figure(figsize=(10, 6))
plt.plot(epochs, accuracy, label='Training Accuracy')
plt.plot(epochs, val_accuracy, label='Validation Accuracy')
plt.axvline(x=len(history.history['accuracy']), color='r', linestyle='--', label='Start of Fine-Tuning')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.axvline(x=len(history.history['loss']), color='r', linestyle='--', label='Start of Fine-Tuning')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
y_pred = np.argmax(model.predict(test_generator), axis=-1)
y_true = test_generator.classes

print("Classification Report:\n", classification_report(y_true, y_pred, target_names=class_names))
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 20s 255ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#        akiec       0.75      0.46      0.57        65
#          bcc       0.76      0.68      0.72       103
#          bkl       0.61      0.75      0.68       220
#           df       0.71      0.52      0.60        23
#          mel       0.59      0.64      0.61       223
#           nv       0.94      0.92      0.93      1341
#         vasc       0.84      0.75      0.79        28
#
#     accuracy                           0.84      2003
#    macro avg       0.74      0.68      0.70      2003
# weighted avg       0.85      0.84      0.84      2003

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# %%
label_counts = np.bincount(y_true)
class_accuracies = np.diag(cm) / label_counts

classes = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']
total_counts = label_counts
accuracies = class_accuracies

fig, ax1 = plt.subplots(figsize=(10, 6))

ax1.bar(classes, total_counts, alpha=0.7, label='Total Samples', color='blue')
ax1.set_xlabel('Classes')
ax1.set_ylabel('Total Samples', color='blue')
ax1.set_title('Per-Class Total Samples and Accuracy')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.legend(loc='upper left')

ax2 = ax1.twinx()
ax2.plot(classes, accuracies, color='orange', marker='o', label='Accuracy')
ax2.set_ylabel('Accuracy', color='orange')
ax2.tick_params(axis='y', labelcolor='orange')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
# Compute overall ROC AUC for multi-class classification
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.preprocessing import label_binarize

num_classes = len(classes)
y_true_one_hot = label_binarize(y_true, classes=np.arange(num_classes))

y_pred_prob = np.zeros_like(y_true_one_hot)
for i, label in enumerate(y_pred):
    y_pred_prob[i, label] = 1

fpr, tpr, _ = roc_curve(y_true_one_hot.ravel(), y_pred_prob.ravel())
roc_auc = roc_auc_score(y_true_one_hot, y_pred_prob, average="micro")

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color="blue", label=f"Micro-Average ROC Curve (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], color="gray", linestyle="--", label="Random Guess")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Overall ROC Curve and AUC")
plt.legend(loc="lower right")
plt.grid()
plt.tight_layout()
plt.show()
